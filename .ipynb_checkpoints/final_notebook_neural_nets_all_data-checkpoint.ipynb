# %%
import numpy as np
import pandas as pd
#for reading in data properly
import ast
import json

import gensim
from gensim.models import Word2Vec

from sklearn.model_selection import train_test_split
from sklearn import utils
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

import re

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import keras.backend as K
from keras.callbacks import EarlyStopping
from keras.layers import Conv1D, GlobalMaxPooling1D, LSTM, SimpleRNN, Dense, Dropout, Flatten
from keras.layers import Input, concatenate, Activation
from keras.layers.embeddings import Embedding
from keras.models import Sequential, Model
from keras.regularizers import l2

stop_words = set(stopwords.words('english'))
# Out:
# Using TensorFlow backend.

# %% [markdown]
# read in the data

# %%
all_data = pd.read_csv('train.csv')
all_data = all_data.dropna(subset=['overview', 'genres']) #drop cols without overview or genre (data we use or labels)

# %%
#parse each row to get label vectors from json
def parse_genres_json(x):
    try:
        json_genres = json.loads(x.replace("'", '"'))
        numElems = len(json_genres)
        ret = [0]*len(genre_dict) #number of genres we are looking at
        for i in range(numElems):
            genre_str = (json_genres[i]['name'])
            if genre_str in genre_map.keys():
                ret[genre_dict[genre_map[genre_str]]] = 1
        return ret
    except Exception as excep:
        print('Exception' + str(excep))
        return ''

# %% [markdown]
# Get dictionary for genre to its index in label vector

# %%
#incldue ALL genres of data set in genre dict as is
genre_dict = {'War': 0,
 'Family': 1,
 'Science Fiction': 2,
 'Thriller': 3,
 'Horror': 4,
 'Romance': 5,
 'Drama': 6,
 'Foreign': 7,
 'Documentary': 8,
 'Fantasy': 9,
 'Western': 10,
 'History': 11,
 'Comedy': 12,
 'Action': 13,
 'Adventure': 14,
 'Animation': 15,
 'Crime': 16,
 'Music': 17,
 'TV Movie': 18,
 'Mystery': 19}

# %%
#for mapping to coarse grained labels (in this situation we don't do that so labels map to self)
genre_map = {'War': 'War',
 'Family': 'Family',
 'Science Fiction': 'Science Fiction',
 'Thriller': 'Thriller',
 'Horror': 'Horror',
 'Romance': 'Romance',
 'Drama': 'Drama',
 'Foreign': 'Foreign',
 'Documentary': 'Documentary',
 'Fantasy': 'Fantasy',
 'Western': 'Western',
 'History': 'History',
 'Comedy': 'Comedy',
 'Action': 'Action',
 'Adventure': 'Adventure',
 'Animation': 'Animation',
 'Crime': 'Crime',
 'Music': 'Music',
 'TV Movie': 'TV Movie',
 'Mystery': 'Mystery'}

# %%
def getGenresVects():
    y = all_data['genres']
    ret = y.apply(parse_genres_json)
    all_data['genres_vect'] = ret

# %%
getGenresVects() #get label vectors for genres indexed by indexes in genre_dict

# %%
#put to lower case, remove punctation, remove stopwords
def cleanText(text):
    no_stopword_text = [w for w in text.split() if not w in stop_words]
    text = ' '.join(no_stopword_text)
    text = re.sub(r'[^a-z A-Z0-9]', "", text) #maybe shouldn't remove punction between words here?
    text = text.lower()
    return text

all_data['cleanOverview'] = all_data['overview'].apply(cleanText)

# %%
all_data = all_data[all_data.genres_vect.map(sum) > 0] #drop rows that now have no labels

# %%
#neural net data only needs a few cols
nn_data = all_data[['cleanOverview', 'genres_vect', 'overview']]

# %%
train, test = train_test_split(nn_data, test_size=0.2, random_state=42)

# %% [markdown]
# Extract actual features and labels from train and test set

# %%
#gettrian and test features for classification. Just need text and lables for this
x = train['cleanOverview'].values.tolist()
y = train['genres_vect']
x_test = test['cleanOverview'].values.tolist()
y_test = test['genres_vect']

# %%
#convert labels from array of lists to numpy array

y_train = y.tolist()
y_train = np.array(y_train)

y_test = y_test.tolist()
y_test = np.array(y_test)

# %% [markdown]
# Get initial word embedding vectors

# %%
tok = [word_tokenize(ov) for ov in x]

# %%
word_vec_len = 32
w2v = Word2Vec(tok, min_count = 2, size=word_vec_len)

# %%
num_words_kept = 100000 #using 100000 most popular words, use throughout

tokenizer = Tokenizer(num_words_kept)
tokenizer.fit_on_texts(x)
sequences = tokenizer.texts_to_sequences(x)

max_seq_len = 150 #larger than averaage but not too large

#get actual train features to feed into neural nets for training
x_train_seq = pad_sequences(sequences, maxlen=max_seq_len)

# %%
test_sequences = tokenizer.texts_to_sequences(x_test)
#get actual test features to feed into neural nets for testing
x_test_seq = pad_sequences(test_sequences, maxlen=max_seq_len)

# %% [markdown]
# Get word embeddings matrix for start input to neural net

# %%
#Citation: This technique to get word embeddings comes, with some minor changes, mostly from: 
#https://towardsdatascience.com/another-twitter-sentiment-analysis-with-python-part-11-cnn-word2vec-41f5e28eda74

embeddings_index = {}
for w in w2v.wv.vocab.keys():
    embeddings_index[w] = w2v.wv[w]


embedding_matrix = np.zeros((num_words_kept, word_vec_len))
for word, i in tokenizer.word_index.items():
    if i >= num_words_kept:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %% [markdown]
# Below we define evlaution metric functions

# %%
def get_per_label_metrics(real_labels_matrix, predictions_labels_matrix):
    for genre in genre_dict.keys():
        index = genre_dict[genre]
        real_labels_vect = real_labels_matrix[:, index]
        prediction_vect = predictions_labels_matrix[:,index]
        print("Accuruacy for " + genre + ": " + str(accuracy_score(real_labels_vect, prediction_vect)))
        print("Precision for " + genre + ": " + str(precision_score(real_labels_vect, prediction_vect)))
        print("Recall for " + genre + ": " + str(recall_score(real_labels_vect, prediction_vect)))
        print()

# %%
#size of intersection of predicted and actual labels divided by size of their union for each datapoint tested on
#sum those and then divide by number of datapoints
#vectorized for speed
def multi_label_accuracy(real_labels_matrix, predictions_labels_matrix):
    #binary so set intersection is and operator
    intersection = real_labels_matrix & predictions_labels_matrix
    #set union for binary is same as or operator
    union = real_labels_matrix | predictions_labels_matrix
    #sum(array.T) gets number of 1s in row
    row_wise_accuracy = sum(intersection.T) / sum(union.T)
    return sum(row_wise_accuracy) / real_labels_matrix.shape[0]

#size of intersection of predicted and actual labels divided by size of predicted set for each datapoint tested on
#sum those and divide by number of datapoints
#if no predicted labels, don't count that row towards the precision as that would be undefined
def multi_label_precision(real_labels_matrix, predictions_labels_matrix):
    #binary so set intersection is and operator
    intersection = real_labels_matrix & predictions_labels_matrix
    precision_sum = 0
    num_rows = 0
    for row in range(intersection.shape[0]):
        if sum(predictions_labels_matrix[row]) > 0: #if there is at least one prediction for this row
            num_rows += 1
            precision_sum += sum(intersection[row]) / sum(predictions_labels_matrix[row])
    if num_rows == 0:
        return 0#no labels predicted at all will give us 0 precision as precision makes no sense here
    return precision_sum / num_rows

#size of intersection of predicted and actual labels divided by size of real label set for each datapoint tested on
#sum those and divide by number of datapoints
#all datapoints should have at least 1 real label in this data set
#vectorized for speed
def multi_label_recall(real_labels_matrix, predictions_labels_matrix):
    #binary so set intersection is and operator
    intersection = real_labels_matrix & predictions_labels_matrix
    #set union for binary is same as or operator
    #sum(array.T) gets number of 1s in row
    row_wise_recall = sum(intersection.T) / sum(real_labels_matrix.T)
    return sum(row_wise_recall) / real_labels_matrix.shape[0]

#lower is better. Percent incorrectly chosen labels counting assignment and non-assignment equally
def hamming_loss(real_labels_matrix, predictions_labels_matrix):
    return (np.logical_xor(real_labels_matrix, predictions_labels_matrix)).sum()/(real_labels_matrix.shape[0] * real_labels_matrix.shape[1])


#K is what we imported keras backend as

#metric for keras for early stopping
#takes in raw labels from kerass (not yet converted to 0 and 1s)
#NOT the same as accuracy, this is total labels correctly identified divided by union of total labels
#this weights rows with more labels higher, where accruacy does not, but this is still a good metric for early stopping
def raw_multi_label_accuracy(y_true, y_pred):
    positives = K.greater_equal(y_pred, 0.5)
    positives = K.cast(positives, K.floatx())
    new_y_pred = positives #+ ((1-positives)*y_pred)
    intersection = y_true * new_y_pred
    union = 1 -((1-y_true)*(1-new_y_pred))
    accuracy = K.sum(intersection) / K.sum(union)
    return accuracy

# %%
def get_all_metrics(actual_labels, predictions):
    print('Getting evaluation metrics for each label:')
    get_per_label_metrics(actual_labels, predictions)
    print('Getting evaluations for multilabel problem')
    print('Multilabel accuracy: ' + str(multi_label_accuracy(actual_labels, predictions)))
    print('Multilabel precision: ' + str(multi_label_precision(actual_labels, predictions)))
    print('Multilabel recall: ' + str(multi_label_recall(actual_labels, predictions)))
    print("Percent of correctly decided label decisions: " + str(100* (1-hamming_loss(actual_labels, predictions))))

# %%
#for early stopping only after certain number of epochs. wait until delay epochs until early stopping
#not same as patience. Want to not even start looking until delay is reached
class DelayedEarlyStopping(EarlyStopping):
    def __init__(self, monitor, min_delta=0, patience=0, verbose=0, mode='auto', delay = 100):
        super(DelayedEarlyStopping, self).__init__(monitor=monitor, min_delta=min_delta, patience=patience,verbose=verbose, mode=mode)
        self.delay = delay

    def on_epoch_end(self, epoch, logs=None):
        if epoch > self.delay:
            super().on_epoch_end(epoch, logs)

# %%
def nn_output_to_predictions(res):
    label_predictions = []
    for i in range(res.shape[0]):
        pred = [0]*len(genre_dict)
        for j in range(res.shape[1]):
            if res[i][j] >= .5:
                pred[j] = 1
        label_predictions.append(pred)
    return np.array(label_predictions)

# %% [markdown]
# Convolutional Neural Networks

# %%
model_cnn = Sequential()
e = Embedding(num_words_kept, word_vec_len, weights=[embedding_matrix], input_length=max_seq_len, trainable=True)
#e = Embedding(num_words_kept, word_vec_len, input_length=max_seq_len, trainable=True)
model_cnn.add(e)
model_cnn.add(Conv1D(filters=50, kernel_size=2, padding='valid', activation='relu', strides=1))
model_cnn.add(GlobalMaxPooling1D())
model_cnn.add(Dense(256, activation='relu', kernel_regularizer=l2(0.001)))
model_cnn.add(Dropout(.5))
model_cnn.add(Dense(len(genre_dict), activation='sigmoid'))
model_cnn.compile(loss='binary_crossentropy', optimizer='adam', metrics=[raw_multi_label_accuracy])
model_cnn.fit(x_train_seq, y_train, validation_split = .1, callbacks = [DelayedEarlyStopping(monitor = 'val_raw_multi_label_accuracy', patience = 5, delay=25)], epochs=1000, batch_size=100, verbose=2)
# Out:
# WARNING:tensorflow:From /home/matt/.local/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/matt/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/matt/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /home/matt/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Train on 2149 samples, validate on 239 samples
# Epoch 1/1000
#  - 4s - loss: 0.5867 - raw_multi_label_accuracy: 0.1208 - val_loss: 0.4078 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 2/1000
#  - 3s - loss: 0.4124 - raw_multi_label_accuracy: 0.1116 - val_loss: 0.3742 - val_raw_multi_label_accuracy: 0.1695
# Epoch 3/1000
#  - 3s - loss: 0.3837 - raw_multi_label_accuracy: 0.1059 - val_loss: 0.3630 - val_raw_multi_label_accuracy: 0.1695
# Epoch 4/1000
#  - 3s - loss: 0.3694 - raw_multi_label_accuracy: 0.1124 - val_loss: 0.3543 - val_raw_multi_label_accuracy: 0.1697
# Epoch 5/1000
#  - 3s - loss: 0.3590 - raw_multi_label_accuracy: 0.1104 - val_loss: 0.3479 - val_raw_multi_label_accuracy: 0.0549
# Epoch 6/1000
#  - 3s - loss: 0.3516 - raw_multi_label_accuracy: 0.0949 - val_loss: 0.3428 - val_raw_multi_label_accuracy: 0.1686
# Epoch 7/1000
#  - 3s - loss: 0.3445 - raw_multi_label_accuracy: 0.0983 - val_loss: 0.3393 - val_raw_multi_label_accuracy: 0.1695
# Epoch 8/1000
#  - 4s - loss: 0.3398 - raw_multi_label_accuracy: 0.1046 - val_loss: 0.3366 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 9/1000
#  - 4s - loss: 0.3315 - raw_multi_label_accuracy: 0.1212 - val_loss: 0.3346 - val_raw_multi_label_accuracy: 0.0273
# Epoch 10/1000
#  - 4s - loss: 0.3259 - raw_multi_label_accuracy: 0.1277 - val_loss: 0.3325 - val_raw_multi_label_accuracy: 0.1645
# Epoch 11/1000
#  - 4s - loss: 0.3156 - raw_multi_label_accuracy: 0.1515 - val_loss: 0.3331 - val_raw_multi_label_accuracy: 0.0818
# Epoch 12/1000
#  - 4s - loss: 0.3029 - raw_multi_label_accuracy: 0.1569 - val_loss: 0.3345 - val_raw_multi_label_accuracy: 0.0767
# Epoch 13/1000
#  - 4s - loss: 0.2892 - raw_multi_label_accuracy: 0.2071 - val_loss: 0.3391 - val_raw_multi_label_accuracy: 0.0667
# Epoch 14/1000
#  - 5s - loss: 0.2765 - raw_multi_label_accuracy: 0.2416 - val_loss: 0.3435 - val_raw_multi_label_accuracy: 0.1018
# Epoch 15/1000
#  - 4s - loss: 0.2605 - raw_multi_label_accuracy: 0.2994 - val_loss: 0.3435 - val_raw_multi_label_accuracy: 0.1078
# Epoch 16/1000
#  - 5s - loss: 0.2451 - raw_multi_label_accuracy: 0.3639 - val_loss: 0.3558 - val_raw_multi_label_accuracy: 0.1147
# Epoch 17/1000
#  - 5s - loss: 0.2316 - raw_multi_label_accuracy: 0.4067 - val_loss: 0.3632 - val_raw_multi_label_accuracy: 0.1329
# Epoch 18/1000
#  - 5s - loss: 0.2216 - raw_multi_label_accuracy: 0.4432 - val_loss: 0.3711 - val_raw_multi_label_accuracy: 0.1144
# Epoch 19/1000
#  - 5s - loss: 0.2118 - raw_multi_label_accuracy: 0.4681 - val_loss: 0.3774 - val_raw_multi_label_accuracy: 0.1410
# Epoch 20/1000
#  - 4s - loss: 0.2042 - raw_multi_label_accuracy: 0.4806 - val_loss: 0.3836 - val_raw_multi_label_accuracy: 0.1516
# Epoch 21/1000
#  - 4s - loss: 0.1966 - raw_multi_label_accuracy: 0.4989 - val_loss: 0.3936 - val_raw_multi_label_accuracy: 0.1507
# Epoch 22/1000
#  - 4s - loss: 0.1909 - raw_multi_label_accuracy: 0.5096 - val_loss: 0.4049 - val_raw_multi_label_accuracy: 0.1470
# Epoch 23/1000
#  - 4s - loss: 0.1842 - raw_multi_label_accuracy: 0.5334 - val_loss: 0.4010 - val_raw_multi_label_accuracy: 0.1512
# Epoch 24/1000
#  - 4s - loss: 0.1788 - raw_multi_label_accuracy: 0.5453 - val_loss: 0.4094 - val_raw_multi_label_accuracy: 0.1535
# Epoch 25/1000
#  - 4s - loss: 0.1725 - raw_multi_label_accuracy: 0.5646 - val_loss: 0.4116 - val_raw_multi_label_accuracy: 0.1513
# Epoch 26/1000
#  - 4s - loss: 0.1686 - raw_multi_label_accuracy: 0.5694 - val_loss: 0.4174 - val_raw_multi_label_accuracy: 0.1524
# Epoch 27/1000
#  - 4s - loss: 0.1622 - raw_multi_label_accuracy: 0.5846 - val_loss: 0.4235 - val_raw_multi_label_accuracy: 0.1564
# Epoch 28/1000
#  - 4s - loss: 0.1561 - raw_multi_label_accuracy: 0.6132 - val_loss: 0.4290 - val_raw_multi_label_accuracy: 0.1639
# Epoch 29/1000
#  - 4s - loss: 0.1496 - raw_multi_label_accuracy: 0.6302 - val_loss: 0.4393 - val_raw_multi_label_accuracy: 0.1644
# Epoch 30/1000
#  - 4s - loss: 0.1451 - raw_multi_label_accuracy: 0.6314 - val_loss: 0.4405 - val_raw_multi_label_accuracy: 0.1681
# Epoch 31/1000
#  - 4s - loss: 0.1403 - raw_multi_label_accuracy: 0.6538 - val_loss: 0.4548 - val_raw_multi_label_accuracy: 0.1655
# Epoch 32/1000
#  - 3s - loss: 0.1362 - raw_multi_label_accuracy: 0.6614 - val_loss: 0.4607 - val_raw_multi_label_accuracy: 0.1648
# Epoch 33/1000
#  - 3s - loss: 0.1310 - raw_multi_label_accuracy: 0.6797 - val_loss: 0.4675 - val_raw_multi_label_accuracy: 0.1722
# Epoch 34/1000
#  - 4s - loss: 0.1275 - raw_multi_label_accuracy: 0.6892 - val_loss: 0.4719 - val_raw_multi_label_accuracy: 0.1728
# Epoch 35/1000
#  - 3s - loss: 0.1250 - raw_multi_label_accuracy: 0.6890 - val_loss: 0.4807 - val_raw_multi_label_accuracy: 0.1723
# Epoch 36/1000
#  - 3s - loss: 0.1201 - raw_multi_label_accuracy: 0.7062 - val_loss: 0.4851 - val_raw_multi_label_accuracy: 0.1675
# Epoch 37/1000
#  - 3s - loss: 0.1166 - raw_multi_label_accuracy: 0.7158 - val_loss: 0.4952 - val_raw_multi_label_accuracy: 0.1730
# Epoch 38/1000
#  - 3s - loss: 0.1138 - raw_multi_label_accuracy: 0.7292 - val_loss: 0.4960 - val_raw_multi_label_accuracy: 0.1674
# Epoch 39/1000
#  - 3s - loss: 0.1115 - raw_multi_label_accuracy: 0.7334 - val_loss: 0.5081 - val_raw_multi_label_accuracy: 0.1704
# Epoch 40/1000
#  - 3s - loss: 0.1085 - raw_multi_label_accuracy: 0.7403 - val_loss: 0.5147 - val_raw_multi_label_accuracy: 0.1614
# Epoch 41/1000
#  - 3s - loss: 0.1072 - raw_multi_label_accuracy: 0.7406 - val_loss: 0.5147 - val_raw_multi_label_accuracy: 0.1654
# Epoch 42/1000
#  - 3s - loss: 0.1042 - raw_multi_label_accuracy: 0.7536 - val_loss: 0.5236 - val_raw_multi_label_accuracy: 0.1675

# %%
predictions = nn_output_to_predictions(model_cnn.predict(x_test_seq))

# %%
get_all_metrics(y_test, predictions)
# Out:
# Getting evaluation metrics for each label:
# Accuruacy for War: 0.964824120603015
# Precision for War: 0.0
# Recall for War: 0.0
#
# Accuruacy for Family: 0.8994974874371859
# Precision for Family: 0.1111111111111111
# Recall for Family: 0.043478260869565216
#
# Accuruacy for Science Fiction: 0.8793969849246231
# Precision for Science Fiction: 0.14285714285714285
# Recall for Science Fiction: 0.03225806451612903
#
# Accuruacy for Thriller: 0.7135678391959799
# Precision for Thriller: 0.484375
# Recall for Thriller: 0.1834319526627219
#
# Accuruacy for Horror: 0.897822445561139
# Precision for Horror: 0.2222222222222222
# Recall for Horror: 0.03571428571428571
#
# Accuruacy for Romance: 0.7336683417085427
# Precision for Romance: 0.17567567567567569
# Recall for Romance: 0.11711711711711711
#
# Accuruacy for Drama: 0.5159128978224455
# Precision for Drama: 0.5635593220338984
# Recall for Drama: 0.4169278996865204
#
# Accuruacy for Foreign: 0.9882747068676717
# Precision for Foreign: 0.0
# Recall for Foreign: 0.0
#
# Accuruacy for Documentary: 0.9731993299832495
# Precision for Documentary: 0.0
# Recall for Documentary: 0.0
#
# Accuruacy for Fantasy: 0.916247906197655
# Precision for Fantasy: 0.0
# Recall for Fantasy: 0.0
#
# Accuruacy for Western: 0.983249581239531
# Precision for Western: 0.0
# Recall for Western: 0.0
#
# Accuruacy for History: 0.9614740368509213
# Precision for History: 0.0
# Recall for History: 0.0
#
# Accuruacy for Comedy: 0.5829145728643216
# Precision for Comedy: 0.42731277533039647
# Recall for Comedy: 0.44907407407407407
#
# Accuruacy for Action: 0.7219430485762144
# Precision for Action: 0.4594594594594595
# Recall for Action: 0.3248407643312102
#
# Accuruacy for Adventure: 0.8073701842546064
# Precision for Adventure: 0.3076923076923077
# Recall for Adventure: 0.16842105263157894
#
# Accuruacy for Animation: 0.9514237855946399
# Precision for Animation: 0.25
# Recall for Animation: 0.037037037037037035
#
# Accuruacy for Crime: 0.8140703517587939
# Precision for Crime: 0.19230769230769232
# Recall for Crime: 0.05263157894736842
#
# Accuruacy for Music: 0.9748743718592965
# /home/matt/.local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Precision for Music: 0.0
# Recall for Music: 0.0
#
# Accuruacy for TV Movie: 1.0
# Precision for TV Movie: 0.0
# Recall for TV Movie: 0.0
#
# Accuruacy for Mystery: 0.931323283082077
# Precision for Mystery: 0.0
# Recall for Mystery: 0.0
#
# Getting evaluations for multilabel problem
# Multilabel accuracy: 0.211316503150674
# Multilabel precision: 0.44587458745874603
# Multilabel recall: 0.2584190795246071
# Percent of correctly decided label decisions: 86.05527638190955
# /home/matt/.local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)

# %% [markdown]
# CNN but with multiple filter sizes so we don't just filter on group of words at a time

# %%
model_input = Input(shape=(max_seq_len,), dtype='int32')
e = Embedding(num_words_kept, word_vec_len, weights=[embedding_matrix], input_length=max_seq_len, trainable=True)(model_input)
two_word_filter = Conv1D(filters=100, kernel_size=2, padding='valid', activation='relu', strides=1)(e)
two_word_filter = GlobalMaxPooling1D()(two_word_filter)
three_word_filter = Conv1D(filters=100, kernel_size=3, padding='valid', activation='relu', strides=1)(e)
three_word_filter = GlobalMaxPooling1D()(three_word_filter)
four_word_filter = Conv1D(filters=100, kernel_size=4, padding='valid', activation='relu', strides=1)(e)
four_word_filter = GlobalMaxPooling1D()(four_word_filter)
merged = concatenate([two_word_filter, three_word_filter, four_word_filter], axis=1)

merged = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(merged)
merged = Dropout(0.5)(merged)
merged = Dense(len(genre_dict))(merged)
output = Activation('sigmoid')(merged)
model = Model(inputs=[model_input], outputs=[output])
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[raw_multi_label_accuracy])

# %%
model.fit(x_train_seq, y_train, validation_split = .1, callbacks = [DelayedEarlyStopping(monitor = 'val_raw_multi_label_accuracy', patience = 5, delay=25)], epochs=1000, batch_size=100, verbose=2)
# Out:
# Train on 2149 samples, validate on 239 samples
# Epoch 1/1000
#  - 16s - loss: 2.6254 - raw_multi_label_accuracy: 0.1178 - val_loss: 1.8901 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 2/1000
#  - 10s - loss: 1.4977 - raw_multi_label_accuracy: 0.1251 - val_loss: 1.0967 - val_raw_multi_label_accuracy: 0.0285
# Epoch 3/1000
#  - 12s - loss: 0.8933 - raw_multi_label_accuracy: 0.1043 - val_loss: 0.6837 - val_raw_multi_label_accuracy: 0.1695
# Epoch 4/1000
#  - 11s - loss: 0.5889 - raw_multi_label_accuracy: 0.1035 - val_loss: 0.4858 - val_raw_multi_label_accuracy: 0.1695
# Epoch 5/1000
#  - 6s - loss: 0.4436 - raw_multi_label_accuracy: 0.1128 - val_loss: 0.3939 - val_raw_multi_label_accuracy: 0.1695
# Epoch 6/1000
#  - 5s - loss: 0.3774 - raw_multi_label_accuracy: 0.1055 - val_loss: 0.3526 - val_raw_multi_label_accuracy: 0.1695
# Epoch 7/1000
#  - 4s - loss: 0.3487 - raw_multi_label_accuracy: 0.0961 - val_loss: 0.3349 - val_raw_multi_label_accuracy: 0.1695
# Epoch 8/1000
#  - 4s - loss: 0.3342 - raw_multi_label_accuracy: 0.1229 - val_loss: 0.3279 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 9/1000
#  - 4s - loss: 0.3276 - raw_multi_label_accuracy: 0.1032 - val_loss: 0.3237 - val_raw_multi_label_accuracy: 0.0016
# Epoch 10/1000
#  - 4s - loss: 0.3239 - raw_multi_label_accuracy: 0.1045 - val_loss: 0.3207 - val_raw_multi_label_accuracy: 0.1695
# Epoch 11/1000
#  - 4s - loss: 0.3220 - raw_multi_label_accuracy: 0.1038 - val_loss: 0.3193 - val_raw_multi_label_accuracy: 0.1700
# Epoch 12/1000
#  - 4s - loss: 0.3192 - raw_multi_label_accuracy: 0.1099 - val_loss: 0.3189 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 13/1000
#  - 5s - loss: 0.3157 - raw_multi_label_accuracy: 0.1100 - val_loss: 0.3191 - val_raw_multi_label_accuracy: 0.1695
# Epoch 14/1000
#  - 5s - loss: 0.3121 - raw_multi_label_accuracy: 0.1202 - val_loss: 0.3215 - val_raw_multi_label_accuracy: 0.1035
# Epoch 15/1000
#  - 4s - loss: 0.3069 - raw_multi_label_accuracy: 0.1244 - val_loss: 0.3226 - val_raw_multi_label_accuracy: 0.1695
# Epoch 16/1000
#  - 8s - loss: 0.3014 - raw_multi_label_accuracy: 0.1429 - val_loss: 0.3210 - val_raw_multi_label_accuracy: 0.1599
# Epoch 17/1000
#  - 10s - loss: 0.2962 - raw_multi_label_accuracy: 0.1383 - val_loss: 0.3222 - val_raw_multi_label_accuracy: 0.0933
# Epoch 18/1000
#  - 9s - loss: 0.2924 - raw_multi_label_accuracy: 0.1348 - val_loss: 0.3230 - val_raw_multi_label_accuracy: 0.1395
# Epoch 19/1000
#  - 9s - loss: 0.2877 - raw_multi_label_accuracy: 0.1491 - val_loss: 0.3211 - val_raw_multi_label_accuracy: 0.1133
# Epoch 20/1000
#  - 9s - loss: 0.2820 - raw_multi_label_accuracy: 0.1649 - val_loss: 0.3227 - val_raw_multi_label_accuracy: 0.1565
# Epoch 21/1000
#  - 9s - loss: 0.2767 - raw_multi_label_accuracy: 0.1844 - val_loss: 0.3218 - val_raw_multi_label_accuracy: 0.1424
# Epoch 22/1000
#  - 9s - loss: 0.2718 - raw_multi_label_accuracy: 0.2018 - val_loss: 0.3258 - val_raw_multi_label_accuracy: 0.1491
# Epoch 23/1000
#  - 9s - loss: 0.2668 - raw_multi_label_accuracy: 0.2081 - val_loss: 0.3240 - val_raw_multi_label_accuracy: 0.1256
# Epoch 24/1000
#  - 9s - loss: 0.2618 - raw_multi_label_accuracy: 0.2183 - val_loss: 0.3295 - val_raw_multi_label_accuracy: 0.1353
# Epoch 25/1000
#  - 9s - loss: 0.2576 - raw_multi_label_accuracy: 0.2290 - val_loss: 0.3283 - val_raw_multi_label_accuracy: 0.1397
# Epoch 26/1000
#  - 9s - loss: 0.2530 - raw_multi_label_accuracy: 0.2429 - val_loss: 0.3334 - val_raw_multi_label_accuracy: 0.1456
# Epoch 27/1000
#  - 9s - loss: 0.2489 - raw_multi_label_accuracy: 0.2608 - val_loss: 0.3326 - val_raw_multi_label_accuracy: 0.1441
# Epoch 28/1000
#  - 9s - loss: 0.2448 - raw_multi_label_accuracy: 0.2896 - val_loss: 0.3341 - val_raw_multi_label_accuracy: 0.1580
# Epoch 29/1000
#  - 10s - loss: 0.2373 - raw_multi_label_accuracy: 0.3286 - val_loss: 0.3437 - val_raw_multi_label_accuracy: 0.1724
# Epoch 30/1000
#  - 10s - loss: 0.2278 - raw_multi_label_accuracy: 0.3609 - val_loss: 0.3493 - val_raw_multi_label_accuracy: 0.1812
# Epoch 31/1000
#  - 9s - loss: 0.2200 - raw_multi_label_accuracy: 0.4007 - val_loss: 0.3527 - val_raw_multi_label_accuracy: 0.1736
# Epoch 32/1000
#  - 9s - loss: 0.2127 - raw_multi_label_accuracy: 0.4231 - val_loss: 0.3538 - val_raw_multi_label_accuracy: 0.1720
# Epoch 33/1000
#  - 9s - loss: 0.2059 - raw_multi_label_accuracy: 0.4444 - val_loss: 0.3557 - val_raw_multi_label_accuracy: 0.1884
# Epoch 34/1000
#  - 9s - loss: 0.2007 - raw_multi_label_accuracy: 0.4605 - val_loss: 0.3699 - val_raw_multi_label_accuracy: 0.1875
# Epoch 35/1000
#  - 9s - loss: 0.1977 - raw_multi_label_accuracy: 0.4632 - val_loss: 0.3661 - val_raw_multi_label_accuracy: 0.1896
# Epoch 36/1000
#  - 9s - loss: 0.1940 - raw_multi_label_accuracy: 0.4753 - val_loss: 0.3761 - val_raw_multi_label_accuracy: 0.1826
# Epoch 37/1000
#  - 9s - loss: 0.1883 - raw_multi_label_accuracy: 0.4880 - val_loss: 0.3835 - val_raw_multi_label_accuracy: 0.1920
# Epoch 38/1000
#  - 9s - loss: 0.1872 - raw_multi_label_accuracy: 0.4946 - val_loss: 0.3990 - val_raw_multi_label_accuracy: 0.1930
# Epoch 39/1000
#  - 11s - loss: 0.1847 - raw_multi_label_accuracy: 0.5063 - val_loss: 0.3918 - val_raw_multi_label_accuracy: 0.1927
# Epoch 40/1000
#  - 11s - loss: 0.1822 - raw_multi_label_accuracy: 0.5038 - val_loss: 0.3997 - val_raw_multi_label_accuracy: 0.1877
# Epoch 41/1000
#  - 12s - loss: 0.1800 - raw_multi_label_accuracy: 0.5115 - val_loss: 0.3999 - val_raw_multi_label_accuracy: 0.1806
# Epoch 42/1000
#  - 9s - loss: 0.1760 - raw_multi_label_accuracy: 0.5186 - val_loss: 0.4086 - val_raw_multi_label_accuracy: 0.1951
# Epoch 43/1000
#  - 9s - loss: 0.1743 - raw_multi_label_accuracy: 0.5238 - val_loss: 0.4073 - val_raw_multi_label_accuracy: 0.1988
# Epoch 44/1000
#  - 9s - loss: 0.1728 - raw_multi_label_accuracy: 0.5209 - val_loss: 0.4110 - val_raw_multi_label_accuracy: 0.1923
# Epoch 45/1000
#  - 9s - loss: 0.1722 - raw_multi_label_accuracy: 0.5276 - val_loss: 0.4099 - val_raw_multi_label_accuracy: 0.1936
# Epoch 46/1000
#  - 9s - loss: 0.1696 - raw_multi_label_accuracy: 0.5342 - val_loss: 0.4137 - val_raw_multi_label_accuracy: 0.1868
# Epoch 47/1000
#  - 9s - loss: 0.1659 - raw_multi_label_accuracy: 0.5459 - val_loss: 0.4281 - val_raw_multi_label_accuracy: 0.1856
# Epoch 48/1000
#  - 9s - loss: 0.1671 - raw_multi_label_accuracy: 0.5399 - val_loss: 0.4217 - val_raw_multi_label_accuracy: 0.1943

# %%
predictions = nn_output_to_predictions(model.predict(x_test_seq))

# %%
get_all_metrics(y_test, predictions)
# Out:
# Getting evaluation metrics for each label:
# Accuruacy for War: 0.964824120603015
# Precision for War: 0.0
# Recall for War: 0.0
#
# Accuruacy for Family: 0.9212730318257957
# Precision for Family: 0.0
# Recall for Family: 0.0
#
# Accuruacy for Science Fiction: 0.8944723618090452
# Precision for Science Fiction: 0.4
# Recall for Science Fiction: 0.03225806451612903
#
# Accuruacy for Thriller: 0.6331658291457286
# Precision for Thriller: 0.3310810810810811
# Recall for Thriller: 0.28994082840236685
#
# Accuruacy for Horror: 0.9061976549413735
# Precision for Horror: 0.0
# Recall for Horror: 0.0
#
# Accuruacy for Romance: 0.7805695142378559
# Precision for Romance: 0.35294117647058826
# Recall for Romance: 0.21621621621621623
#
# Accuruacy for Drama: 0.5963149078726968
# Precision for Drama: 0.5984848484848485
# Recall for Drama: 0.7429467084639498
#
# Accuruacy for Foreign: 0.9882747068676717
# Precision for Foreign: 0.0
# Recall for Foreign: 0.0
#
# Accuruacy for Documentary: 0.9731993299832495
# Precision for Documentary: 0.0
# Recall for Documentary: 0.0
#
# Accuruacy for Fantasy: 0.9229480737018425
# Precision for Fantasy: 0.0
# Recall for Fantasy: 0.0
#
# Accuruacy for Western: 0.983249581239531
# Precision for Western: 0.0
# Recall for Western: 0.0
#
# Accuruacy for History: 0.9614740368509213
# Precision for History: 0.0
# Recall for History: 0.0
#
# Accuruacy for Comedy: 0.626465661641541
# Precision for Comedy: 0.47107438016528924
# Recall for Comedy: 0.2638888888888889
#
# Accuruacy for Action: 0.7018425460636516
# Precision for Action: 0.34782608695652173
# Recall for Action: 0.15286624203821655
#
# Accuruacy for Adventure: 0.8341708542713567
# Precision for Adventure: 0.25
# Recall for Adventure: 0.021052631578947368
#
# Accuruacy for Animation: 0.9547738693467337
# Precision for Animation: 0.0
# Recall for Animation: 0.0
#
# Accuruacy for Crime: 0.8224455611390284
# Precision for Crime: 0.28
# Recall for Crime: 0.07368421052631578
#
# Accuruacy for Music: 0.9748743718592965
# Precision for Music: 0.0
# Recall for Music: 0.0
#
# Accuruacy for TV Movie: 1.0
# Precision for TV Movie: 0.0
# Recall for TV Movie: 0.0
#
# Accuruacy for Mystery: 0.9128978224455612
# Precision for Mystery: 0.125
# Recall for Mystery: 0.05
#
# Getting evaluations for multilabel problem
# Multilabel accuracy: 0.24907473877323108
# Multilabel precision: 0.5035959974984366
# Multilabel recall: 0.2948392757437984
# Percent of correctly decided label decisions: 86.76716917922948

# %% [markdown]
# Regular Neural Network

# %%
normal_nn = Sequential()
e = Embedding(num_words_kept, word_vec_len, weights=[embedding_matrix], input_length=max_seq_len, trainable=True)
normal_nn.add(e)
normal_nn.add(Flatten())
normal_nn.add(Dense(256, activation='relu'))
normal_nn.add(Dense(len(genre_dict), activation='sigmoid'))
normal_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=[raw_multi_label_accuracy])
normal_nn.fit(x_train_seq, y_train, validation_split = .1, callbacks = [DelayedEarlyStopping(monitor = 'val_raw_multi_label_accuracy', patience = 5, delay=25)], epochs=1000, batch_size=100, verbose=2)
# Out:
# Train on 2149 samples, validate on 239 samples
# Epoch 1/1000
#  - 6s - loss: 0.4074 - raw_multi_label_accuracy: 0.1360 - val_loss: 0.3456 - val_raw_multi_label_accuracy: 0.0478
# Epoch 2/1000
#  - 5s - loss: 0.3263 - raw_multi_label_accuracy: 0.0988 - val_loss: 0.3300 - val_raw_multi_label_accuracy: 0.1391
# Epoch 3/1000
#  - 4s - loss: 0.3098 - raw_multi_label_accuracy: 0.1267 - val_loss: 0.3239 - val_raw_multi_label_accuracy: 0.1466
# Epoch 4/1000
#  - 4s - loss: 0.2985 - raw_multi_label_accuracy: 0.1396 - val_loss: 0.3228 - val_raw_multi_label_accuracy: 0.1320
# Epoch 5/1000
#  - 4s - loss: 0.2900 - raw_multi_label_accuracy: 0.1454 - val_loss: 0.3227 - val_raw_multi_label_accuracy: 0.1270
# Epoch 6/1000
#  - 4s - loss: 0.2803 - raw_multi_label_accuracy: 0.1693 - val_loss: 0.3248 - val_raw_multi_label_accuracy: 0.1258
# Epoch 7/1000
#  - 4s - loss: 0.2648 - raw_multi_label_accuracy: 0.2195 - val_loss: 0.3215 - val_raw_multi_label_accuracy: 0.1186
# Epoch 8/1000
#  - 4s - loss: 0.2427 - raw_multi_label_accuracy: 0.2857 - val_loss: 0.3206 - val_raw_multi_label_accuracy: 0.1526
# Epoch 9/1000
#  - 3s - loss: 0.2176 - raw_multi_label_accuracy: 0.3787 - val_loss: 0.3165 - val_raw_multi_label_accuracy: 0.1395
# Epoch 10/1000
#  - 4s - loss: 0.1906 - raw_multi_label_accuracy: 0.4770 - val_loss: 0.3193 - val_raw_multi_label_accuracy: 0.1503
# Epoch 11/1000
#  - 5s - loss: 0.1658 - raw_multi_label_accuracy: 0.5670 - val_loss: 0.3232 - val_raw_multi_label_accuracy: 0.1500
# Epoch 12/1000
#  - 4s - loss: 0.1441 - raw_multi_label_accuracy: 0.6319 - val_loss: 0.3261 - val_raw_multi_label_accuracy: 0.1649
# Epoch 13/1000
#  - 4s - loss: 0.1251 - raw_multi_label_accuracy: 0.6923 - val_loss: 0.3411 - val_raw_multi_label_accuracy: 0.1720
# Epoch 14/1000
#  - 4s - loss: 0.1084 - raw_multi_label_accuracy: 0.7414 - val_loss: 0.3477 - val_raw_multi_label_accuracy: 0.1704
# Epoch 15/1000
#  - 3s - loss: 0.0927 - raw_multi_label_accuracy: 0.7878 - val_loss: 0.3536 - val_raw_multi_label_accuracy: 0.1700
# Epoch 16/1000
#  - 4s - loss: 0.0790 - raw_multi_label_accuracy: 0.8273 - val_loss: 0.3700 - val_raw_multi_label_accuracy: 0.1680
# Epoch 17/1000
#  - 4s - loss: 0.0677 - raw_multi_label_accuracy: 0.8643 - val_loss: 0.3823 - val_raw_multi_label_accuracy: 0.1778
# Epoch 18/1000
#  - 4s - loss: 0.0576 - raw_multi_label_accuracy: 0.8903 - val_loss: 0.3952 - val_raw_multi_label_accuracy: 0.1837
# Epoch 19/1000
#  - 4s - loss: 0.0489 - raw_multi_label_accuracy: 0.9153 - val_loss: 0.4052 - val_raw_multi_label_accuracy: 0.1795
# Epoch 20/1000
#  - 4s - loss: 0.0414 - raw_multi_label_accuracy: 0.9341 - val_loss: 0.4141 - val_raw_multi_label_accuracy: 0.1794
# Epoch 21/1000
#  - 5s - loss: 0.0355 - raw_multi_label_accuracy: 0.9457 - val_loss: 0.4364 - val_raw_multi_label_accuracy: 0.1808
# Epoch 22/1000
#  - 4s - loss: 0.0300 - raw_multi_label_accuracy: 0.9609 - val_loss: 0.4517 - val_raw_multi_label_accuracy: 0.1640
# Epoch 23/1000
#  - 4s - loss: 0.0257 - raw_multi_label_accuracy: 0.9679 - val_loss: 0.4589 - val_raw_multi_label_accuracy: 0.1765
# Epoch 24/1000
#  - 4s - loss: 0.0219 - raw_multi_label_accuracy: 0.9797 - val_loss: 0.4727 - val_raw_multi_label_accuracy: 0.1709
# Epoch 25/1000
#  - 4s - loss: 0.0188 - raw_multi_label_accuracy: 0.9827 - val_loss: 0.4956 - val_raw_multi_label_accuracy: 0.1647
# Epoch 26/1000
#  - 4s - loss: 0.0162 - raw_multi_label_accuracy: 0.9864 - val_loss: 0.5047 - val_raw_multi_label_accuracy: 0.1649
# Epoch 27/1000
#  - 4s - loss: 0.0140 - raw_multi_label_accuracy: 0.9903 - val_loss: 0.5128 - val_raw_multi_label_accuracy: 0.1764
# Epoch 28/1000
#  - 4s - loss: 0.0122 - raw_multi_label_accuracy: 0.9920 - val_loss: 0.5219 - val_raw_multi_label_accuracy: 0.1785
# Epoch 29/1000
#  - 4s - loss: 0.0107 - raw_multi_label_accuracy: 0.9939 - val_loss: 0.5326 - val_raw_multi_label_accuracy: 0.1879
# Epoch 30/1000
#  - 4s - loss: 0.0093 - raw_multi_label_accuracy: 0.9952 - val_loss: 0.5456 - val_raw_multi_label_accuracy: 0.1750
# Epoch 31/1000
#  - 3s - loss: 0.0082 - raw_multi_label_accuracy: 0.9962 - val_loss: 0.5658 - val_raw_multi_label_accuracy: 0.1647
# Epoch 32/1000
#  - 4s - loss: 0.0073 - raw_multi_label_accuracy: 0.9972 - val_loss: 0.5698 - val_raw_multi_label_accuracy: 0.1756
# Epoch 33/1000
#  - 4s - loss: 0.0065 - raw_multi_label_accuracy: 0.9974 - val_loss: 0.5819 - val_raw_multi_label_accuracy: 0.1729
# Epoch 34/1000
#  - 3s - loss: 0.0058 - raw_multi_label_accuracy: 0.9978 - val_loss: 0.5853 - val_raw_multi_label_accuracy: 0.1809

# %%
predictions = nn_output_to_predictions(normal_nn.predict(x_test_seq))

# %%
get_all_metrics(y_test, predictions)
# Out:
# Getting evaluation metrics for each label:
# Accuruacy for War: 0.9631490787269682
# Precision for War: 0.0
# Recall for War: 0.0
#
# Accuruacy for Family: 0.9212730318257957
# Precision for Family: 0.0
# Recall for Family: 0.0
#
# Accuruacy for Science Fiction: 0.9011725293132329
# Precision for Science Fiction: 0.8
# Recall for Science Fiction: 0.06451612903225806
#
# Accuruacy for Thriller: 0.7236180904522613
# Precision for Thriller: 0.55
# Recall for Thriller: 0.1301775147928994
#
# Accuruacy for Horror: 0.9061976549413735
# Precision for Horror: 0.5
# Recall for Horror: 0.017857142857142856
#
# Accuruacy for Romance: 0.8257956448911222
# Precision for Romance: 0.6
# Recall for Romance: 0.1891891891891892
#
# Accuruacy for Drama: 0.6130653266331658
# Precision for Drama: 0.6301775147928994
# Recall for Drama: 0.6677115987460815
#
# Accuruacy for Foreign: 0.9882747068676717
# Precision for Foreign: 0.0
# Recall for Foreign: 0.0
#
# Accuruacy for Documentary: 0.9731993299832495
# Precision for Documentary: 0.0
# Recall for Documentary: 0.0
#
# Accuruacy for Fantasy: 0.9195979899497487
# Precision for Fantasy: 0.0
# Recall for Fantasy: 0.0
#
# Accuruacy for Western: 0.983249581239531
# Precision for Western: 0.0
# Recall for Western: 0.0
#
# Accuruacy for History: 0.9614740368509213
# Precision for History: 0.0
# Recall for History: 0.0
#
# Accuruacy for Comedy: 0.644891122278057
# Precision for Comedy: 0.5208333333333334
# Recall for Comedy: 0.23148148148148148
#
# Accuruacy for Action: 0.7202680067001676
# Precision for Action: 0.3958333333333333
# Recall for Action: 0.12101910828025478
#
# Accuruacy for Adventure: 0.830820770519263
# Precision for Adventure: 0.25
# Recall for Adventure: 0.031578947368421054
#
# Accuruacy for Animation: 0.9547738693467337
# Precision for Animation: 0.0
# Recall for Animation: 0.0
#
# Accuruacy for Crime: 0.8425460636515912
# Precision for Crime: 0.5384615384615384
# Recall for Crime: 0.07368421052631578
#
# Accuruacy for Music: 0.9748743718592965
# Precision for Music: 0.0
# Recall for Music: 0.0
#
# Accuruacy for TV Movie: 1.0
# Precision for TV Movie: 0.0
# Recall for TV Movie: 0.0
#
# Accuruacy for Mystery: 0.931323283082077
# Precision for Mystery: 0.0
# Recall for Mystery: 0.0
#
# Getting evaluations for multilabel problem
# Multilabel accuracy: 0.22847172369785437
# Multilabel precision: 0.5696033562166284
# Multilabel recall: 0.25832735104091886
# Percent of correctly decided label decisions: 87.89782244556113

# %% [markdown]
# LSTM

# %%
lstm_model = Sequential()
e = Embedding(num_words_kept, word_vec_len, weights=[embedding_matrix], input_length=max_seq_len, trainable=True)
lstm_model.add(e)
lstm_model.add(LSTM(100, dropout=0.25, recurrent_dropout=0.25))
lstm_model.add(Dense(256, activation='relu'))
lstm_model.add(Dense(len(genre_dict), activation='sigmoid'))
lstm_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[raw_multi_label_accuracy])
lstm_model.fit(x_train_seq, y_train, validation_split = .1, callbacks = [DelayedEarlyStopping(monitor = 'val_raw_multi_label_accuracy', patience = 5, delay=25)], epochs=1000, batch_size=100, verbose=2)
# Out:
# Train on 2149 samples, validate on 239 samples
# Epoch 1/1000
#  - 24s - loss: 0.5007 - raw_multi_label_accuracy: 0.0897 - val_loss: 0.3298 - val_raw_multi_label_accuracy: 0.1695
# Epoch 2/1000
#  - 20s - loss: 0.3175 - raw_multi_label_accuracy: 0.1077 - val_loss: 0.3151 - val_raw_multi_label_accuracy: 0.1695
# Epoch 3/1000
#  - 21s - loss: 0.3131 - raw_multi_label_accuracy: 0.1282 - val_loss: 0.3147 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 4/1000
#  - 22s - loss: 0.3127 - raw_multi_label_accuracy: 0.0879 - val_loss: 0.3156 - val_raw_multi_label_accuracy: 0.0690
# Epoch 5/1000
#  - 21s - loss: 0.3120 - raw_multi_label_accuracy: 0.1096 - val_loss: 0.3149 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 6/1000
#  - 19s - loss: 0.3118 - raw_multi_label_accuracy: 0.1047 - val_loss: 0.3150 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 7/1000
#  - 20s - loss: 0.3119 - raw_multi_label_accuracy: 0.0710 - val_loss: 0.3152 - val_raw_multi_label_accuracy: 0.1695
# Epoch 8/1000
#  - 19s - loss: 0.3119 - raw_multi_label_accuracy: 0.1221 - val_loss: 0.3142 - val_raw_multi_label_accuracy: 0.1695
# Epoch 9/1000
#  - 19s - loss: 0.3116 - raw_multi_label_accuracy: 0.1239 - val_loss: 0.3145 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 10/1000
#  - 19s - loss: 0.3111 - raw_multi_label_accuracy: 0.0855 - val_loss: 0.3136 - val_raw_multi_label_accuracy: 0.1695
# Epoch 11/1000
#  - 20s - loss: 0.3098 - raw_multi_label_accuracy: 0.1475 - val_loss: 0.3143 - val_raw_multi_label_accuracy: 0.0384
# Epoch 12/1000
#  - 20s - loss: 0.3091 - raw_multi_label_accuracy: 0.1033 - val_loss: 0.3140 - val_raw_multi_label_accuracy: 0.0160
# Epoch 13/1000
#  - 20s - loss: 0.3085 - raw_multi_label_accuracy: 0.0892 - val_loss: 0.3141 - val_raw_multi_label_accuracy: 0.0319
# Epoch 14/1000
#  - 19s - loss: 0.3059 - raw_multi_label_accuracy: 0.1096 - val_loss: 0.3154 - val_raw_multi_label_accuracy: 0.0129
# Epoch 15/1000
#  - 20s - loss: 0.3026 - raw_multi_label_accuracy: 0.0957 - val_loss: 0.3153 - val_raw_multi_label_accuracy: 0.1695
# Epoch 16/1000
#  - 20s - loss: 0.2944 - raw_multi_label_accuracy: 0.1312 - val_loss: 0.3156 - val_raw_multi_label_accuracy: 0.1599
# Epoch 17/1000
#  - 20s - loss: 0.2815 - raw_multi_label_accuracy: 0.1450 - val_loss: 0.3130 - val_raw_multi_label_accuracy: 0.1234
# Epoch 18/1000
#  - 20s - loss: 0.2635 - raw_multi_label_accuracy: 0.2174 - val_loss: 0.3222 - val_raw_multi_label_accuracy: 0.1192
# Epoch 19/1000
#  - 19s - loss: 0.2495 - raw_multi_label_accuracy: 0.2607 - val_loss: 0.3267 - val_raw_multi_label_accuracy: 0.1256
# Epoch 20/1000
#  - 19s - loss: 0.2361 - raw_multi_label_accuracy: 0.3138 - val_loss: 0.3262 - val_raw_multi_label_accuracy: 0.1475
# Epoch 21/1000
#  - 20s - loss: 0.2231 - raw_multi_label_accuracy: 0.3661 - val_loss: 0.3306 - val_raw_multi_label_accuracy: 0.1491
# Epoch 22/1000
#  - 19s - loss: 0.2129 - raw_multi_label_accuracy: 0.4032 - val_loss: 0.3364 - val_raw_multi_label_accuracy: 0.1663
# Epoch 23/1000
#  - 20s - loss: 0.2044 - raw_multi_label_accuracy: 0.4252 - val_loss: 0.3448 - val_raw_multi_label_accuracy: 0.1806
# Epoch 24/1000
#  - 20s - loss: 0.1967 - raw_multi_label_accuracy: 0.4527 - val_loss: 0.3503 - val_raw_multi_label_accuracy: 0.1729
# Epoch 25/1000
#  - 19s - loss: 0.1889 - raw_multi_label_accuracy: 0.4737 - val_loss: 0.3553 - val_raw_multi_label_accuracy: 0.1913
# Epoch 26/1000
#  - 20s - loss: 0.1829 - raw_multi_label_accuracy: 0.4976 - val_loss: 0.3669 - val_raw_multi_label_accuracy: 0.1714
# Epoch 27/1000
#  - 19s - loss: 0.1767 - raw_multi_label_accuracy: 0.5050 - val_loss: 0.3696 - val_raw_multi_label_accuracy: 0.1902
# Epoch 28/1000
#  - 19s - loss: 0.1695 - raw_multi_label_accuracy: 0.5253 - val_loss: 0.3809 - val_raw_multi_label_accuracy: 0.1881
# Epoch 29/1000
#  - 21s - loss: 0.1623 - raw_multi_label_accuracy: 0.5449 - val_loss: 0.3909 - val_raw_multi_label_accuracy: 0.1906
# Epoch 30/1000
#  - 23s - loss: 0.1546 - raw_multi_label_accuracy: 0.5636 - val_loss: 0.3994 - val_raw_multi_label_accuracy: 0.1994
# Epoch 31/1000
#  - 24s - loss: 0.1475 - raw_multi_label_accuracy: 0.5791 - val_loss: 0.4158 - val_raw_multi_label_accuracy: 0.1871
# Epoch 32/1000
#  - 23s - loss: 0.1402 - raw_multi_label_accuracy: 0.5933 - val_loss: 0.4193 - val_raw_multi_label_accuracy: 0.1942
# Epoch 33/1000
#  - 21s - loss: 0.1321 - raw_multi_label_accuracy: 0.6272 - val_loss: 0.4397 - val_raw_multi_label_accuracy: 0.1914
# Epoch 34/1000
#  - 21s - loss: 0.1241 - raw_multi_label_accuracy: 0.6531 - val_loss: 0.4447 - val_raw_multi_label_accuracy: 0.1996
# Epoch 35/1000
#  - 17s - loss: 0.1172 - raw_multi_label_accuracy: 0.6664 - val_loss: 0.4616 - val_raw_multi_label_accuracy: 0.1990
# Epoch 36/1000
#  - 9s - loss: 0.1111 - raw_multi_label_accuracy: 0.6845 - val_loss: 0.4822 - val_raw_multi_label_accuracy: 0.1975
# Epoch 37/1000
#  - 9s - loss: 0.1045 - raw_multi_label_accuracy: 0.6966 - val_loss: 0.4921 - val_raw_multi_label_accuracy: 0.2019
# Epoch 38/1000
#  - 9s - loss: 0.0971 - raw_multi_label_accuracy: 0.7235 - val_loss: 0.5102 - val_raw_multi_label_accuracy: 0.2204
# Epoch 39/1000
#  - 10s - loss: 0.0935 - raw_multi_label_accuracy: 0.7313 - val_loss: 0.5278 - val_raw_multi_label_accuracy: 0.2223
# Epoch 40/1000
#  - 9s - loss: 0.0889 - raw_multi_label_accuracy: 0.7478 - val_loss: 0.5408 - val_raw_multi_label_accuracy: 0.2045
# Epoch 41/1000
#  - 9s - loss: 0.0856 - raw_multi_label_accuracy: 0.7579 - val_loss: 0.5555 - val_raw_multi_label_accuracy: 0.2054
# Epoch 42/1000
#  - 9s - loss: 0.0821 - raw_multi_label_accuracy: 0.7717 - val_loss: 0.5601 - val_raw_multi_label_accuracy: 0.2210
# Epoch 43/1000
#  - 9s - loss: 0.0756 - raw_multi_label_accuracy: 0.7855 - val_loss: 0.5944 - val_raw_multi_label_accuracy: 0.2190
# Epoch 44/1000
#  - 9s - loss: 0.0743 - raw_multi_label_accuracy: 0.7868 - val_loss: 0.5920 - val_raw_multi_label_accuracy: 0.2306
# Epoch 45/1000
#  - 9s - loss: 0.0699 - raw_multi_label_accuracy: 0.8030 - val_loss: 0.6195 - val_raw_multi_label_accuracy: 0.2148
# Epoch 46/1000
#  - 9s - loss: 0.0677 - raw_multi_label_accuracy: 0.8049 - val_loss: 0.6268 - val_raw_multi_label_accuracy: 0.2152
# Epoch 47/1000
#  - 10s - loss: 0.0649 - raw_multi_label_accuracy: 0.8186 - val_loss: 0.6247 - val_raw_multi_label_accuracy: 0.2220
# Epoch 48/1000
#  - 10s - loss: 0.0618 - raw_multi_label_accuracy: 0.8299 - val_loss: 0.6615 - val_raw_multi_label_accuracy: 0.2081
# Epoch 49/1000
#  - 9s - loss: 0.0608 - raw_multi_label_accuracy: 0.8239 - val_loss: 0.6548 - val_raw_multi_label_accuracy: 0.2162

# %%
predictions = nn_output_to_predictions(lstm_model.predict(x_test_seq))

# %%
get_all_metrics(y_test, predictions)
# Out:
# Getting evaluation metrics for each label:
# Accuruacy for War: 0.9631490787269682
# Precision for War: 0.0
# Recall for War: 0.0
#
# Accuruacy for Family: 0.8944723618090452
# Precision for Family: 0.20689655172413793
# Recall for Family: 0.13043478260869565
#
# Accuruacy for Science Fiction: 0.8693467336683417
# Precision for Science Fiction: 0.2777777777777778
# Recall for Science Fiction: 0.16129032258064516
#
# Accuruacy for Thriller: 0.7219430485762144
# Precision for Thriller: 0.512
# Recall for Thriller: 0.378698224852071
#
# Accuruacy for Horror: 0.8994974874371859
# Precision for Horror: 0.42857142857142855
# Recall for Horror: 0.21428571428571427
#
# Accuruacy for Romance: 0.7738693467336684
# Precision for Romance: 0.4016393442622951
# Recall for Romance: 0.44144144144144143
#
# Accuruacy for Drama: 0.5678391959798995
# Precision for Drama: 0.608540925266904
# Recall for Drama: 0.5360501567398119
#
# Accuruacy for Foreign: 0.9882747068676717
# Precision for Foreign: 0.0
# Recall for Foreign: 0.0
#
# Accuruacy for Documentary: 0.9731993299832495
# Precision for Documentary: 0.0
# Recall for Documentary: 0.0
#
# Accuruacy for Fantasy: 0.8961474036850922
# Precision for Fantasy: 0.19230769230769232
# Recall for Fantasy: 0.10869565217391304
#
# Accuruacy for Western: 0.983249581239531
# Precision for Western: 0.0
# Recall for Western: 0.0
#
# Accuruacy for History: 0.9564489112227805
# Precision for History: 0.2857142857142857
# Recall for History: 0.08695652173913043
#
# Accuruacy for Comedy: 0.6080402010050251
# Precision for Comedy: 0.45714285714285713
# Recall for Comedy: 0.4444444444444444
#
# Accuruacy for Action: 0.7269681742043551
# Precision for Action: 0.47761194029850745
# Recall for Action: 0.40764331210191085
#
# Accuruacy for Adventure: 0.8040201005025126
# Precision for Adventure: 0.3103448275862069
# Recall for Adventure: 0.18947368421052632
#
# Accuruacy for Animation: 0.9564489112227805
# Precision for Animation: 0.6666666666666666
# Recall for Animation: 0.07407407407407407
#
# Accuruacy for Crime: 0.8241206030150754
# Precision for Crime: 0.4264705882352941
# Recall for Crime: 0.30526315789473685
#
# Accuruacy for Music: 0.964824120603015
# Precision for Music: 0.0
# Recall for Music: 0.0
#
# Accuruacy for TV Movie: 1.0
# Precision for TV Movie: 0.0
# Recall for TV Movie: 0.0
#
# Accuruacy for Mystery: 0.9296482412060302
# Precision for Mystery: 0.375
# Recall for Mystery: 0.075
#
# Getting evaluations for multilabel problem
# Multilabel accuracy: 0.2881311318497246
# Multilabel precision: 0.48040935672514645
# Multilabel recall: 0.36368748504426895
# Percent of correctly decided label decisions: 86.50753768844221

# %% [markdown]
# simple rnn

# %%
rnn = Sequential()
e = Embedding(num_words_kept, word_vec_len, weights=[embedding_matrix], input_length=max_seq_len, trainable=True)
rnn.add(e)
rnn.add(SimpleRNN(32, activation = 'relu'))
rnn.add(Dense(256, activation='relu'))
rnn.add(Dense(len(genre_dict), activation='sigmoid'))
rnn.compile(loss='binary_crossentropy', optimizer='adam', metrics=[raw_multi_label_accuracy])
rnn.fit(x_train_seq, y_train, validation_split = .1, callbacks = [DelayedEarlyStopping(monitor = 'val_raw_multi_label_accuracy', patience = 5, delay=25)], epochs=1000, batch_size=100, verbose=2)
# Out:
# Train on 2149 samples, validate on 239 samples
# Epoch 1/1000
#  - 3s - loss: 0.4777 - raw_multi_label_accuracy: 0.1021 - val_loss: 0.3353 - val_raw_multi_label_accuracy: 0.1752
# Epoch 2/1000
#  - 1s - loss: 0.3275 - raw_multi_label_accuracy: 0.1243 - val_loss: 0.3266 - val_raw_multi_label_accuracy: 0.0464
# Epoch 3/1000
#  - 2s - loss: 0.3165 - raw_multi_label_accuracy: 0.1201 - val_loss: 0.3199 - val_raw_multi_label_accuracy: 0.1070
# Epoch 4/1000
#  - 2s - loss: 0.3090 - raw_multi_label_accuracy: 0.1168 - val_loss: 0.3146 - val_raw_multi_label_accuracy: 0.1524
# Epoch 5/1000
#  - 2s - loss: 0.3022 - raw_multi_label_accuracy: 0.1421 - val_loss: 0.3141 - val_raw_multi_label_accuracy: 0.1346
# Epoch 6/1000
#  - 2s - loss: 0.2974 - raw_multi_label_accuracy: 0.1501 - val_loss: 0.3120 - val_raw_multi_label_accuracy: 0.0879
# Epoch 7/1000
#  - 2s - loss: 0.2903 - raw_multi_label_accuracy: 0.1416 - val_loss: 0.3104 - val_raw_multi_label_accuracy: 0.1331
# Epoch 8/1000
#  - 1s - loss: 0.2813 - raw_multi_label_accuracy: 0.1513 - val_loss: 0.3101 - val_raw_multi_label_accuracy: 0.1194
# Epoch 9/1000
#  - 2s - loss: 0.2694 - raw_multi_label_accuracy: 0.1597 - val_loss: 0.3157 - val_raw_multi_label_accuracy: 0.1351
# Epoch 10/1000
#  - 2s - loss: 0.2489 - raw_multi_label_accuracy: 0.2069 - val_loss: 0.3146 - val_raw_multi_label_accuracy: 0.0989
# Epoch 11/1000
#  - 1s - loss: 0.2178 - raw_multi_label_accuracy: 0.3284 - val_loss: 0.3260 - val_raw_multi_label_accuracy: 0.1117
# Epoch 12/1000
#  - 2s - loss: 0.1825 - raw_multi_label_accuracy: 0.4722 - val_loss: 0.3588 - val_raw_multi_label_accuracy: 0.1202
# Epoch 13/1000
#  - 2s - loss: 0.1566 - raw_multi_label_accuracy: 0.5675 - val_loss: 0.3771 - val_raw_multi_label_accuracy: 0.1234
# Epoch 14/1000
#  - 2s - loss: 0.1325 - raw_multi_label_accuracy: 0.6395 - val_loss: 0.4401 - val_raw_multi_label_accuracy: 0.1343
# Epoch 15/1000
#  - 2s - loss: 0.1105 - raw_multi_label_accuracy: 0.7069 - val_loss: 0.5127 - val_raw_multi_label_accuracy: 0.1331
# Epoch 16/1000
#  - 2s - loss: 0.0956 - raw_multi_label_accuracy: 0.7451 - val_loss: 0.4745 - val_raw_multi_label_accuracy: 0.1455
# Epoch 17/1000
#  - 2s - loss: 0.0777 - raw_multi_label_accuracy: 0.7949 - val_loss: 0.5087 - val_raw_multi_label_accuracy: 0.1614
# Epoch 18/1000
#  - 2s - loss: 0.0620 - raw_multi_label_accuracy: 0.8420 - val_loss: 0.5791 - val_raw_multi_label_accuracy: 0.1432
# Epoch 19/1000
#  - 2s - loss: 0.0485 - raw_multi_label_accuracy: 0.8841 - val_loss: 0.6233 - val_raw_multi_label_accuracy: 0.1489
# Epoch 20/1000
#  - 2s - loss: 0.0404 - raw_multi_label_accuracy: 0.9051 - val_loss: 0.7380 - val_raw_multi_label_accuracy: 0.1474
# Epoch 21/1000
#  - 2s - loss: 0.0342 - raw_multi_label_accuracy: 0.9257 - val_loss: 0.7734 - val_raw_multi_label_accuracy: 0.1504
# Epoch 22/1000
#  - 2s - loss: 0.0268 - raw_multi_label_accuracy: 0.9445 - val_loss: 0.8546 - val_raw_multi_label_accuracy: 0.1246
# Epoch 23/1000
#  - 2s - loss: 0.0224 - raw_multi_label_accuracy: 0.9562 - val_loss: 0.8435 - val_raw_multi_label_accuracy: 0.1405
# Epoch 24/1000
#  - 2s - loss: 0.0194 - raw_multi_label_accuracy: 0.9611 - val_loss: 0.8658 - val_raw_multi_label_accuracy: 0.1463
# Epoch 25/1000
#  - 2s - loss: 0.0164 - raw_multi_label_accuracy: 0.9701 - val_loss: 0.9119 - val_raw_multi_label_accuracy: 0.1659
# Epoch 26/1000
#  - 2s - loss: 0.0171 - raw_multi_label_accuracy: 0.9669 - val_loss: 0.7661 - val_raw_multi_label_accuracy: 0.1512
# Epoch 27/1000
#  - 2s - loss: 0.0314 - raw_multi_label_accuracy: 0.9292 - val_loss: 0.6967 - val_raw_multi_label_accuracy: 0.1338
# Epoch 28/1000
#  - 2s - loss: 0.0295 - raw_multi_label_accuracy: 0.9259 - val_loss: 0.8182 - val_raw_multi_label_accuracy: 0.1471
# Epoch 29/1000
#  - 2s - loss: 0.0152 - raw_multi_label_accuracy: 0.9722 - val_loss: 0.9133 - val_raw_multi_label_accuracy: 0.1435
# Epoch 30/1000
#  - 2s - loss: 0.0103 - raw_multi_label_accuracy: 0.9840 - val_loss: 0.9675 - val_raw_multi_label_accuracy: 0.1475
# Epoch 31/1000
#  - 2s - loss: 0.0079 - raw_multi_label_accuracy: 0.9885 - val_loss: 1.0299 - val_raw_multi_label_accuracy: 0.1502
# Epoch 32/1000
#  - 2s - loss: 0.0063 - raw_multi_label_accuracy: 0.9922 - val_loss: 1.0806 - val_raw_multi_label_accuracy: 0.1395
# Epoch 33/1000
#  - 2s - loss: 0.0053 - raw_multi_label_accuracy: 0.9928 - val_loss: 1.1289 - val_raw_multi_label_accuracy: 0.1430
# Epoch 34/1000
#  - 2s - loss: 0.0047 - raw_multi_label_accuracy: 0.9948 - val_loss: 1.1478 - val_raw_multi_label_accuracy: 0.1450
# Epoch 35/1000
#  - 2s - loss: 0.0043 - raw_multi_label_accuracy: 0.9935 - val_loss: 1.1718 - val_raw_multi_label_accuracy: 0.1340
# Epoch 36/1000
#  - 2s - loss: 0.0041 - raw_multi_label_accuracy: 0.9945 - val_loss: 1.1708 - val_raw_multi_label_accuracy: 0.1502

# %%
predictions = nn_output_to_predictions(rnn.predict(x_test_seq))

# %%
get_all_metrics(y_test, predictions)
# Out:
# Getting evaluation metrics for each label:
# Accuruacy for War: 0.9631490787269682
# Precision for War: 0.0
# Recall for War: 0.0
#
# Accuruacy for Family: 0.9179229480737019
# Precision for Family: 0.0
# Recall for Family: 0.0
#
# Accuruacy for Science Fiction: 0.8944723618090452
# Precision for Science Fiction: 0.4
# Recall for Science Fiction: 0.03225806451612903
#
# Accuruacy for Thriller: 0.6515912897822446
# Precision for Thriller: 0.29896907216494845
# Recall for Thriller: 0.17159763313609466
#
# Accuruacy for Horror: 0.8944723618090452
# Precision for Horror: 0.1111111111111111
# Recall for Horror: 0.017857142857142856
#
# Accuruacy for Romance: 0.7855946398659966
# Precision for Romance: 0.2571428571428571
# Recall for Romance: 0.08108108108108109
#
# Accuruacy for Drama: 0.5326633165829145
# Precision for Drama: 0.5662251655629139
# Recall for Drama: 0.5360501567398119
#
# Accuruacy for Foreign: 0.9882747068676717
# Precision for Foreign: 0.0
# Recall for Foreign: 0.0
#
# Accuruacy for Documentary: 0.9731993299832495
# Precision for Documentary: 0.0
# Recall for Documentary: 0.0
#
# Accuruacy for Fantasy: 0.9229480737018425
# Precision for Fantasy: 0.5
# Recall for Fantasy: 0.043478260869565216
#
# Accuruacy for Western: 0.983249581239531
# Precision for Western: 0.0
# Recall for Western: 0.0
#
# Accuruacy for History: 0.9597989949748744
# Precision for History: 0.0
# Recall for History: 0.0
#
# Accuruacy for Comedy: 0.5695142378559463
# Precision for Comedy: 0.34108527131782945
# Recall for Comedy: 0.2037037037037037
#
# Accuruacy for Action: 0.6566164154103853
# Precision for Action: 0.2692307692307692
# Recall for Action: 0.17834394904458598
#
# Accuruacy for Adventure: 0.8358458961474037
# Precision for Adventure: 0.2857142857142857
# Recall for Adventure: 0.021052631578947368
#
# Accuruacy for Animation: 0.9547738693467337
# Precision for Animation: 0.5
# Recall for Animation: 0.037037037037037035
#
# Accuruacy for Crime: 0.7973199329983249
# Precision for Crime: 0.15789473684210525
# Recall for Crime: 0.06315789473684211
#
# Accuruacy for Music: 0.9731993299832495
# Precision for Music: 0.0
# Recall for Music: 0.0
#
# Accuruacy for TV Movie: 1.0
# Precision for TV Movie: 0.0
# Recall for TV Movie: 0.0
#
# Accuruacy for Mystery: 0.9262981574539364
# Precision for Mystery: 0.0
# Recall for Mystery: 0.0
#
# Getting evaluations for multilabel problem
# Multilabel accuracy: 0.1736260668421472
# Multilabel precision: 0.4132762312633832
# Multilabel recall: 0.21294568078487663
# Percent of correctly decided label decisions: 85.90452261306532
