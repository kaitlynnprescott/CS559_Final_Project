# %%
import numpy as np
import pandas as pd

#for reading in data properly
import ast
import json

from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import utils

import re

import nltk
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

import time

# %% [markdown]
# Read in the data

# %%
all_data = pd.read_csv('train.csv')
all_data = all_data.dropna(subset=['overview', 'genres']) #drop cols without overview or genre (data we use or labels)
genre_set = {'Comedy'}

# %%
#get set of all genres in dataset    
def parse_all_genres_json(x):
    try:
        json_genres = json.loads(x.replace("'", '"'))
        numElems = len(json_genres)
        for i in range(numElems):
            genre_set.add(json_genres[i]['name'])
    except:
        return ''

#parse genres of specific example in dataset to get their label vector
def parse_genres_json(x):
    try:
        json_genres = json.loads(x.replace("'", '"'))
        numElems = len(json_genres)
        ret = [0]*len(genre_dict) #20 0s
        for i in range(numElems):
            ret[genre_dict[(json_genres[i]['name'])]] = 1
        return ret
    except:
        return ''
    
#get list of labels this row has in string format
def get_labels_as_strs(x):
    try:
        json_genres = json.loads(x.replace("'", '"'))
        numElems = len(json_genres)
        ret = []
        for i in range(numElems):
            ret.append(json_genres[i]['name'])
        return ret
    except:
        return ''

# %%
def getAllGenres():
    y = all_data['genres']
    y.apply(parse_all_genres_json)

# %%
getAllGenres()

# %%
#get set to dictionary for indexing of label vectors
genre_dict = {}
index = 0
for genre in genre_set:
    genre_dict[genre] = index
    index += 1

# %%
def getGenresVects():
    y = all_data['genres']
    ret = y.apply(parse_genres_json)
    all_data['genres_vect'] = ret
    label_strs = y.apply(get_labels_as_strs) #not currently used but could be useful
    all_data['genres_labels'] = label_strs

# %%
getGenresVects() #get labels in vector form

# %%
#put to lower case, remove punctation, remove stopwords
def cleanText(text):
    no_stopword_text = [w for w in text.split() if not w in stop_words]
    text = ' '.join(no_stopword_text)
    text = re.sub(r'[^a-z A-Z0-9]', "", text)
    text = text.lower()
    return text

#clean up the overview field and put it in cleanOverview
all_data['cleanOverview'] = all_data['overview'].apply(cleanText)

# %%
#logistic regression data
lr_data = all_data[['cleanOverview', 'genres_labels', 'genres_vect']]

# %% [markdown]
# Train Test Split and getting text features and labels vectors

# %%
train, test = train_test_split(lr_data, test_size=0.2, random_state=42)

# %%
X_train = train.cleanOverview
X_test = test.cleanOverview

# %%
#convert labels from array of lists to numpy array

train_targets_arr = train['genres_vect'].tolist()
train_targets_arr = np.array(train_targets_arr)

test_targets_arr = test['genres_vect'].tolist()
test_targets_arr = np.array(test_targets_arr)

# %% [markdown]
# Define class that will do multilabel logistic regression by wrapping Pipelines of tfidf and OneVsRest Logistic Regression Classifiers

# %%
class MultiLabelLogisitcRegression():
    def __init__(self, genre_dict):
        self.genre_dict = genre_dict
        self.pipelines = {}
        for category in self.genre_dict.keys():
            self.pipelines[category]=Pipeline([
                ('tfidf', TfidfVectorizer(stop_words=stop_words)),
                ('clf', OneVsRestClassifier(LogisticRegression(solver='liblinear', multi_class='ovr'), n_jobs=1)),
            ])
        
    def fit(self, X_train, train_targets_arr):
        start = time.time()
        for category in self.genre_dict.keys():
            print('Processing {}'.format(category))
            self.pipelines[category].fit(X_train, train_targets_arr[:,genre_dict[category]])
        end = time.time()
        print('Time to train ' + str(end-start) + ' seconds')

    def predict(self, X_test):
        Ret = np.zeros((X_test.shape[0],len(self.genre_dict.keys())), dtype='int')
        for category in self.genre_dict.keys():
            try:
                prediction = self.pipelines[category].predict(X_test)
            except: #exception we get is it was trained with data taht was only 0 label during cross validation
                prediction = np.zeros(X_test.shape[0], dtype=int)
            Ret[:,self.genre_dict[category]] = prediction
        return Ret
    
    #unbalanced data so allow prediction with given threshold
    def predict_threshold(self, X_test, threshold):
        Ret = np.zeros((X_test.shape[0],len(self.genre_dict.keys())), dtype='int')
        for category in self.genre_dict.keys():
            try:
                prediction = self.pipelines[category].predict_proba(X_test)[:,1]
            except:#exception we get is it was trained with data taht was only 0 label during cross validation
                prediction = np.zeros(X_test.shape[0], dtype=int)
            prediction[prediction >=threshold] = 1
            prediction[prediction < threshold] = 0
            Ret[:,self.genre_dict[category]] = prediction
        return Ret

# %% [markdown]
# Evaluation metric definitions and printing functions

# %%
#size of intersection of predicted and actual labels divided by size of their union for each datapoint tested on
#sum those and then divide by number of datapoints
#vectorized for speed
def multi_label_accuracy(real_labels_matrix, predictions_labels_matrix):
    #binary so set intersection is and operator
    intersection = real_labels_matrix & predictions_labels_matrix
    #set union for binary is same as or operator
    union = real_labels_matrix | predictions_labels_matrix
    #sum(array.T) gets number of 1s in row
    row_wise_accuracy = sum(intersection.T) / sum(union.T)
    return sum(row_wise_accuracy) / real_labels_matrix.shape[0]

#size of intersection of predicted and actual labels divided by size of predicted set for each datapoint tested on
#sum those and divide by number of datapoints
#if no predicted labels, don't count that row towards the precision as that would be undefined
def multi_label_precision(real_labels_matrix, predictions_labels_matrix):
    #binary so set intersection is and operator
    intersection = real_labels_matrix & predictions_labels_matrix
    precision_sum = 0
    num_rows = 0
    for row in range(intersection.shape[0]):
        if sum(predictions_labels_matrix[row]) > 0: #if there is at least one prediction for this row
            num_rows += 1
            precision_sum += sum(intersection[row]) / sum(predictions_labels_matrix[row])
    if num_rows == 0:
        return 0#no labels predicted at all will give us 0 precision as precision makes no sense here
    return precision_sum / num_rows

#size of intersection of predicted and actual labels divided by size of real label set for each datapoint tested on
#sum those and divide by number of datapoints
#all datapoints should have at least 1 real label in this data set
#vectorized for speed
def multi_label_recall(real_labels_matrix, predictions_labels_matrix):
    #binary so set intersection is and operator
    intersection = real_labels_matrix & predictions_labels_matrix
    #set union for binary is same as or operator
    #sum(array.T) gets number of 1s in row
    row_wise_recall = sum(intersection.T) / sum(real_labels_matrix.T)
    return sum(row_wise_recall) / real_labels_matrix.shape[0]

#lower is better
def hamming_loss(real_labels_matrix, predictions_labels_matrix):
    return (np.logical_xor(real_labels_matrix, predictions_labels_matrix)).sum()/(real_labels_matrix.shape[0] * real_labels_matrix.shape[1])

# %%
def get_per_label_metrics(real_labels_matrix, predictions_labels_matrix):
    for genre in genre_dict.keys():
        index = genre_dict[genre]
        real_labels_vect = real_labels_matrix[:, index]
        prediction_vect = predictions_labels_matrix[:,index]
        print("Accuruacy for " + genre + ": " + str(accuracy_score(real_labels_vect, prediction_vect)))
        print("Precision for " + genre + ": " + str(precision_score(real_labels_vect, prediction_vect)))
        print("Recall for " + genre + ": " + str(recall_score(real_labels_vect, prediction_vect)))
        print()

# %%
def get_all_metrics(actual_labels, predictions):
    print('Getting evaluation metrics for each label:')
    get_per_label_metrics(actual_labels, predictions)
    print('Getting evaluations for multilabel problem')
    print('Multilabel accuracy: ' + str(multi_label_accuracy(actual_labels, predictions)))
    print('Multilabel precision: ' + str(multi_label_precision(actual_labels, predictions)))
    print('Multilabel recall: ' + str(multi_label_recall(actual_labels, predictions)))
    print("Percent of correctly decided label decisions: " + str(100* (1-hamming_loss(actual_labels, predictions))))

# %%
multi = MultiLabelLogisitcRegression(genre_dict)
multi.fit(X_train, train_targets_arr)
results = multi.predict(X_test)
# Out:
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 3.479907751083374 seconds

# %%
get_all_metrics(test_targets_arr, results)
# Out:
# Getting evaluation metrics for each label:
# Accuruacy for Foreign: 0.9882747068676717
# Precision for Foreign: 0.0
# Recall for Foreign: 0.0
#
# Accuruacy for Crime: 0.8408710217755444
# Precision for Crime: 0.0
# Recall for Crime: 0.0
#
# Accuruacy for Adventure: 0.8408710217755444
# Precision for Adventure: 0.0
# Recall for Adventure: 0.0
#
# Accuruacy for Comedy: 0.6834170854271356
# Precision for Comedy: 0.813953488372093
# Recall for Comedy: 0.16203703703703703
#
# Accuruacy for Animation: 0.9547738693467337
# Precision for Animation: 0.0
# Recall for Animation: 0.0
#
# Accuruacy for TV Movie: 1.0
# Precision for TV Movie: 0.0
# Recall for TV Movie: 0.0
#
# Accuruacy for Drama: 0.6633165829145728
# Precision for Drama: 0.6966666666666667
# Recall for Drama: 0.6551724137931034
#
# Accuruacy for Family: 0.9229480737018425
# Precision for Family: 0.0
# Recall for Family: 0.0
#
# Accuruacy for Action: 0.7554438860971524
# Precision for Action: 0.9230769230769231
# Recall for Action: 0.07643312101910828
#
# Accuruacy for Fantasy: 0.9229480737018425
# Precision for Fantasy: 0.0
# Recall for Fantasy: 0.0
#
# Accuruacy for Science Fiction: 0.8961474036850922
# Precision for Science Fiction: 0.0
# Recall for Science Fiction: 0.0
#
# Accuruacy for Romance: 0.8257956448911222
# Precision for Romance: 0.8888888888888888
# Recall for Romance: 0.07207207207207207
#
# Accuruacy for Music: 0.9748743718592965
# Precision for Music: 0.0
# Recall for Music: 0.0
#
# Accuruacy for Mystery: 0.932998324958124
# Precision for Mystery: 0.0
# Recall for Mystery: 0.0
#
# Accuruacy for Western: 0.983249581239531
# Precision for Western: 0.0
# Recall for Western: 0.0
#
# Accuruacy for History: 0.9614740368509213
# Precision for History: 0.0
# Recall for History: 0.0
#
# Accuruacy for War: 0.964824120603015
# Precision for War: 0.0
# Recall for War: 0.0
#
# Accuruacy for Documentary: 0.9731993299832495
# Precision for Documentary: 0.0
# Recall for Documentary: 0.0
#
# Accuruacy for Thriller: 0.7286432160804021
# Precision for Thriller: 0.8888888888888888
# Recall for Thriller: 0.047337278106508875
#
# Accuruacy for Horror: 0.9061976549413735
# Precision for Horror: 0.0
# Recall for Horror: 0.0
#
# Getting evaluations for multilabel problem
# Multilabel accuracy: 0.2167185132009251
# Multilabel precision: 0.717564870259481
# Multilabel recall: 0.22224615139188
# Percent of correctly decided label decisions: 88.60134003350085
# /home/matt/.local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/matt/.local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)

# %% [markdown]
# Notice the poor multilabel metrics despite high accuracy on each label when considered alone. Do cross validation to find better threshold than .5

# %%
#k fold cross validation with threshold
def kFoldCrossValidation(X, y, folds, threshold):
    print("Doing cross validation for threshold = " + str(threshold))
    held_out_size = len(X)//folds
    multi_label_acc = 0
    for i in range(folds):
        print("Iteration " + str(i+1) + " of " + str(folds) + " fold cross validation")
        held_out_index = i*held_out_size
        if i == folds-1:
            held_out_data = X[held_out_index:]
            held_out_y = y[held_out_index:]
            iter_training_data = X[0:held_out_index]
            iter_y = y[0:held_out_index]
        else:
            held_out_data = X[held_out_index:held_out_index+held_out_size]
            held_out_y = y[held_out_index:held_out_index+held_out_size]
            iter_training_data = np.append(X[0:held_out_index], X[held_out_index+held_out_size:], axis=0)
            iter_y = np.append(y[0:held_out_index], y[held_out_index+held_out_size:], axis=0)
        multi = MultiLabelLogisitcRegression(genre_dict)
        multi.fit(iter_training_data, iter_y)
        predictions = multi.predict_threshold(held_out_data, threshold)
        multi_label_acc += multi_label_accuracy(held_out_y, predictions)
    return multi_label_acc / folds #sum accross all folds and divide by number of folds

# %%
#find best threshold looking from .3 to .7 in ntervals of .05
test_threshold = .3
best_threshold_acc = 0
best_threshold = .5 #default is .5
start = time.time()
while test_threshold <= .7:
    acc = kFoldCrossValidation(X_train, train_targets_arr, 5, test_threshold)
    print("Accuracy: " + str(acc))
    if acc > best_threshold_acc:
        best_threshold_acc = acc
        best_threshold = test_threshold
    test_threshold += .05
end = time.time()
print('Time to run k fold cross validation to find best threshold ' + str(end-start))
# Out:
# Doing cross validation for threshold = 0.3
# Iteration 1 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.8468070030212402 seconds
# Iteration 2 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.432809829711914 seconds
# Iteration 3 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.3419041633605957 seconds
# Iteration 4 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 3.490022659301758 seconds
# Iteration 5 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# /home/matt/.local/lib/python3.6/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 0 is present in all training examples.
#   str(classes[c]))
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 4.487736225128174 seconds
# Accuracy: 0.3681808456873316
# Doing cross validation for threshold = 0.35
# Iteration 1 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 3.7458229064941406 seconds
# Iteration 2 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.559363842010498 seconds
# Iteration 3 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 3.0725910663604736 seconds
# Iteration 4 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.0341124534606934 seconds
# Iteration 5 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# /home/matt/.local/lib/python3.6/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 0 is present in all training examples.
#   str(classes[c]))
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.2443044185638428 seconds
# Accuracy: 0.33811258360786667
# Doing cross validation for threshold = 0.39999999999999997
# Iteration 1 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.140397548675537 seconds
# Iteration 2 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 1.985569953918457 seconds
# Iteration 3 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.192272186279297 seconds
# Iteration 4 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.0553407669067383 seconds
# Iteration 5 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# /home/matt/.local/lib/python3.6/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 0 is present in all training examples.
#   str(classes[c]))
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.115283489227295 seconds
# Accuracy: 0.31031498327842666
# Doing cross validation for threshold = 0.44999999999999996
# Iteration 1 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.096423625946045 seconds
# Iteration 2 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.0884861946105957 seconds
# Iteration 3 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.036109685897827 seconds
# Iteration 4 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.039761781692505 seconds
# Iteration 5 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# /home/matt/.local/lib/python3.6/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 0 is present in all training examples.
#   str(classes[c]))
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.097968578338623 seconds
# Accuracy: 0.26161788085255044
# Doing cross validation for threshold = 0.49999999999999994
# Iteration 1 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.039646625518799 seconds
# Iteration 2 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.0346224308013916 seconds
# Iteration 3 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.065187454223633 seconds
# Iteration 4 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.0358145236968994 seconds
# Iteration 5 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# /home/matt/.local/lib/python3.6/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 0 is present in all training examples.
#   str(classes[c]))
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.111846923828125 seconds
# Accuracy: 0.2048677935010481
# Doing cross validation for threshold = 0.5499999999999999
# Iteration 1 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.045185089111328 seconds
# Iteration 2 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.056483030319214 seconds
# Iteration 3 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.0793023109436035 seconds
# Iteration 4 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.057224750518799 seconds
# Iteration 5 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# /home/matt/.local/lib/python3.6/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 0 is present in all training examples.
#   str(classes[c]))
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 1.9919326305389404 seconds
# Accuracy: 0.1371191474493362
# Doing cross validation for threshold = 0.6
# Iteration 1 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.0400352478027344 seconds
# Iteration 2 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.0820374488830566 seconds
# Iteration 3 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.210265874862671 seconds
# Iteration 4 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.113121509552002 seconds
# Iteration 5 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# /home/matt/.local/lib/python3.6/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 0 is present in all training examples.
#   str(classes[c]))
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.1202824115753174 seconds
# Accuracy: 0.0781012403913347
# Doing cross validation for threshold = 0.65
# Iteration 1 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.029661178588867 seconds
# Iteration 2 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.0920662879943848 seconds
# Iteration 3 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.270277261734009 seconds
# Iteration 4 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.28413987159729 seconds
# Iteration 5 of 5 fold cross validation
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# /home/matt/.local/lib/python3.6/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 0 is present in all training examples.
#   str(classes[c]))
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 2.1718573570251465 seconds
# Accuracy: 0.03687360237596087
# Time to run k fold cross validation to find best threshold 107.80405282974243

# %%
print('Best threshold for multilabel accuracy: ' + str(best_threshold))
classifier = MultiLabelLogisitcRegression(genre_dict)
classifier.fit(X_train, train_targets_arr)
predictions = multi.predict_threshold(X_test, best_threshold)
# Out:
# Best threshold for multilabel accuracy: 0.3
# Processing Foreign
# Processing Crime
# Processing Adventure
# Processing Comedy
# Processing Animation
# Processing TV Movie
# Processing Drama
# Processing Family
# Processing Action
# Processing Fantasy
# Processing Science Fiction
# Processing Romance
# Processing Music
# Processing Mystery
# Processing Western
# Processing History
# Processing War
# Processing Documentary
# Processing Thriller
# Processing Horror
# Time to train 3.3889646530151367 seconds

# %%
get_all_metrics(test_targets_arr, predictions)
# Out:
# Getting evaluation metrics for each label:
# Accuruacy for Foreign: 0.9882747068676717
# Precision for Foreign: 0.0
# Recall for Foreign: 0.0
#
# Accuruacy for Crime: 0.8659966499162479
# Precision for Crime: 0.7586206896551724
# Recall for Crime: 0.23157894736842105
#
# Accuruacy for Adventure: 0.8458961474036851
# Precision for Adventure: 0.6153846153846154
# Recall for Adventure: 0.08421052631578947
#
# Accuruacy for Comedy: 0.6599664991624791
# Precision for Comedy: 0.5183098591549296
# Recall for Comedy: 0.8518518518518519
#
# Accuruacy for Animation: 0.9547738693467337
# Precision for Animation: 0.0
# Recall for Animation: 0.0
#
# Accuruacy for TV Movie: 1.0
# Precision for TV Movie: 0.0
# Recall for TV Movie: 0.0
#
# Accuruacy for Drama: 0.5494137353433836
# Precision for Drama: 0.5429553264604811
# Recall for Drama: 0.9905956112852664
#
# Accuruacy for Family: 0.9229480737018425
# Precision for Family: 0.0
# Recall for Family: 0.0
#
# Accuruacy for Action: 0.7939698492462312
# Precision for Action: 0.6328125
# Recall for Action: 0.5159235668789809
#
# Accuruacy for Fantasy: 0.9229480737018425
# Precision for Fantasy: 0.0
# Recall for Fantasy: 0.0
#
# Accuruacy for Science Fiction: 0.9045226130653267
# Precision for Science Fiction: 1.0
# Recall for Science Fiction: 0.08064516129032258
#
# Accuruacy for Romance: 0.8576214405360134
# Precision for Romance: 0.703125
# Recall for Romance: 0.40540540540540543
#
# Accuruacy for Music: 0.9748743718592965
# Precision for Music: 0.0
# Recall for Music: 0.0
#
# Accuruacy for Mystery: 0.932998324958124
# Precision for Mystery: 0.0
# Recall for Mystery: 0.0
#
# Accuruacy for Western: 0.983249581239531
# Precision for Western: 0.0
# Recall for Western: 0.0
#
# Accuruacy for History: 0.9614740368509213
# Precision for History: 0.0
# Recall for History: 0.0
#
# Accuruacy for War: 0.964824120603015
# Precision for War: 0.0
# Recall for War: 0.0
#
# Accuruacy for Documentary: 0.9731993299832495
# Precision for Documentary: 0.0
# Recall for Documentary: 0.0
#
# Accuruacy for Thriller: 0.7755443886097152
# Precision for Thriller: 0.6258992805755396
# Recall for Thriller: 0.514792899408284
#
# Accuruacy for Horror: 0.9061976549413735
# Precision for Horror: 0.0
# Recall for Horror: 0.0
#
# Getting evaluations for multilabel problem
# Multilabel accuracy: 0.4031746031746031
# Multilabel precision: 0.5721105527638193
# Multilabel recall: 0.5409388210895745
# Percent of correctly decided label decisions: 88.69346733668341
# /home/matt/.local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/matt/.local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
