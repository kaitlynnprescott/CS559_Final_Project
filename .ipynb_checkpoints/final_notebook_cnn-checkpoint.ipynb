# %%
import numpy as np
import pandas as pd
#for reading in data properly
import ast
import json

import gensim
from gensim.models import Doc2Vec
from gensim.models import Word2Vec
from gensim.models.doc2vec import TaggedDocument

from sklearn.model_selection import train_test_split
from sklearn import utils

import re

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))

# %%
all_data = pd.read_csv('train.csv')
all_data = all_data.dropna(subset=['overview', 'genres']) #drop cols without overview or genre (data we use or labels)
genre_set = {'Comedy'}

# %%
def text_to_list(x):
    if pd.isna(x):
        return ''
    else:
        return ast.literal_eval(x)

def parse_json(x):
    try:
        return json.loads(x.replace("'", '"'))[0]['name']
    except:
        return ''
    
def parse_all_genres_json(x):
    try:
        json_genres = json.loads(x.replace("'", '"'))
        numElems = len(json_genres)
        for i in range(numElems):
            genre_set.add(json_genres[i]['name'])
    except:
        return ''
    
def parse_genres_json(x):
    try:
        json_genres = json.loads(x.replace("'", '"'))
        numElems = len(json_genres)
        ret = [0]*len(genre_dict) #20 0s
        for i in range(numElems):
            ret[genre_dict[(json_genres[i]['name'])]] = 1
        return ret
    except:
        return ''
    

def get_labels_as_strs(x):
    try:
        json_genres = json.loads(x.replace("'", '"'))
        numElems = len(json_genres)
        ret = []#20 0s
        for i in range(numElems):
            ret.append(json_genres[i]['name'])
        return ret
    except:
        return ''

# %%
 def getAllGenres():
    full_data = pd.read_csv('train.csv')

    y = full_data['genres']
    y.apply(parse_all_genres_json)

# %%
getAllGenres()#populate the genre set

# %%
#get set to dictionary for indexing of target vectors
genre_dict = {}
index = 0
for genre in genre_set:
    genre_dict[genre] = index
    index += 1

# %%
def getGenresVects():
    y = all_data['genres']
    ret = y.apply(parse_genres_json)
    all_data['genres_vect'] = ret
    label_strs = y.apply(get_labels_as_strs)
    all_data['genres_labels'] = label_strs
    return ret

# %%
labels_vects = getGenresVects() #get label vectors for genres indexed by indexes in genre_dict

# %%
#put to lower case, remove punctation
def cleanText(text):
    text = re.sub(r'[^a-z A-Z0-9]', "", text) #maybe shouldn't remove punction between words here?
    text = text.lower()
    return text
all_data['cleanOverview'] = all_data['overview'].apply(cleanText)

# %%
#logistic regression data
lr_data = all_data[['cleanOverview', 'genres_labels', 'genres_vect', 'overview']]

# %%
train, test = train_test_split(lr_data, test_size=0.2, random_state=42)

# %% [markdown]
# CNN STUFF here

# %%
#get word embeddings
x = train['cleanOverview'].values.tolist()
y = train['genres_vect']

# %%
x_test = test['cleanOverview'].values.tolist()
y_test = test['genres_vect']

# %%
y_train = y.tolist()
y_train = np.array(y_train)

# %%
y_test = y_test.tolist()
y_test = np.array(y_test)

# %%
tok = [word_tokenize(sent) for sent in x]

# %%
word_vec_len = 32
model = Word2Vec(tok, min_count = 1, size=word_vec_len)

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

num_words_kept = 100000 #using 100000 most popular words, use throughout

tokenizer = Tokenizer(num_words_kept)
tokenizer.fit_on_texts(x)
sequences = tokenizer.texts_to_sequences(x)

x_train_seq = pad_sequences(sequences, maxlen=200)
# Out:
# Using TensorFlow backend.

# %%
test_sequences = tokenizer.texts_to_sequences(x_test)
x_test_seq = pad_sequences(test_sequences, maxlen=200)

# %%
embeddings_index = {}
for w in model.wv.vocab.keys():
    embeddings_index[w] = model.wv[w]


embedding_matrix = np.zeros((num_words_kept, word_vec_len))
for word, i in tokenizer.word_index.items():
    if i >= num_words_kept:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
#intersection of predicted and actual labels divided by uniont for each datapoint tested on
#sum those and then divide by number of datapoints
#vectorized for speed
def multi_label_accuracy(real_labels_matrix, predictions_labels_matrix):
    #binary so set intersection is and operator
    intersection = real_labels_matrix & predictions_labels_matrix
    #set union for binary is same as or operator
    union = real_labels_matrix | predictions_labels_matrix
    #sum(array.T) gets number of 1s in row
    row_wise_accuracy = sum(intersection.T) / sum(union.T)
    return sum(row_wise_accuracy) / real_labels_matrix.shape[0]

import keras.backend as K

#metric for keras for early stopping
#takes in raw labels from kerass (not yet converted to 0 and 1s)
#NOT the same as accuracy, this is total labels correctly identified divided by union of total labels
#this weights rows with more labels higher, where accruacy does not, but this is still a good metric for early stopping
def raw_multi_label_accuracy(y_true, y_pred):
    positives = K.greater_equal(y_pred, 0.5)
    positives = K.cast(positives, K.floatx())
    new_y_pred = positives #+ ((1-positives)*y_pred)
    intersection = y_true * new_y_pred
    union = 1 -((1-y_true)*(1-new_y_pred))
    accuracy = K.sum(intersection) / K.sum(union)
    return accuracy

# %%
from keras.callbacks import EarlyStopping
#for early stopping only after certain number of epochs. wait until delay epochs until early stopping
class DelayedEarlyStopping(EarlyStopping):
    def __init__(self, monitor, min_delta=0, patience=0, verbose=0, mode='auto', delay = 100):
        super(DelayedEarlyStopping, self).__init__()
        self.delay = delay

    def on_epoch_end(self, epoch, logs=None):
        if epoch > self.delay:
            super().on_epoch_end(epoch, logs)

# %%
from keras.layers import Conv1D, GlobalMaxPooling1D
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Flatten
from keras.layers.embeddings import Embedding

model_cnn = Sequential()
e = Embedding(num_words_kept, word_vec_len, weights=[embedding_matrix], input_length=200, trainable=False)
model_cnn.add(e)
model_cnn.add(Conv1D(filters=100, kernel_size=2, padding='valid', activation='relu', strides=1))
model_cnn.add(GlobalMaxPooling1D())
model_cnn.add(Dense(256, activation='relu'))
model_cnn.add(Dense(20, activation='sigmoid'))
model_cnn.compile(loss='binary_crossentropy', optimizer='adam', metrics=[raw_multi_label_accuracy])
#model_cnn_01.fit(x_train_seq, y_train, validation_data=(x_val_seq, y_validation), epochs=5, batch_size=32, verbose=2)
model_cnn.fit(x_train_seq, y_train, validation_split = .1, callbacks = [DelayedEarlyStopping(monitor = 'val_raw_multi_label_accuracy', patience = 10, delay=500)], epochs=1000, batch_size=100, verbose=2)
# Out:
# WARNING:tensorflow:From /home/matt/.local/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/matt/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /home/matt/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Train on 2149 samples, validate on 239 samples
# Epoch 1/1000
#  - 2s - loss: 0.4166 - raw_multi_label_accuracy: 0.0872 - val_loss: 0.3231 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 2/1000
#  - 1s - loss: 0.3163 - raw_multi_label_accuracy: 0.0688 - val_loss: 0.3158 - val_raw_multi_label_accuracy: 0.1695
# Epoch 3/1000
#  - 1s - loss: 0.3136 - raw_multi_label_accuracy: 0.0937 - val_loss: 0.3159 - val_raw_multi_label_accuracy: 0.1695
# Epoch 4/1000
#  - 1s - loss: 0.3133 - raw_multi_label_accuracy: 0.1000 - val_loss: 0.3148 - val_raw_multi_label_accuracy: 0.1695
# Epoch 5/1000
#  - 1s - loss: 0.3132 - raw_multi_label_accuracy: 0.1023 - val_loss: 0.3160 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 6/1000
#  - 1s - loss: 0.3134 - raw_multi_label_accuracy: 0.0754 - val_loss: 0.3150 - val_raw_multi_label_accuracy: 0.1695
# Epoch 7/1000
#  - 1s - loss: 0.3135 - raw_multi_label_accuracy: 0.0816 - val_loss: 0.3140 - val_raw_multi_label_accuracy: 0.1432
# Epoch 8/1000
#  - 1s - loss: 0.3140 - raw_multi_label_accuracy: 0.1125 - val_loss: 0.3161 - val_raw_multi_label_accuracy: 0.1695
# Epoch 9/1000
#  - 2s - loss: 0.3144 - raw_multi_label_accuracy: 0.0926 - val_loss: 0.3168 - val_raw_multi_label_accuracy: 0.1695
# Epoch 10/1000
#  - 2s - loss: 0.3136 - raw_multi_label_accuracy: 0.1086 - val_loss: 0.3156 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 11/1000
#  - 2s - loss: 0.3131 - raw_multi_label_accuracy: 0.1302 - val_loss: 0.3153 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 12/1000
#  - 2s - loss: 0.3131 - raw_multi_label_accuracy: 0.0894 - val_loss: 0.3141 - val_raw_multi_label_accuracy: 0.1685
# Epoch 13/1000
#  - 2s - loss: 0.3131 - raw_multi_label_accuracy: 0.1518 - val_loss: 0.3153 - val_raw_multi_label_accuracy: 0.1487
# Epoch 14/1000
#  - 3s - loss: 0.3138 - raw_multi_label_accuracy: 0.1132 - val_loss: 0.3159 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 15/1000
#  - 3s - loss: 0.3130 - raw_multi_label_accuracy: 0.1149 - val_loss: 0.3139 - val_raw_multi_label_accuracy: 0.1650
# Epoch 16/1000
#  - 3s - loss: 0.3128 - raw_multi_label_accuracy: 0.0788 - val_loss: 0.3149 - val_raw_multi_label_accuracy: 0.1697
# Epoch 17/1000
#  - 3s - loss: 0.3134 - raw_multi_label_accuracy: 0.1148 - val_loss: 0.3165 - val_raw_multi_label_accuracy: 0.0145
# Epoch 18/1000
#  - 3s - loss: 0.3136 - raw_multi_label_accuracy: 0.0675 - val_loss: 0.3157 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 19/1000
#  - 3s - loss: 0.3136 - raw_multi_label_accuracy: 0.0729 - val_loss: 0.3162 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 20/1000
#  - 3s - loss: 0.3136 - raw_multi_label_accuracy: 0.1134 - val_loss: 0.3160 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 21/1000
#  - 3s - loss: 0.3128 - raw_multi_label_accuracy: 0.1006 - val_loss: 0.3159 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 22/1000
#  - 3s - loss: 0.3126 - raw_multi_label_accuracy: 0.0813 - val_loss: 0.3158 - val_raw_multi_label_accuracy: 0.1674
# Epoch 23/1000
#  - 3s - loss: 0.3127 - raw_multi_label_accuracy: 0.0930 - val_loss: 0.3150 - val_raw_multi_label_accuracy: 0.1676
# Epoch 24/1000
#  - 3s - loss: 0.3132 - raw_multi_label_accuracy: 0.1132 - val_loss: 0.3145 - val_raw_multi_label_accuracy: 0.1685
# Epoch 25/1000
#  - 3s - loss: 0.3125 - raw_multi_label_accuracy: 0.0982 - val_loss: 0.3137 - val_raw_multi_label_accuracy: 0.1674
# Epoch 26/1000
#  - 3s - loss: 0.3129 - raw_multi_label_accuracy: 0.0845 - val_loss: 0.3139 - val_raw_multi_label_accuracy: 0.1650
# Epoch 27/1000
#  - 3s - loss: 0.3125 - raw_multi_label_accuracy: 0.0959 - val_loss: 0.3157 - val_raw_multi_label_accuracy: 0.1676
# Epoch 28/1000
#  - 3s - loss: 0.3131 - raw_multi_label_accuracy: 0.0915 - val_loss: 0.3155 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 29/1000
#  - 3s - loss: 0.3130 - raw_multi_label_accuracy: 0.0978 - val_loss: 0.3143 - val_raw_multi_label_accuracy: 0.1697
# Epoch 30/1000
#  - 3s - loss: 0.3124 - raw_multi_label_accuracy: 0.1093 - val_loss: 0.3138 - val_raw_multi_label_accuracy: 0.1286
# Epoch 31/1000
#  - 2s - loss: 0.3127 - raw_multi_label_accuracy: 0.0914 - val_loss: 0.3159 - val_raw_multi_label_accuracy: 0.0580
# Epoch 32/1000
#  - 1s - loss: 0.3119 - raw_multi_label_accuracy: 0.1077 - val_loss: 0.3151 - val_raw_multi_label_accuracy: 0.1650
# Epoch 33/1000
#  - 1s - loss: 0.3122 - raw_multi_label_accuracy: 0.0904 - val_loss: 0.3139 - val_raw_multi_label_accuracy: 0.1628
# Epoch 34/1000
#  - 2s - loss: 0.3120 - raw_multi_label_accuracy: 0.1236 - val_loss: 0.3163 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 35/1000
#  - 2s - loss: 0.3125 - raw_multi_label_accuracy: 0.0920 - val_loss: 0.3143 - val_raw_multi_label_accuracy: 0.1539
# Epoch 36/1000
#  - 2s - loss: 0.3120 - raw_multi_label_accuracy: 0.0846 - val_loss: 0.3139 - val_raw_multi_label_accuracy: 0.0080
# Epoch 37/1000
#  - 2s - loss: 0.3119 - raw_multi_label_accuracy: 0.1207 - val_loss: 0.3151 - val_raw_multi_label_accuracy: 0.1688
# Epoch 38/1000
#  - 2s - loss: 0.3121 - raw_multi_label_accuracy: 0.0837 - val_loss: 0.3146 - val_raw_multi_label_accuracy: 0.1676
# Epoch 39/1000
#  - 1s - loss: 0.3121 - raw_multi_label_accuracy: 0.1004 - val_loss: 0.3140 - val_raw_multi_label_accuracy: 0.1688
# Epoch 40/1000
#  - 1s - loss: 0.3119 - raw_multi_label_accuracy: 0.1056 - val_loss: 0.3150 - val_raw_multi_label_accuracy: 0.1636
# Epoch 41/1000
#  - 1s - loss: 0.3118 - raw_multi_label_accuracy: 0.1070 - val_loss: 0.3148 - val_raw_multi_label_accuracy: 0.1650
# Epoch 42/1000
#  - 1s - loss: 0.3113 - raw_multi_label_accuracy: 0.0996 - val_loss: 0.3144 - val_raw_multi_label_accuracy: 0.1407
# Epoch 43/1000
#  - 1s - loss: 0.3121 - raw_multi_label_accuracy: 0.1452 - val_loss: 0.3160 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 44/1000
#  - 1s - loss: 0.3116 - raw_multi_label_accuracy: 0.0764 - val_loss: 0.3149 - val_raw_multi_label_accuracy: 0.1464
# Epoch 45/1000
#  - 1s - loss: 0.3116 - raw_multi_label_accuracy: 0.1238 - val_loss: 0.3152 - val_raw_multi_label_accuracy: 0.1662
# Epoch 46/1000
#  - 2s - loss: 0.3116 - raw_multi_label_accuracy: 0.0887 - val_loss: 0.3141 - val_raw_multi_label_accuracy: 0.1567
# Epoch 47/1000
#  - 2s - loss: 0.3113 - raw_multi_label_accuracy: 0.1445 - val_loss: 0.3161 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 48/1000
#  - 2s - loss: 0.3117 - raw_multi_label_accuracy: 0.0837 - val_loss: 0.3152 - val_raw_multi_label_accuracy: 0.0032
# Epoch 49/1000
#  - 2s - loss: 0.3114 - raw_multi_label_accuracy: 0.1353 - val_loss: 0.3141 - val_raw_multi_label_accuracy: 0.1627
# Epoch 50/1000
#  - 2s - loss: 0.3110 - raw_multi_label_accuracy: 0.1335 - val_loss: 0.3144 - val_raw_multi_label_accuracy: 0.0617
# Epoch 51/1000
#  - 1s - loss: 0.3107 - raw_multi_label_accuracy: 0.0954 - val_loss: 0.3142 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 52/1000
#  - 1s - loss: 0.3107 - raw_multi_label_accuracy: 0.0774 - val_loss: 0.3145 - val_raw_multi_label_accuracy: 0.0885
# Epoch 53/1000
#  - 2s - loss: 0.3115 - raw_multi_label_accuracy: 0.1052 - val_loss: 0.3142 - val_raw_multi_label_accuracy: 0.1071
# Epoch 54/1000
#  - 1s - loss: 0.3110 - raw_multi_label_accuracy: 0.0966 - val_loss: 0.3139 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 55/1000
#  - 2s - loss: 0.3109 - raw_multi_label_accuracy: 0.1098 - val_loss: 0.3140 - val_raw_multi_label_accuracy: 0.0703
# Epoch 56/1000
#  - 2s - loss: 0.3111 - raw_multi_label_accuracy: 0.0983 - val_loss: 0.3143 - val_raw_multi_label_accuracy: 0.1688
# Epoch 57/1000
#  - 1s - loss: 0.3103 - raw_multi_label_accuracy: 0.1058 - val_loss: 0.3141 - val_raw_multi_label_accuracy: 0.1648
# Epoch 58/1000
#  - 2s - loss: 0.3109 - raw_multi_label_accuracy: 0.0891 - val_loss: 0.3141 - val_raw_multi_label_accuracy: 0.0099
# Epoch 59/1000
#  - 2s - loss: 0.3113 - raw_multi_label_accuracy: 0.1052 - val_loss: 0.3142 - val_raw_multi_label_accuracy: 0.0513
# Epoch 60/1000
#  - 2s - loss: 0.3105 - raw_multi_label_accuracy: 0.1003 - val_loss: 0.3138 - val_raw_multi_label_accuracy: 0.1688
# Epoch 61/1000
#  - 1s - loss: 0.3102 - raw_multi_label_accuracy: 0.1326 - val_loss: 0.3138 - val_raw_multi_label_accuracy: 0.1030
# Epoch 62/1000
#  - 1s - loss: 0.3103 - raw_multi_label_accuracy: 0.1072 - val_loss: 0.3143 - val_raw_multi_label_accuracy: 0.0558
# Epoch 63/1000
#  - 1s - loss: 0.3103 - raw_multi_label_accuracy: 0.1304 - val_loss: 0.3153 - val_raw_multi_label_accuracy: 0.1648
# Epoch 64/1000
#  - 1s - loss: 0.3100 - raw_multi_label_accuracy: 0.1188 - val_loss: 0.3145 - val_raw_multi_label_accuracy: 0.1543
# Epoch 65/1000
#  - 1s - loss: 0.3101 - raw_multi_label_accuracy: 0.1264 - val_loss: 0.3139 - val_raw_multi_label_accuracy: 0.1685
# Epoch 66/1000
#  - 1s - loss: 0.3101 - raw_multi_label_accuracy: 0.0961 - val_loss: 0.3142 - val_raw_multi_label_accuracy: 0.1659
# Epoch 67/1000
#  - 2s - loss: 0.3098 - raw_multi_label_accuracy: 0.1586 - val_loss: 0.3144 - val_raw_multi_label_accuracy: 0.0527
# Epoch 68/1000
#  - 2s - loss: 0.3098 - raw_multi_label_accuracy: 0.0996 - val_loss: 0.3137 - val_raw_multi_label_accuracy: 0.1290
# Epoch 69/1000
#  - 1s - loss: 0.3099 - raw_multi_label_accuracy: 0.0850 - val_loss: 0.3166 - val_raw_multi_label_accuracy: 0.1652
# Epoch 70/1000
#  - 1s - loss: 0.3112 - raw_multi_label_accuracy: 0.0984 - val_loss: 0.3139 - val_raw_multi_label_accuracy: 0.0018
# Epoch 71/1000
#  - 1s - loss: 0.3106 - raw_multi_label_accuracy: 0.0975 - val_loss: 0.3141 - val_raw_multi_label_accuracy: 0.0996
# Epoch 72/1000
#  - 2s - loss: 0.3100 - raw_multi_label_accuracy: 0.1424 - val_loss: 0.3140 - val_raw_multi_label_accuracy: 0.0721
# Epoch 73/1000
#  - 2s - loss: 0.3095 - raw_multi_label_accuracy: 0.1085 - val_loss: 0.3138 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 74/1000
#  - 2s - loss: 0.3104 - raw_multi_label_accuracy: 0.0707 - val_loss: 0.3142 - val_raw_multi_label_accuracy: 0.0711
# Epoch 75/1000
#  - 2s - loss: 0.3097 - raw_multi_label_accuracy: 0.1392 - val_loss: 0.3146 - val_raw_multi_label_accuracy: 0.1231
# Epoch 76/1000
#  - 1s - loss: 0.3095 - raw_multi_label_accuracy: 0.1052 - val_loss: 0.3136 - val_raw_multi_label_accuracy: 0.1449
# Epoch 77/1000
#  - 2s - loss: 0.3094 - raw_multi_label_accuracy: 0.1149 - val_loss: 0.3145 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 78/1000
#  - 2s - loss: 0.3095 - raw_multi_label_accuracy: 0.1283 - val_loss: 0.3134 - val_raw_multi_label_accuracy: 0.0147
# Epoch 79/1000
#  - 1s - loss: 0.3091 - raw_multi_label_accuracy: 0.0883 - val_loss: 0.3138 - val_raw_multi_label_accuracy: 0.1671
# Epoch 80/1000
#  - 1s - loss: 0.3094 - raw_multi_label_accuracy: 0.1049 - val_loss: 0.3134 - val_raw_multi_label_accuracy: 0.1548
# Epoch 81/1000
#  - 1s - loss: 0.3091 - raw_multi_label_accuracy: 0.1390 - val_loss: 0.3136 - val_raw_multi_label_accuracy: 0.1598
# Epoch 82/1000
#  - 1s - loss: 0.3091 - raw_multi_label_accuracy: 0.1048 - val_loss: 0.3132 - val_raw_multi_label_accuracy: 0.1604
# Epoch 83/1000
#  - 1s - loss: 0.3098 - raw_multi_label_accuracy: 0.1089 - val_loss: 0.3149 - val_raw_multi_label_accuracy: 0.0579
# Epoch 84/1000
#  - 1s - loss: 0.3095 - raw_multi_label_accuracy: 0.1086 - val_loss: 0.3134 - val_raw_multi_label_accuracy: 0.1651
# Epoch 85/1000
#  - 1s - loss: 0.3091 - raw_multi_label_accuracy: 0.1130 - val_loss: 0.3132 - val_raw_multi_label_accuracy: 0.0065
# Epoch 86/1000
#  - 1s - loss: 0.3094 - raw_multi_label_accuracy: 0.1200 - val_loss: 0.3133 - val_raw_multi_label_accuracy: 0.0533
# Epoch 87/1000
#  - 1s - loss: 0.3090 - raw_multi_label_accuracy: 0.1013 - val_loss: 0.3136 - val_raw_multi_label_accuracy: 0.0474
# Epoch 88/1000
#  - 1s - loss: 0.3090 - raw_multi_label_accuracy: 0.1076 - val_loss: 0.3136 - val_raw_multi_label_accuracy: 0.1509
# Epoch 89/1000
#  - 1s - loss: 0.3087 - raw_multi_label_accuracy: 0.0878 - val_loss: 0.3138 - val_raw_multi_label_accuracy: 0.1212
# Epoch 90/1000
#  - 2s - loss: 0.3090 - raw_multi_label_accuracy: 0.1294 - val_loss: 0.3133 - val_raw_multi_label_accuracy: 0.1566
# Epoch 91/1000
#  - 1s - loss: 0.3088 - raw_multi_label_accuracy: 0.1384 - val_loss: 0.3138 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 92/1000
#  - 2s - loss: 0.3086 - raw_multi_label_accuracy: 0.0911 - val_loss: 0.3146 - val_raw_multi_label_accuracy: 0.1366
# Epoch 93/1000
#  - 3s - loss: 0.3093 - raw_multi_label_accuracy: 0.1049 - val_loss: 0.3131 - val_raw_multi_label_accuracy: 0.1549
# Epoch 94/1000
#  - 2s - loss: 0.3085 - raw_multi_label_accuracy: 0.1255 - val_loss: 0.3132 - val_raw_multi_label_accuracy: 0.0853
# Epoch 95/1000
#  - 1s - loss: 0.3084 - raw_multi_label_accuracy: 0.1250 - val_loss: 0.3171 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 96/1000
#  - 1s - loss: 0.3090 - raw_multi_label_accuracy: 0.1003 - val_loss: 0.3138 - val_raw_multi_label_accuracy: 0.0016
# Epoch 97/1000
#  - 1s - loss: 0.3085 - raw_multi_label_accuracy: 0.1181 - val_loss: 0.3129 - val_raw_multi_label_accuracy: 0.1226
# Epoch 98/1000
#  - 1s - loss: 0.3086 - raw_multi_label_accuracy: 0.0868 - val_loss: 0.3127 - val_raw_multi_label_accuracy: 0.1531
# Epoch 99/1000
#  - 1s - loss: 0.3084 - raw_multi_label_accuracy: 0.1170 - val_loss: 0.3130 - val_raw_multi_label_accuracy: 0.1180
# Epoch 100/1000
#  - 1s - loss: 0.3087 - raw_multi_label_accuracy: 0.0839 - val_loss: 0.3122 - val_raw_multi_label_accuracy: 0.1218
# Epoch 101/1000
#  - 1s - loss: 0.3082 - raw_multi_label_accuracy: 0.0909 - val_loss: 0.3128 - val_raw_multi_label_accuracy: 0.1644
# Epoch 102/1000
#  - 1s - loss: 0.3081 - raw_multi_label_accuracy: 0.1452 - val_loss: 0.3123 - val_raw_multi_label_accuracy: 0.1218
# Epoch 103/1000
#  - 1s - loss: 0.3091 - raw_multi_label_accuracy: 0.1149 - val_loss: 0.3126 - val_raw_multi_label_accuracy: 0.0957
# Epoch 104/1000
#  - 1s - loss: 0.3084 - raw_multi_label_accuracy: 0.1162 - val_loss: 0.3122 - val_raw_multi_label_accuracy: 0.0473
# Epoch 105/1000
#  - 1s - loss: 0.3083 - raw_multi_label_accuracy: 0.0985 - val_loss: 0.3124 - val_raw_multi_label_accuracy: 0.0488
# Epoch 106/1000
#  - 1s - loss: 0.3080 - raw_multi_label_accuracy: 0.1097 - val_loss: 0.3130 - val_raw_multi_label_accuracy: 0.1236
# Epoch 107/1000
#  - 1s - loss: 0.3080 - raw_multi_label_accuracy: 0.1219 - val_loss: 0.3131 - val_raw_multi_label_accuracy: 0.1574
# Epoch 108/1000
#  - 1s - loss: 0.3079 - raw_multi_label_accuracy: 0.0900 - val_loss: 0.3133 - val_raw_multi_label_accuracy: 0.1672
# Epoch 109/1000
#  - 1s - loss: 0.3079 - raw_multi_label_accuracy: 0.1120 - val_loss: 0.3133 - val_raw_multi_label_accuracy: 0.1302
# Epoch 110/1000
#  - 1s - loss: 0.3077 - raw_multi_label_accuracy: 0.0989 - val_loss: 0.3133 - val_raw_multi_label_accuracy: 0.1029
# Epoch 111/1000
#  - 1s - loss: 0.3078 - raw_multi_label_accuracy: 0.1356 - val_loss: 0.3124 - val_raw_multi_label_accuracy: 0.0065
# Epoch 112/1000
#  - 1s - loss: 0.3077 - raw_multi_label_accuracy: 0.1039 - val_loss: 0.3121 - val_raw_multi_label_accuracy: 0.0720
# Epoch 113/1000
#  - 1s - loss: 0.3071 - raw_multi_label_accuracy: 0.1122 - val_loss: 0.3122 - val_raw_multi_label_accuracy: 0.1593
# Epoch 114/1000
#  - 1s - loss: 0.3078 - raw_multi_label_accuracy: 0.1033 - val_loss: 0.3142 - val_raw_multi_label_accuracy: 0.1254
# Epoch 115/1000
#  - 1s - loss: 0.3074 - raw_multi_label_accuracy: 0.0879 - val_loss: 0.3118 - val_raw_multi_label_accuracy: 0.1528
# Epoch 116/1000
#  - 1s - loss: 0.3074 - raw_multi_label_accuracy: 0.1097 - val_loss: 0.3121 - val_raw_multi_label_accuracy: 0.1573
# Epoch 117/1000
#  - 2s - loss: 0.3073 - raw_multi_label_accuracy: 0.1178 - val_loss: 0.3125 - val_raw_multi_label_accuracy: 0.1194
# Epoch 118/1000
#  - 1s - loss: 0.3071 - raw_multi_label_accuracy: 0.0975 - val_loss: 0.3135 - val_raw_multi_label_accuracy: 0.0164
# Epoch 119/1000
#  - 1s - loss: 0.3072 - raw_multi_label_accuracy: 0.1174 - val_loss: 0.3120 - val_raw_multi_label_accuracy: 0.0571
# Epoch 120/1000
#  - 1s - loss: 0.3070 - raw_multi_label_accuracy: 0.1089 - val_loss: 0.3121 - val_raw_multi_label_accuracy: 0.0548
# Epoch 121/1000
#  - 2s - loss: 0.3069 - raw_multi_label_accuracy: 0.0912 - val_loss: 0.3116 - val_raw_multi_label_accuracy: 0.1542
# Epoch 122/1000
#  - 2s - loss: 0.3071 - raw_multi_label_accuracy: 0.0815 - val_loss: 0.3114 - val_raw_multi_label_accuracy: 0.1385
# Epoch 123/1000
#  - 2s - loss: 0.3077 - raw_multi_label_accuracy: 0.1351 - val_loss: 0.3118 - val_raw_multi_label_accuracy: 0.0860
# Epoch 124/1000
#  - 2s - loss: 0.3078 - raw_multi_label_accuracy: 0.1038 - val_loss: 0.3124 - val_raw_multi_label_accuracy: 0.0246
# Epoch 125/1000
#  - 2s - loss: 0.3076 - raw_multi_label_accuracy: 0.0770 - val_loss: 0.3115 - val_raw_multi_label_accuracy: 0.1503
# Epoch 126/1000
#  - 2s - loss: 0.3066 - raw_multi_label_accuracy: 0.1269 - val_loss: 0.3119 - val_raw_multi_label_accuracy: 0.0878
# Epoch 127/1000
#  - 2s - loss: 0.3067 - raw_multi_label_accuracy: 0.1021 - val_loss: 0.3115 - val_raw_multi_label_accuracy: 0.1127
# Epoch 128/1000
#  - 1s - loss: 0.3067 - raw_multi_label_accuracy: 0.1097 - val_loss: 0.3136 - val_raw_multi_label_accuracy: 0.0147
# Epoch 129/1000
#  - 1s - loss: 0.3069 - raw_multi_label_accuracy: 0.0906 - val_loss: 0.3116 - val_raw_multi_label_accuracy: 0.1390
# Epoch 130/1000
#  - 1s - loss: 0.3068 - raw_multi_label_accuracy: 0.1053 - val_loss: 0.3118 - val_raw_multi_label_accuracy: 0.1422
# Epoch 131/1000
#  - 1s - loss: 0.3064 - raw_multi_label_accuracy: 0.1315 - val_loss: 0.3137 - val_raw_multi_label_accuracy: 0.1317
# Epoch 132/1000
#  - 2s - loss: 0.3060 - raw_multi_label_accuracy: 0.1007 - val_loss: 0.3126 - val_raw_multi_label_accuracy: 0.1514
# Epoch 133/1000
#  - 2s - loss: 0.3057 - raw_multi_label_accuracy: 0.1316 - val_loss: 0.3130 - val_raw_multi_label_accuracy: 0.0495
# Epoch 134/1000
#  - 2s - loss: 0.3071 - raw_multi_label_accuracy: 0.1056 - val_loss: 0.3111 - val_raw_multi_label_accuracy: 0.0386
# Epoch 135/1000
#  - 2s - loss: 0.3064 - raw_multi_label_accuracy: 0.0925 - val_loss: 0.3112 - val_raw_multi_label_accuracy: 0.1189
# Epoch 136/1000
#  - 1s - loss: 0.3066 - raw_multi_label_accuracy: 0.1061 - val_loss: 0.3115 - val_raw_multi_label_accuracy: 0.0991
# Epoch 137/1000
#  - 1s - loss: 0.3067 - raw_multi_label_accuracy: 0.1047 - val_loss: 0.3114 - val_raw_multi_label_accuracy: 0.1239
# Epoch 138/1000
#  - 1s - loss: 0.3062 - raw_multi_label_accuracy: 0.0984 - val_loss: 0.3127 - val_raw_multi_label_accuracy: 0.1632
# Epoch 139/1000
#  - 1s - loss: 0.3068 - raw_multi_label_accuracy: 0.1271 - val_loss: 0.3119 - val_raw_multi_label_accuracy: 0.1097
# Epoch 140/1000
#  - 1s - loss: 0.3060 - raw_multi_label_accuracy: 0.1103 - val_loss: 0.3110 - val_raw_multi_label_accuracy: 0.1057
# Epoch 141/1000
#  - 1s - loss: 0.3056 - raw_multi_label_accuracy: 0.1218 - val_loss: 0.3118 - val_raw_multi_label_accuracy: 0.0563
# Epoch 142/1000
#  - 1s - loss: 0.3062 - raw_multi_label_accuracy: 0.1092 - val_loss: 0.3112 - val_raw_multi_label_accuracy: 0.1169
# Epoch 143/1000
#  - 1s - loss: 0.3062 - raw_multi_label_accuracy: 0.1073 - val_loss: 0.3119 - val_raw_multi_label_accuracy: 0.1429
# Epoch 144/1000
#  - 1s - loss: 0.3064 - raw_multi_label_accuracy: 0.1193 - val_loss: 0.3111 - val_raw_multi_label_accuracy: 0.1103
# Epoch 145/1000
#  - 1s - loss: 0.3055 - raw_multi_label_accuracy: 0.1151 - val_loss: 0.3118 - val_raw_multi_label_accuracy: 0.0893
# Epoch 146/1000
#  - 1s - loss: 0.3050 - raw_multi_label_accuracy: 0.1157 - val_loss: 0.3111 - val_raw_multi_label_accuracy: 0.1335
# Epoch 147/1000
#  - 1s - loss: 0.3050 - raw_multi_label_accuracy: 0.0908 - val_loss: 0.3117 - val_raw_multi_label_accuracy: 0.1278
# Epoch 148/1000
#  - 2s - loss: 0.3062 - raw_multi_label_accuracy: 0.1228 - val_loss: 0.3142 - val_raw_multi_label_accuracy: 0.0432
# Epoch 149/1000
#  - 2s - loss: 0.3064 - raw_multi_label_accuracy: 0.0968 - val_loss: 0.3122 - val_raw_multi_label_accuracy: 0.0165
# Epoch 150/1000
#  - 2s - loss: 0.3056 - raw_multi_label_accuracy: 0.0983 - val_loss: 0.3107 - val_raw_multi_label_accuracy: 0.1018
# Epoch 151/1000
#  - 2s - loss: 0.3048 - raw_multi_label_accuracy: 0.1131 - val_loss: 0.3104 - val_raw_multi_label_accuracy: 0.1271
# Epoch 152/1000
#  - 2s - loss: 0.3049 - raw_multi_label_accuracy: 0.1148 - val_loss: 0.3114 - val_raw_multi_label_accuracy: 0.1359
# Epoch 153/1000
#  - 1s - loss: 0.3050 - raw_multi_label_accuracy: 0.1231 - val_loss: 0.3122 - val_raw_multi_label_accuracy: 0.1380
# Epoch 154/1000
#  - 1s - loss: 0.3052 - raw_multi_label_accuracy: 0.1042 - val_loss: 0.3124 - val_raw_multi_label_accuracy: 0.1310
# Epoch 155/1000
#  - 1s - loss: 0.3044 - raw_multi_label_accuracy: 0.0988 - val_loss: 0.3109 - val_raw_multi_label_accuracy: 0.1441
# Epoch 156/1000
#  - 1s - loss: 0.3057 - raw_multi_label_accuracy: 0.1285 - val_loss: 0.3122 - val_raw_multi_label_accuracy: 0.1482
# Epoch 157/1000
#  - 1s - loss: 0.3051 - raw_multi_label_accuracy: 0.1040 - val_loss: 0.3111 - val_raw_multi_label_accuracy: 0.1362
# Epoch 158/1000
#  - 2s - loss: 0.3047 - raw_multi_label_accuracy: 0.1117 - val_loss: 0.3102 - val_raw_multi_label_accuracy: 0.1185
# Epoch 159/1000
#  - 2s - loss: 0.3045 - raw_multi_label_accuracy: 0.1032 - val_loss: 0.3106 - val_raw_multi_label_accuracy: 0.0444
# Epoch 160/1000
#  - 1s - loss: 0.3041 - raw_multi_label_accuracy: 0.1073 - val_loss: 0.3113 - val_raw_multi_label_accuracy: 0.0399
# Epoch 161/1000
#  - 1s - loss: 0.3049 - raw_multi_label_accuracy: 0.1130 - val_loss: 0.3123 - val_raw_multi_label_accuracy: 0.1517
# Epoch 162/1000
#  - 2s - loss: 0.3048 - raw_multi_label_accuracy: 0.1201 - val_loss: 0.3120 - val_raw_multi_label_accuracy: 0.1314
# Epoch 163/1000
#  - 2s - loss: 0.3036 - raw_multi_label_accuracy: 0.0995 - val_loss: 0.3114 - val_raw_multi_label_accuracy: 0.1469
# Epoch 164/1000
#  - 2s - loss: 0.3043 - raw_multi_label_accuracy: 0.1051 - val_loss: 0.3153 - val_raw_multi_label_accuracy: 0.1508
# Epoch 165/1000
#  - 2s - loss: 0.3045 - raw_multi_label_accuracy: 0.1141 - val_loss: 0.3111 - val_raw_multi_label_accuracy: 0.1313
# Epoch 166/1000
#  - 1s - loss: 0.3042 - raw_multi_label_accuracy: 0.1087 - val_loss: 0.3129 - val_raw_multi_label_accuracy: 0.0509
# Epoch 167/1000
#  - 1s - loss: 0.3048 - raw_multi_label_accuracy: 0.1174 - val_loss: 0.3106 - val_raw_multi_label_accuracy: 0.0784
# Epoch 168/1000
#  - 1s - loss: 0.3036 - raw_multi_label_accuracy: 0.1133 - val_loss: 0.3108 - val_raw_multi_label_accuracy: 0.0904
# Epoch 169/1000
#  - 2s - loss: 0.3035 - raw_multi_label_accuracy: 0.1129 - val_loss: 0.3105 - val_raw_multi_label_accuracy: 0.0941
# Epoch 170/1000
#  - 3s - loss: 0.3040 - raw_multi_label_accuracy: 0.1239 - val_loss: 0.3118 - val_raw_multi_label_accuracy: 0.0828
# Epoch 171/1000
#  - 2s - loss: 0.3049 - raw_multi_label_accuracy: 0.1159 - val_loss: 0.3111 - val_raw_multi_label_accuracy: 0.0341
# Epoch 172/1000
#  - 1s - loss: 0.3038 - raw_multi_label_accuracy: 0.1159 - val_loss: 0.3126 - val_raw_multi_label_accuracy: 0.0415
# Epoch 173/1000
#  - 1s - loss: 0.3031 - raw_multi_label_accuracy: 0.0953 - val_loss: 0.3098 - val_raw_multi_label_accuracy: 0.1200
# Epoch 174/1000
#  - 1s - loss: 0.3027 - raw_multi_label_accuracy: 0.1121 - val_loss: 0.3135 - val_raw_multi_label_accuracy: 0.1050
# Epoch 175/1000
#  - 1s - loss: 0.3040 - raw_multi_label_accuracy: 0.1253 - val_loss: 0.3118 - val_raw_multi_label_accuracy: 0.1655
# Epoch 176/1000
#  - 1s - loss: 0.3036 - raw_multi_label_accuracy: 0.1022 - val_loss: 0.3115 - val_raw_multi_label_accuracy: 0.1730
# Epoch 177/1000
#  - 1s - loss: 0.3027 - raw_multi_label_accuracy: 0.0924 - val_loss: 0.3135 - val_raw_multi_label_accuracy: 0.1784
# Epoch 178/1000
#  - 1s - loss: 0.3035 - raw_multi_label_accuracy: 0.1127 - val_loss: 0.3111 - val_raw_multi_label_accuracy: 0.1266
# Epoch 179/1000
#  - 1s - loss: 0.3025 - raw_multi_label_accuracy: 0.1085 - val_loss: 0.3101 - val_raw_multi_label_accuracy: 0.1648
# Epoch 180/1000
#  - 1s - loss: 0.3026 - raw_multi_label_accuracy: 0.1329 - val_loss: 0.3110 - val_raw_multi_label_accuracy: 0.0688
# Epoch 181/1000
#  - 1s - loss: 0.3029 - raw_multi_label_accuracy: 0.1034 - val_loss: 0.3129 - val_raw_multi_label_accuracy: 0.0338
# Epoch 182/1000
#  - 1s - loss: 0.3024 - raw_multi_label_accuracy: 0.1011 - val_loss: 0.3104 - val_raw_multi_label_accuracy: 0.1398
# Epoch 183/1000
#  - 1s - loss: 0.3028 - raw_multi_label_accuracy: 0.1277 - val_loss: 0.3108 - val_raw_multi_label_accuracy: 0.1226
# Epoch 184/1000
#  - 1s - loss: 0.3030 - raw_multi_label_accuracy: 0.1143 - val_loss: 0.3126 - val_raw_multi_label_accuracy: 0.1372
# Epoch 185/1000
#  - 1s - loss: 0.3028 - raw_multi_label_accuracy: 0.1021 - val_loss: 0.3148 - val_raw_multi_label_accuracy: 0.1242
# Epoch 186/1000
#  - 1s - loss: 0.3027 - raw_multi_label_accuracy: 0.1163 - val_loss: 0.3103 - val_raw_multi_label_accuracy: 0.1531
# Epoch 187/1000
#  - 1s - loss: 0.3019 - raw_multi_label_accuracy: 0.1177 - val_loss: 0.3118 - val_raw_multi_label_accuracy: 0.1502
# Epoch 188/1000
#  - 1s - loss: 0.3021 - raw_multi_label_accuracy: 0.1166 - val_loss: 0.3119 - val_raw_multi_label_accuracy: 0.0625
# Epoch 189/1000
#  - 1s - loss: 0.3020 - raw_multi_label_accuracy: 0.1184 - val_loss: 0.3099 - val_raw_multi_label_accuracy: 0.1291
# Epoch 190/1000
#  - 1s - loss: 0.3013 - raw_multi_label_accuracy: 0.1274 - val_loss: 0.3118 - val_raw_multi_label_accuracy: 0.0802
# Epoch 191/1000
#  - 2s - loss: 0.3016 - raw_multi_label_accuracy: 0.1210 - val_loss: 0.3128 - val_raw_multi_label_accuracy: 0.1667
# Epoch 192/1000
#  - 2s - loss: 0.3012 - raw_multi_label_accuracy: 0.1074 - val_loss: 0.3097 - val_raw_multi_label_accuracy: 0.1506
# Epoch 193/1000
#  - 2s - loss: 0.3010 - raw_multi_label_accuracy: 0.1185 - val_loss: 0.3109 - val_raw_multi_label_accuracy: 0.1389
# Epoch 194/1000
#  - 1s - loss: 0.3019 - raw_multi_label_accuracy: 0.1154 - val_loss: 0.3114 - val_raw_multi_label_accuracy: 0.0582
# Epoch 195/1000
#  - 1s - loss: 0.3015 - raw_multi_label_accuracy: 0.1227 - val_loss: 0.3116 - val_raw_multi_label_accuracy: 0.0307
# Epoch 196/1000
#  - 1s - loss: 0.3022 - raw_multi_label_accuracy: 0.1011 - val_loss: 0.3097 - val_raw_multi_label_accuracy: 0.0843
# Epoch 197/1000
#  - 1s - loss: 0.3013 - raw_multi_label_accuracy: 0.1009 - val_loss: 0.3117 - val_raw_multi_label_accuracy: 0.1779
# Epoch 198/1000
#  - 2s - loss: 0.3021 - raw_multi_label_accuracy: 0.1218 - val_loss: 0.3098 - val_raw_multi_label_accuracy: 0.1216
# Epoch 199/1000
#  - 2s - loss: 0.3013 - raw_multi_label_accuracy: 0.1184 - val_loss: 0.3123 - val_raw_multi_label_accuracy: 0.1217
# Epoch 200/1000
#  - 3s - loss: 0.3006 - raw_multi_label_accuracy: 0.1158 - val_loss: 0.3109 - val_raw_multi_label_accuracy: 0.1607
# Epoch 201/1000
#  - 2s - loss: 0.3005 - raw_multi_label_accuracy: 0.1249 - val_loss: 0.3105 - val_raw_multi_label_accuracy: 0.1207
# Epoch 202/1000
#  - 1s - loss: 0.3003 - raw_multi_label_accuracy: 0.1252 - val_loss: 0.3098 - val_raw_multi_label_accuracy: 0.1229
# Epoch 203/1000
#  - 1s - loss: 0.3015 - raw_multi_label_accuracy: 0.1104 - val_loss: 0.3114 - val_raw_multi_label_accuracy: 0.0401
# Epoch 204/1000
#  - 1s - loss: 0.3013 - raw_multi_label_accuracy: 0.1120 - val_loss: 0.3116 - val_raw_multi_label_accuracy: 0.0979
# Epoch 205/1000
#  - 1s - loss: 0.3017 - raw_multi_label_accuracy: 0.1190 - val_loss: 0.3112 - val_raw_multi_label_accuracy: 0.1629
# Epoch 206/1000
#  - 2s - loss: 0.3020 - raw_multi_label_accuracy: 0.1143 - val_loss: 0.3105 - val_raw_multi_label_accuracy: 0.1054
# Epoch 207/1000
#  - 2s - loss: 0.3010 - raw_multi_label_accuracy: 0.0934 - val_loss: 0.3110 - val_raw_multi_label_accuracy: 0.1427
# Epoch 208/1000
#  - 2s - loss: 0.3011 - raw_multi_label_accuracy: 0.1276 - val_loss: 0.3105 - val_raw_multi_label_accuracy: 0.0751
# Epoch 209/1000
#  - 1s - loss: 0.3014 - raw_multi_label_accuracy: 0.1163 - val_loss: 0.3106 - val_raw_multi_label_accuracy: 0.1133
# Epoch 210/1000
#  - 1s - loss: 0.3003 - raw_multi_label_accuracy: 0.1172 - val_loss: 0.3108 - val_raw_multi_label_accuracy: 0.0989
# Epoch 211/1000
#  - 1s - loss: 0.2995 - raw_multi_label_accuracy: 0.1239 - val_loss: 0.3102 - val_raw_multi_label_accuracy: 0.0784
# Epoch 212/1000
#  - 1s - loss: 0.2992 - raw_multi_label_accuracy: 0.1103 - val_loss: 0.3111 - val_raw_multi_label_accuracy: 0.1226
# Epoch 213/1000
#  - 1s - loss: 0.2998 - raw_multi_label_accuracy: 0.1299 - val_loss: 0.3108 - val_raw_multi_label_accuracy: 0.1307
# Epoch 214/1000
#  - 1s - loss: 0.2994 - raw_multi_label_accuracy: 0.1216 - val_loss: 0.3097 - val_raw_multi_label_accuracy: 0.1515
# Epoch 215/1000
#  - 1s - loss: 0.2996 - raw_multi_label_accuracy: 0.1231 - val_loss: 0.3104 - val_raw_multi_label_accuracy: 0.1203
# Epoch 216/1000
#  - 1s - loss: 0.2993 - raw_multi_label_accuracy: 0.1282 - val_loss: 0.3108 - val_raw_multi_label_accuracy: 0.0851
# Epoch 217/1000
#  - 1s - loss: 0.2994 - raw_multi_label_accuracy: 0.1067 - val_loss: 0.3105 - val_raw_multi_label_accuracy: 0.1048
# Epoch 218/1000
#  - 1s - loss: 0.2992 - raw_multi_label_accuracy: 0.1249 - val_loss: 0.3106 - val_raw_multi_label_accuracy: 0.1110
# Epoch 219/1000
#  - 1s - loss: 0.2995 - raw_multi_label_accuracy: 0.1150 - val_loss: 0.3136 - val_raw_multi_label_accuracy: 0.0694
# Epoch 220/1000
#  - 1s - loss: 0.3000 - raw_multi_label_accuracy: 0.1066 - val_loss: 0.3105 - val_raw_multi_label_accuracy: 0.1528
# Epoch 221/1000
#  - 1s - loss: 0.2985 - raw_multi_label_accuracy: 0.1301 - val_loss: 0.3133 - val_raw_multi_label_accuracy: 0.0646
# Epoch 222/1000
#  - 1s - loss: 0.3003 - raw_multi_label_accuracy: 0.1220 - val_loss: 0.3145 - val_raw_multi_label_accuracy: 0.0365
# Epoch 223/1000
#  - 1s - loss: 0.2988 - raw_multi_label_accuracy: 0.1150 - val_loss: 0.3118 - val_raw_multi_label_accuracy: 0.0448
# Epoch 224/1000
#  - 1s - loss: 0.2992 - raw_multi_label_accuracy: 0.1189 - val_loss: 0.3114 - val_raw_multi_label_accuracy: 0.1416
# Epoch 225/1000
#  - 1s - loss: 0.2998 - raw_multi_label_accuracy: 0.1190 - val_loss: 0.3137 - val_raw_multi_label_accuracy: 0.1715
# Epoch 226/1000
#  - 1s - loss: 0.2985 - raw_multi_label_accuracy: 0.1216 - val_loss: 0.3121 - val_raw_multi_label_accuracy: 0.1184
# Epoch 227/1000
#  - 1s - loss: 0.2985 - raw_multi_label_accuracy: 0.1240 - val_loss: 0.3108 - val_raw_multi_label_accuracy: 0.1046
# Epoch 228/1000
#  - 1s - loss: 0.2993 - raw_multi_label_accuracy: 0.1241 - val_loss: 0.3143 - val_raw_multi_label_accuracy: 0.0534
# Epoch 229/1000
#  - 1s - loss: 0.2980 - raw_multi_label_accuracy: 0.1120 - val_loss: 0.3115 - val_raw_multi_label_accuracy: 0.1146
# Epoch 230/1000
#  - 1s - loss: 0.2974 - raw_multi_label_accuracy: 0.1271 - val_loss: 0.3131 - val_raw_multi_label_accuracy: 0.0845
# Epoch 231/1000
#  - 1s - loss: 0.2974 - raw_multi_label_accuracy: 0.1300 - val_loss: 0.3142 - val_raw_multi_label_accuracy: 0.0384
# Epoch 232/1000
#  - 1s - loss: 0.2979 - raw_multi_label_accuracy: 0.1098 - val_loss: 0.3110 - val_raw_multi_label_accuracy: 0.1103
# Epoch 233/1000
#  - 1s - loss: 0.2981 - raw_multi_label_accuracy: 0.1246 - val_loss: 0.3117 - val_raw_multi_label_accuracy: 0.1579
# Epoch 234/1000
#  - 1s - loss: 0.2976 - raw_multi_label_accuracy: 0.1210 - val_loss: 0.3120 - val_raw_multi_label_accuracy: 0.1049
# Epoch 235/1000
#  - 1s - loss: 0.2971 - raw_multi_label_accuracy: 0.1240 - val_loss: 0.3115 - val_raw_multi_label_accuracy: 0.1304
# Epoch 236/1000
#  - 1s - loss: 0.2982 - raw_multi_label_accuracy: 0.1199 - val_loss: 0.3128 - val_raw_multi_label_accuracy: 0.1598
# Epoch 237/1000
#  - 1s - loss: 0.2970 - raw_multi_label_accuracy: 0.1232 - val_loss: 0.3113 - val_raw_multi_label_accuracy: 0.1085
# Epoch 238/1000
#  - 1s - loss: 0.2986 - raw_multi_label_accuracy: 0.1328 - val_loss: 0.3144 - val_raw_multi_label_accuracy: 0.1323
# Epoch 239/1000
#  - 1s - loss: 0.3001 - raw_multi_label_accuracy: 0.0972 - val_loss: 0.3126 - val_raw_multi_label_accuracy: 0.1712
# Epoch 240/1000
#  - 1s - loss: 0.2970 - raw_multi_label_accuracy: 0.1295 - val_loss: 0.3132 - val_raw_multi_label_accuracy: 0.1658
# Epoch 241/1000
#  - 1s - loss: 0.2970 - raw_multi_label_accuracy: 0.1245 - val_loss: 0.3130 - val_raw_multi_label_accuracy: 0.1250
# Epoch 242/1000
#  - 1s - loss: 0.2963 - raw_multi_label_accuracy: 0.1216 - val_loss: 0.3116 - val_raw_multi_label_accuracy: 0.1280
# Epoch 243/1000
#  - 1s - loss: 0.2974 - raw_multi_label_accuracy: 0.1309 - val_loss: 0.3110 - val_raw_multi_label_accuracy: 0.1037
# Epoch 244/1000
#  - 1s - loss: 0.2972 - raw_multi_label_accuracy: 0.1173 - val_loss: 0.3099 - val_raw_multi_label_accuracy: 0.1146
# Epoch 245/1000
#  - 1s - loss: 0.2962 - raw_multi_label_accuracy: 0.1360 - val_loss: 0.3122 - val_raw_multi_label_accuracy: 0.1084
# Epoch 246/1000
#  - 2s - loss: 0.2962 - raw_multi_label_accuracy: 0.1196 - val_loss: 0.3130 - val_raw_multi_label_accuracy: 0.1142
# Epoch 247/1000
#  - 2s - loss: 0.2966 - raw_multi_label_accuracy: 0.1320 - val_loss: 0.3126 - val_raw_multi_label_accuracy: 0.0966
# Epoch 248/1000
#  - 1s - loss: 0.2961 - raw_multi_label_accuracy: 0.1193 - val_loss: 0.3117 - val_raw_multi_label_accuracy: 0.1477
# Epoch 249/1000
#  - 1s - loss: 0.2962 - raw_multi_label_accuracy: 0.1269 - val_loss: 0.3109 - val_raw_multi_label_accuracy: 0.1320
# Epoch 250/1000
#  - 2s - loss: 0.2958 - raw_multi_label_accuracy: 0.1193 - val_loss: 0.3125 - val_raw_multi_label_accuracy: 0.1674
# Epoch 251/1000
#  - 2s - loss: 0.2975 - raw_multi_label_accuracy: 0.1271 - val_loss: 0.3124 - val_raw_multi_label_accuracy: 0.1618
# Epoch 252/1000
#  - 2s - loss: 0.2966 - raw_multi_label_accuracy: 0.1287 - val_loss: 0.3129 - val_raw_multi_label_accuracy: 0.0990
# Epoch 253/1000
#  - 2s - loss: 0.2957 - raw_multi_label_accuracy: 0.1222 - val_loss: 0.3131 - val_raw_multi_label_accuracy: 0.1358
# Epoch 254/1000
#  - 2s - loss: 0.2960 - raw_multi_label_accuracy: 0.1309 - val_loss: 0.3112 - val_raw_multi_label_accuracy: 0.1261
# Epoch 255/1000
#  - 1s - loss: 0.2958 - raw_multi_label_accuracy: 0.1192 - val_loss: 0.3113 - val_raw_multi_label_accuracy: 0.0985
# Epoch 256/1000
#  - 1s - loss: 0.2957 - raw_multi_label_accuracy: 0.1279 - val_loss: 0.3116 - val_raw_multi_label_accuracy: 0.1231
# Epoch 257/1000
#  - 1s - loss: 0.2958 - raw_multi_label_accuracy: 0.1292 - val_loss: 0.3141 - val_raw_multi_label_accuracy: 0.0834
# Epoch 258/1000
#  - 2s - loss: 0.2947 - raw_multi_label_accuracy: 0.1221 - val_loss: 0.3140 - val_raw_multi_label_accuracy: 0.0616
# Epoch 259/1000
#  - 1s - loss: 0.2946 - raw_multi_label_accuracy: 0.1188 - val_loss: 0.3136 - val_raw_multi_label_accuracy: 0.1049
# Epoch 260/1000
#  - 1s - loss: 0.2942 - raw_multi_label_accuracy: 0.1269 - val_loss: 0.3140 - val_raw_multi_label_accuracy: 0.0766
# Epoch 261/1000
#  - 1s - loss: 0.2943 - raw_multi_label_accuracy: 0.1197 - val_loss: 0.3129 - val_raw_multi_label_accuracy: 0.1145
# Epoch 262/1000
#  - 1s - loss: 0.2952 - raw_multi_label_accuracy: 0.1367 - val_loss: 0.3176 - val_raw_multi_label_accuracy: 0.1223
# Epoch 263/1000
#  - 1s - loss: 0.2955 - raw_multi_label_accuracy: 0.1343 - val_loss: 0.3126 - val_raw_multi_label_accuracy: 0.0607
# Epoch 264/1000
#  - 1s - loss: 0.2951 - raw_multi_label_accuracy: 0.1138 - val_loss: 0.3115 - val_raw_multi_label_accuracy: 0.1663
# Epoch 265/1000
#  - 1s - loss: 0.2951 - raw_multi_label_accuracy: 0.1413 - val_loss: 0.3125 - val_raw_multi_label_accuracy: 0.0866
# Epoch 266/1000
#  - 1s - loss: 0.2952 - raw_multi_label_accuracy: 0.1274 - val_loss: 0.3129 - val_raw_multi_label_accuracy: 0.1124
# Epoch 267/1000
#  - 1s - loss: 0.2954 - raw_multi_label_accuracy: 0.1166 - val_loss: 0.3153 - val_raw_multi_label_accuracy: 0.0955
# Epoch 268/1000
#  - 1s - loss: 0.2942 - raw_multi_label_accuracy: 0.1359 - val_loss: 0.3116 - val_raw_multi_label_accuracy: 0.1012
# Epoch 269/1000
#  - 1s - loss: 0.2945 - raw_multi_label_accuracy: 0.1205 - val_loss: 0.3142 - val_raw_multi_label_accuracy: 0.1687
# Epoch 270/1000
#  - 1s - loss: 0.2953 - raw_multi_label_accuracy: 0.1306 - val_loss: 0.3137 - val_raw_multi_label_accuracy: 0.0765
# Epoch 271/1000
#  - 2s - loss: 0.2940 - raw_multi_label_accuracy: 0.1167 - val_loss: 0.3126 - val_raw_multi_label_accuracy: 0.1622
# Epoch 272/1000
#  - 2s - loss: 0.2949 - raw_multi_label_accuracy: 0.1245 - val_loss: 0.3123 - val_raw_multi_label_accuracy: 0.1479
# Epoch 273/1000
#  - 1s - loss: 0.2937 - raw_multi_label_accuracy: 0.1288 - val_loss: 0.3125 - val_raw_multi_label_accuracy: 0.1505
# Epoch 274/1000
#  - 1s - loss: 0.2937 - raw_multi_label_accuracy: 0.1390 - val_loss: 0.3143 - val_raw_multi_label_accuracy: 0.0690
# Epoch 275/1000
#  - 1s - loss: 0.2935 - raw_multi_label_accuracy: 0.1246 - val_loss: 0.3132 - val_raw_multi_label_accuracy: 0.1273
# Epoch 276/1000
#  - 1s - loss: 0.2928 - raw_multi_label_accuracy: 0.1350 - val_loss: 0.3132 - val_raw_multi_label_accuracy: 0.0886
# Epoch 277/1000
#  - 1s - loss: 0.2932 - raw_multi_label_accuracy: 0.1261 - val_loss: 0.3151 - val_raw_multi_label_accuracy: 0.1160
# Epoch 278/1000
#  - 1s - loss: 0.2927 - raw_multi_label_accuracy: 0.1312 - val_loss: 0.3126 - val_raw_multi_label_accuracy: 0.1528
# Epoch 279/1000
#  - 1s - loss: 0.2931 - raw_multi_label_accuracy: 0.1377 - val_loss: 0.3129 - val_raw_multi_label_accuracy: 0.0749
# Epoch 280/1000
#  - 1s - loss: 0.2932 - raw_multi_label_accuracy: 0.1301 - val_loss: 0.3123 - val_raw_multi_label_accuracy: 0.1126
# Epoch 281/1000
#  - 1s - loss: 0.2934 - raw_multi_label_accuracy: 0.1307 - val_loss: 0.3144 - val_raw_multi_label_accuracy: 0.0672
# Epoch 282/1000
#  - 1s - loss: 0.2945 - raw_multi_label_accuracy: 0.1224 - val_loss: 0.3119 - val_raw_multi_label_accuracy: 0.1436
# Epoch 283/1000
#  - 1s - loss: 0.2928 - raw_multi_label_accuracy: 0.1322 - val_loss: 0.3106 - val_raw_multi_label_accuracy: 0.1125
# Epoch 284/1000
#  - 1s - loss: 0.2925 - raw_multi_label_accuracy: 0.1343 - val_loss: 0.3137 - val_raw_multi_label_accuracy: 0.0871
# Epoch 285/1000
#  - 1s - loss: 0.2942 - raw_multi_label_accuracy: 0.1215 - val_loss: 0.3167 - val_raw_multi_label_accuracy: 0.1280
# Epoch 286/1000
#  - 1s - loss: 0.2933 - raw_multi_label_accuracy: 0.1294 - val_loss: 0.3147 - val_raw_multi_label_accuracy: 0.1458
# Epoch 287/1000
#  - 1s - loss: 0.2927 - raw_multi_label_accuracy: 0.1280 - val_loss: 0.3126 - val_raw_multi_label_accuracy: 0.1506
# Epoch 288/1000
#  - 1s - loss: 0.2929 - raw_multi_label_accuracy: 0.1352 - val_loss: 0.3128 - val_raw_multi_label_accuracy: 0.1280
# Epoch 289/1000
#  - 1s - loss: 0.2916 - raw_multi_label_accuracy: 0.1397 - val_loss: 0.3132 - val_raw_multi_label_accuracy: 0.1339
# Epoch 290/1000
#  - 1s - loss: 0.2921 - raw_multi_label_accuracy: 0.1279 - val_loss: 0.3125 - val_raw_multi_label_accuracy: 0.1515
# Epoch 291/1000
#  - 1s - loss: 0.2938 - raw_multi_label_accuracy: 0.1399 - val_loss: 0.3139 - val_raw_multi_label_accuracy: 0.0808
# Epoch 292/1000
#  - 1s - loss: 0.2924 - raw_multi_label_accuracy: 0.1222 - val_loss: 0.3146 - val_raw_multi_label_accuracy: 0.1267
# Epoch 293/1000
#  - 1s - loss: 0.2914 - raw_multi_label_accuracy: 0.1470 - val_loss: 0.3146 - val_raw_multi_label_accuracy: 0.0626
# Epoch 294/1000
#  - 1s - loss: 0.2923 - raw_multi_label_accuracy: 0.1335 - val_loss: 0.3165 - val_raw_multi_label_accuracy: 0.0863
# Epoch 295/1000
#  - 1s - loss: 0.2914 - raw_multi_label_accuracy: 0.1282 - val_loss: 0.3130 - val_raw_multi_label_accuracy: 0.1432
# Epoch 296/1000
#  - 1s - loss: 0.2910 - raw_multi_label_accuracy: 0.1406 - val_loss: 0.3165 - val_raw_multi_label_accuracy: 0.0969
# Epoch 297/1000
#  - 1s - loss: 0.2919 - raw_multi_label_accuracy: 0.1353 - val_loss: 0.3129 - val_raw_multi_label_accuracy: 0.1143
# Epoch 298/1000
#  - 1s - loss: 0.2912 - raw_multi_label_accuracy: 0.1343 - val_loss: 0.3130 - val_raw_multi_label_accuracy: 0.1332
# Epoch 299/1000
#  - 2s - loss: 0.2923 - raw_multi_label_accuracy: 0.1367 - val_loss: 0.3153 - val_raw_multi_label_accuracy: 0.1227
# Epoch 300/1000
#  - 2s - loss: 0.2910 - raw_multi_label_accuracy: 0.1282 - val_loss: 0.3128 - val_raw_multi_label_accuracy: 0.1147
# Epoch 301/1000
#  - 1s - loss: 0.2911 - raw_multi_label_accuracy: 0.1375 - val_loss: 0.3120 - val_raw_multi_label_accuracy: 0.1155
# Epoch 302/1000
#  - 1s - loss: 0.2909 - raw_multi_label_accuracy: 0.1389 - val_loss: 0.3138 - val_raw_multi_label_accuracy: 0.0703
# Epoch 303/1000
#  - 1s - loss: 0.2907 - raw_multi_label_accuracy: 0.1438 - val_loss: 0.3144 - val_raw_multi_label_accuracy: 0.0982
# Epoch 304/1000
#  - 1s - loss: 0.2903 - raw_multi_label_accuracy: 0.1317 - val_loss: 0.3142 - val_raw_multi_label_accuracy: 0.1165
# Epoch 305/1000
#  - 2s - loss: 0.2903 - raw_multi_label_accuracy: 0.1355 - val_loss: 0.3151 - val_raw_multi_label_accuracy: 0.1114
# Epoch 306/1000
#  - 3s - loss: 0.2912 - raw_multi_label_accuracy: 0.1270 - val_loss: 0.3119 - val_raw_multi_label_accuracy: 0.1125
# Epoch 307/1000
#  - 3s - loss: 0.2908 - raw_multi_label_accuracy: 0.1452 - val_loss: 0.3133 - val_raw_multi_label_accuracy: 0.1241
# Epoch 308/1000
#  - 1s - loss: 0.2913 - raw_multi_label_accuracy: 0.1323 - val_loss: 0.3144 - val_raw_multi_label_accuracy: 0.1003
# Epoch 309/1000
#  - 2s - loss: 0.2895 - raw_multi_label_accuracy: 0.1396 - val_loss: 0.3136 - val_raw_multi_label_accuracy: 0.1422
# Epoch 310/1000
#  - 2s - loss: 0.2920 - raw_multi_label_accuracy: 0.1366 - val_loss: 0.3164 - val_raw_multi_label_accuracy: 0.0677
# Epoch 311/1000
#  - 2s - loss: 0.2903 - raw_multi_label_accuracy: 0.1363 - val_loss: 0.3131 - val_raw_multi_label_accuracy: 0.1269
# Epoch 312/1000
#  - 2s - loss: 0.2889 - raw_multi_label_accuracy: 0.1445 - val_loss: 0.3140 - val_raw_multi_label_accuracy: 0.1264
# Epoch 313/1000
#  - 2s - loss: 0.2899 - raw_multi_label_accuracy: 0.1320 - val_loss: 0.3124 - val_raw_multi_label_accuracy: 0.1243
# Epoch 314/1000
#  - 2s - loss: 0.2895 - raw_multi_label_accuracy: 0.1466 - val_loss: 0.3137 - val_raw_multi_label_accuracy: 0.1178
# Epoch 315/1000
#  - 2s - loss: 0.2887 - raw_multi_label_accuracy: 0.1447 - val_loss: 0.3150 - val_raw_multi_label_accuracy: 0.1367
# Epoch 316/1000
#  - 2s - loss: 0.2892 - raw_multi_label_accuracy: 0.1300 - val_loss: 0.3154 - val_raw_multi_label_accuracy: 0.1555
# Epoch 317/1000
#  - 2s - loss: 0.2893 - raw_multi_label_accuracy: 0.1422 - val_loss: 0.3142 - val_raw_multi_label_accuracy: 0.1412
# Epoch 318/1000
#  - 2s - loss: 0.2882 - raw_multi_label_accuracy: 0.1418 - val_loss: 0.3130 - val_raw_multi_label_accuracy: 0.1446
# Epoch 319/1000
#  - 2s - loss: 0.2895 - raw_multi_label_accuracy: 0.1420 - val_loss: 0.3148 - val_raw_multi_label_accuracy: 0.1039
# Epoch 320/1000
#  - 2s - loss: 0.2892 - raw_multi_label_accuracy: 0.1369 - val_loss: 0.3154 - val_raw_multi_label_accuracy: 0.1478
# Epoch 321/1000
#  - 1s - loss: 0.2885 - raw_multi_label_accuracy: 0.1438 - val_loss: 0.3148 - val_raw_multi_label_accuracy: 0.1055
# Epoch 322/1000
#  - 1s - loss: 0.2881 - raw_multi_label_accuracy: 0.1404 - val_loss: 0.3153 - val_raw_multi_label_accuracy: 0.1195
# Epoch 323/1000
#  - 1s - loss: 0.2885 - raw_multi_label_accuracy: 0.1387 - val_loss: 0.3175 - val_raw_multi_label_accuracy: 0.1084
# Epoch 324/1000
#  - 1s - loss: 0.2893 - raw_multi_label_accuracy: 0.1392 - val_loss: 0.3127 - val_raw_multi_label_accuracy: 0.1280
# Epoch 325/1000
#  - 1s - loss: 0.2896 - raw_multi_label_accuracy: 0.1500 - val_loss: 0.3140 - val_raw_multi_label_accuracy: 0.1098
# Epoch 326/1000
#  - 1s - loss: 0.2881 - raw_multi_label_accuracy: 0.1495 - val_loss: 0.3188 - val_raw_multi_label_accuracy: 0.0839
# Epoch 327/1000
#  - 1s - loss: 0.2883 - raw_multi_label_accuracy: 0.1419 - val_loss: 0.3173 - val_raw_multi_label_accuracy: 0.1122
# Epoch 328/1000
#  - 3s - loss: 0.2876 - raw_multi_label_accuracy: 0.1550 - val_loss: 0.3132 - val_raw_multi_label_accuracy: 0.1144
# Epoch 329/1000
#  - 3s - loss: 0.2869 - raw_multi_label_accuracy: 0.1468 - val_loss: 0.3174 - val_raw_multi_label_accuracy: 0.1301
# Epoch 330/1000
#  - 3s - loss: 0.2886 - raw_multi_label_accuracy: 0.1553 - val_loss: 0.3143 - val_raw_multi_label_accuracy: 0.0930
# Epoch 331/1000
#  - 3s - loss: 0.2883 - raw_multi_label_accuracy: 0.1321 - val_loss: 0.3222 - val_raw_multi_label_accuracy: 0.0820
# Epoch 332/1000
#  - 3s - loss: 0.2894 - raw_multi_label_accuracy: 0.1419 - val_loss: 0.3144 - val_raw_multi_label_accuracy: 0.1242
# Epoch 333/1000
#  - 3s - loss: 0.2889 - raw_multi_label_accuracy: 0.1457 - val_loss: 0.3193 - val_raw_multi_label_accuracy: 0.1334
# Epoch 334/1000
#  - 3s - loss: 0.2889 - raw_multi_label_accuracy: 0.1365 - val_loss: 0.3132 - val_raw_multi_label_accuracy: 0.1326
# Epoch 335/1000
#  - 3s - loss: 0.2878 - raw_multi_label_accuracy: 0.1498 - val_loss: 0.3137 - val_raw_multi_label_accuracy: 0.1181
# Epoch 336/1000
#  - 3s - loss: 0.2871 - raw_multi_label_accuracy: 0.1417 - val_loss: 0.3144 - val_raw_multi_label_accuracy: 0.0986
# Epoch 337/1000
#  - 3s - loss: 0.2870 - raw_multi_label_accuracy: 0.1472 - val_loss: 0.3156 - val_raw_multi_label_accuracy: 0.1192
# Epoch 338/1000
#  - 3s - loss: 0.2865 - raw_multi_label_accuracy: 0.1496 - val_loss: 0.3193 - val_raw_multi_label_accuracy: 0.0962
# Epoch 339/1000
#  - 3s - loss: 0.2870 - raw_multi_label_accuracy: 0.1490 - val_loss: 0.3177 - val_raw_multi_label_accuracy: 0.0795
# Epoch 340/1000
#  - 3s - loss: 0.2863 - raw_multi_label_accuracy: 0.1515 - val_loss: 0.3178 - val_raw_multi_label_accuracy: 0.1087
# Epoch 341/1000
#  - 3s - loss: 0.2876 - raw_multi_label_accuracy: 0.1492 - val_loss: 0.3158 - val_raw_multi_label_accuracy: 0.1403
# Epoch 342/1000
#  - 2s - loss: 0.2866 - raw_multi_label_accuracy: 0.1537 - val_loss: 0.3139 - val_raw_multi_label_accuracy: 0.1326
# Epoch 343/1000
#  - 3s - loss: 0.2872 - raw_multi_label_accuracy: 0.1399 - val_loss: 0.3184 - val_raw_multi_label_accuracy: 0.1089
# Epoch 344/1000
#  - 2s - loss: 0.2855 - raw_multi_label_accuracy: 0.1463 - val_loss: 0.3157 - val_raw_multi_label_accuracy: 0.1482
# Epoch 345/1000
#  - 3s - loss: 0.2858 - raw_multi_label_accuracy: 0.1497 - val_loss: 0.3168 - val_raw_multi_label_accuracy: 0.0948
# Epoch 346/1000
#  - 3s - loss: 0.2855 - raw_multi_label_accuracy: 0.1507 - val_loss: 0.3159 - val_raw_multi_label_accuracy: 0.1144
# Epoch 347/1000
#  - 3s - loss: 0.2848 - raw_multi_label_accuracy: 0.1476 - val_loss: 0.3158 - val_raw_multi_label_accuracy: 0.1237
# Epoch 348/1000
#  - 3s - loss: 0.2860 - raw_multi_label_accuracy: 0.1492 - val_loss: 0.3176 - val_raw_multi_label_accuracy: 0.1614
# Epoch 349/1000
#  - 3s - loss: 0.2858 - raw_multi_label_accuracy: 0.1467 - val_loss: 0.3181 - val_raw_multi_label_accuracy: 0.1385
# Epoch 350/1000
#  - 3s - loss: 0.2860 - raw_multi_label_accuracy: 0.1643 - val_loss: 0.3148 - val_raw_multi_label_accuracy: 0.1250
# Epoch 351/1000
#  - 3s - loss: 0.2851 - raw_multi_label_accuracy: 0.1482 - val_loss: 0.3160 - val_raw_multi_label_accuracy: 0.1041
# Epoch 352/1000
#  - 3s - loss: 0.2845 - raw_multi_label_accuracy: 0.1579 - val_loss: 0.3155 - val_raw_multi_label_accuracy: 0.1065
# Epoch 353/1000
#  - 3s - loss: 0.2842 - raw_multi_label_accuracy: 0.1579 - val_loss: 0.3176 - val_raw_multi_label_accuracy: 0.1220
# Epoch 354/1000
#  - 3s - loss: 0.2863 - raw_multi_label_accuracy: 0.1462 - val_loss: 0.3173 - val_raw_multi_label_accuracy: 0.1039
# Epoch 355/1000
#  - 3s - loss: 0.2856 - raw_multi_label_accuracy: 0.1520 - val_loss: 0.3163 - val_raw_multi_label_accuracy: 0.1524
# Epoch 356/1000
#  - 3s - loss: 0.2853 - raw_multi_label_accuracy: 0.1543 - val_loss: 0.3162 - val_raw_multi_label_accuracy: 0.1296
# Epoch 357/1000
#  - 2s - loss: 0.2847 - raw_multi_label_accuracy: 0.1492 - val_loss: 0.3164 - val_raw_multi_label_accuracy: 0.1212
# Epoch 358/1000
#  - 2s - loss: 0.2847 - raw_multi_label_accuracy: 0.1507 - val_loss: 0.3181 - val_raw_multi_label_accuracy: 0.1580
# Epoch 359/1000
#  - 2s - loss: 0.2856 - raw_multi_label_accuracy: 0.1512 - val_loss: 0.3181 - val_raw_multi_label_accuracy: 0.1090
# Epoch 360/1000
#  - 3s - loss: 0.2845 - raw_multi_label_accuracy: 0.1595 - val_loss: 0.3166 - val_raw_multi_label_accuracy: 0.1117
# Epoch 361/1000
#  - 3s - loss: 0.2833 - raw_multi_label_accuracy: 0.1476 - val_loss: 0.3168 - val_raw_multi_label_accuracy: 0.1469
# Epoch 362/1000
#  - 3s - loss: 0.2835 - raw_multi_label_accuracy: 0.1627 - val_loss: 0.3180 - val_raw_multi_label_accuracy: 0.0961
# Epoch 363/1000
#  - 2s - loss: 0.2849 - raw_multi_label_accuracy: 0.1600 - val_loss: 0.3194 - val_raw_multi_label_accuracy: 0.0961
# Epoch 364/1000
#  - 3s - loss: 0.2839 - raw_multi_label_accuracy: 0.1517 - val_loss: 0.3192 - val_raw_multi_label_accuracy: 0.1191
# Epoch 365/1000
#  - 2s - loss: 0.2836 - raw_multi_label_accuracy: 0.1596 - val_loss: 0.3170 - val_raw_multi_label_accuracy: 0.1116
# Epoch 366/1000
# ...
# Epoch 381/1000
#  - 2s - loss: 0.2808 - raw_multi_label_accuracy: 0.1620 - val_loss: 0.3204 - val_raw_multi_label_accuracy: 0.1525
# Epoch 382/1000
#  - 2s - loss: 0.2809 - raw_multi_label_accuracy: 0.1609 - val_loss: 0.3176 - val_raw_multi_label_accuracy: 0.1096
# Epoch 383/1000
#  - 2s - loss: 0.2813 - raw_multi_label_accuracy: 0.1595 - val_loss: 0.3172 - val_raw_multi_label_accuracy: 0.1219
# Epoch 384/1000
#  - 2s - loss: 0.2814 - raw_multi_label_accuracy: 0.1669 - val_loss: 0.3176 - val_raw_multi_label_accuracy: 0.1492
# Epoch 385/1000
#  - 1s - loss: 0.2820 - raw_multi_label_accuracy: 0.1600 - val_loss: 0.3188 - val_raw_multi_label_accuracy: 0.1201
# Epoch 386/1000
#  - 1s - loss: 0.2809 - raw_multi_label_accuracy: 0.1637 - val_loss: 0.3205 - val_raw_multi_label_accuracy: 0.1575
# Epoch 387/1000
#  - 1s - loss: 0.2832 - raw_multi_label_accuracy: 0.1614 - val_loss: 0.3215 - val_raw_multi_label_accuracy: 0.0646
# Epoch 388/1000
#  - 2s - loss: 0.2814 - raw_multi_label_accuracy: 0.1568 - val_loss: 0.3188 - val_raw_multi_label_accuracy: 0.1183
# Epoch 389/1000
#  - 2s - loss: 0.2819 - raw_multi_label_accuracy: 0.1638 - val_loss: 0.3181 - val_raw_multi_label_accuracy: 0.1250
# Epoch 390/1000
#  - 3s - loss: 0.2803 - raw_multi_label_accuracy: 0.1673 - val_loss: 0.3186 - val_raw_multi_label_accuracy: 0.1302
# Epoch 391/1000
#  - 3s - loss: 0.2796 - raw_multi_label_accuracy: 0.1661 - val_loss: 0.3195 - val_raw_multi_label_accuracy: 0.1215
# Epoch 392/1000
#  - 1s - loss: 0.2810 - raw_multi_label_accuracy: 0.1595 - val_loss: 0.3192 - val_raw_multi_label_accuracy: 0.1342
# Epoch 393/1000
#  - 2s - loss: 0.2812 - raw_multi_label_accuracy: 0.1652 - val_loss: 0.3188 - val_raw_multi_label_accuracy: 0.1242
# Epoch 394/1000
#  - 3s - loss: 0.2815 - raw_multi_label_accuracy: 0.1643 - val_loss: 0.3236 - val_raw_multi_label_accuracy: 0.1357
# Epoch 395/1000
#  - 2s - loss: 0.2800 - raw_multi_label_accuracy: 0.1662 - val_loss: 0.3180 - val_raw_multi_label_accuracy: 0.1176
# Epoch 396/1000
#  - 2s - loss: 0.2792 - raw_multi_label_accuracy: 0.1616 - val_loss: 0.3210 - val_raw_multi_label_accuracy: 0.1395
# Epoch 397/1000
#  - 3s - loss: 0.2795 - raw_multi_label_accuracy: 0.1645 - val_loss: 0.3212 - val_raw_multi_label_accuracy: 0.1057
# Epoch 398/1000
#  - 1s - loss: 0.2789 - raw_multi_label_accuracy: 0.1622 - val_loss: 0.3204 - val_raw_multi_label_accuracy: 0.1316
# Epoch 399/1000
#  - 1s - loss: 0.2794 - raw_multi_label_accuracy: 0.1750 - val_loss: 0.3239 - val_raw_multi_label_accuracy: 0.1183
# Epoch 400/1000
#  - 2s - loss: 0.2788 - raw_multi_label_accuracy: 0.1645 - val_loss: 0.3206 - val_raw_multi_label_accuracy: 0.1233
# Epoch 401/1000
#  - 2s - loss: 0.2791 - raw_multi_label_accuracy: 0.1643 - val_loss: 0.3192 - val_raw_multi_label_accuracy: 0.1321
# Epoch 402/1000
#  - 1s - loss: 0.2786 - raw_multi_label_accuracy: 0.1731 - val_loss: 0.3211 - val_raw_multi_label_accuracy: 0.1393
# Epoch 403/1000
#  - 1s - loss: 0.2798 - raw_multi_label_accuracy: 0.1692 - val_loss: 0.3225 - val_raw_multi_label_accuracy: 0.1278
# Epoch 404/1000
#  - 1s - loss: 0.2778 - raw_multi_label_accuracy: 0.1705 - val_loss: 0.3206 - val_raw_multi_label_accuracy: 0.1140
# Epoch 405/1000
#  - 2s - loss: 0.2781 - raw_multi_label_accuracy: 0.1698 - val_loss: 0.3206 - val_raw_multi_label_accuracy: 0.1207
# Epoch 406/1000
#  - 2s - loss: 0.2769 - raw_multi_label_accuracy: 0.1730 - val_loss: 0.3220 - val_raw_multi_label_accuracy: 0.1184
# Epoch 407/1000
#  - 1s - loss: 0.2778 - raw_multi_label_accuracy: 0.1701 - val_loss: 0.3188 - val_raw_multi_label_accuracy: 0.1199
# Epoch 408/1000
#  - 2s - loss: 0.2777 - raw_multi_label_accuracy: 0.1688 - val_loss: 0.3211 - val_raw_multi_label_accuracy: 0.1106
# Epoch 409/1000
#  - 3s - loss: 0.2774 - raw_multi_label_accuracy: 0.1688 - val_loss: 0.3242 - val_raw_multi_label_accuracy: 0.1678
# Epoch 410/1000
#  - 3s - loss: 0.2790 - raw_multi_label_accuracy: 0.1739 - val_loss: 0.3241 - val_raw_multi_label_accuracy: 0.1035
# Epoch 411/1000
#  - 2s - loss: 0.2768 - raw_multi_label_accuracy: 0.1750 - val_loss: 0.3203 - val_raw_multi_label_accuracy: 0.1179
# Epoch 412/1000
#  - 2s - loss: 0.2766 - raw_multi_label_accuracy: 0.1700 - val_loss: 0.3208 - val_raw_multi_label_accuracy: 0.1239
# Epoch 413/1000
#  - 1s - loss: 0.2769 - raw_multi_label_accuracy: 0.1711 - val_loss: 0.3223 - val_raw_multi_label_accuracy: 0.1597
# Epoch 414/1000
#  - 1s - loss: 0.2775 - raw_multi_label_accuracy: 0.1772 - val_loss: 0.3246 - val_raw_multi_label_accuracy: 0.1551
# Epoch 415/1000
#  - 1s - loss: 0.2772 - raw_multi_label_accuracy: 0.1687 - val_loss: 0.3226 - val_raw_multi_label_accuracy: 0.1230
# Epoch 416/1000
#  - 1s - loss: 0.2764 - raw_multi_label_accuracy: 0.1731 - val_loss: 0.3223 - val_raw_multi_label_accuracy: 0.1208
# Epoch 417/1000
#  - 1s - loss: 0.2761 - raw_multi_label_accuracy: 0.1777 - val_loss: 0.3253 - val_raw_multi_label_accuracy: 0.1100
# Epoch 418/1000
#  - 1s - loss: 0.2787 - raw_multi_label_accuracy: 0.1754 - val_loss: 0.3229 - val_raw_multi_label_accuracy: 0.1457
# Epoch 419/1000
#  - 2s - loss: 0.2772 - raw_multi_label_accuracy: 0.1738 - val_loss: 0.3240 - val_raw_multi_label_accuracy: 0.1058
# Epoch 420/1000
#  - 1s - loss: 0.2760 - raw_multi_label_accuracy: 0.1761 - val_loss: 0.3220 - val_raw_multi_label_accuracy: 0.1380
# Epoch 421/1000
#  - 1s - loss: 0.2750 - raw_multi_label_accuracy: 0.1737 - val_loss: 0.3246 - val_raw_multi_label_accuracy: 0.1143
# Epoch 422/1000
#  - 1s - loss: 0.2764 - raw_multi_label_accuracy: 0.1744 - val_loss: 0.3226 - val_raw_multi_label_accuracy: 0.1347
# Epoch 423/1000
#  - 1s - loss: 0.2781 - raw_multi_label_accuracy: 0.1788 - val_loss: 0.3262 - val_raw_multi_label_accuracy: 0.1216
# Epoch 424/1000
#  - 1s - loss: 0.2756 - raw_multi_label_accuracy: 0.1760 - val_loss: 0.3229 - val_raw_multi_label_accuracy: 0.1473
# Epoch 425/1000
#  - 1s - loss: 0.2741 - raw_multi_label_accuracy: 0.1768 - val_loss: 0.3246 - val_raw_multi_label_accuracy: 0.1127
# Epoch 426/1000
#  - 1s - loss: 0.2749 - raw_multi_label_accuracy: 0.1741 - val_loss: 0.3233 - val_raw_multi_label_accuracy: 0.1138
# Epoch 427/1000
#  - 1s - loss: 0.2752 - raw_multi_label_accuracy: 0.1865 - val_loss: 0.3261 - val_raw_multi_label_accuracy: 0.1365
# Epoch 428/1000
#  - 1s - loss: 0.2743 - raw_multi_label_accuracy: 0.1808 - val_loss: 0.3234 - val_raw_multi_label_accuracy: 0.1161
# Epoch 429/1000
#  - 1s - loss: 0.2753 - raw_multi_label_accuracy: 0.1836 - val_loss: 0.3258 - val_raw_multi_label_accuracy: 0.1139
# Epoch 430/1000
#  - 1s - loss: 0.2768 - raw_multi_label_accuracy: 0.1705 - val_loss: 0.3244 - val_raw_multi_label_accuracy: 0.1164
# Epoch 431/1000
#  - 1s - loss: 0.2754 - raw_multi_label_accuracy: 0.1875 - val_loss: 0.3245 - val_raw_multi_label_accuracy: 0.1014
# Epoch 432/1000
#  - 2s - loss: 0.2741 - raw_multi_label_accuracy: 0.1816 - val_loss: 0.3232 - val_raw_multi_label_accuracy: 0.1351
# Epoch 433/1000
#  - 2s - loss: 0.2735 - raw_multi_label_accuracy: 0.1829 - val_loss: 0.3265 - val_raw_multi_label_accuracy: 0.1363
# Epoch 434/1000
#  - 2s - loss: 0.2745 - raw_multi_label_accuracy: 0.1815 - val_loss: 0.3246 - val_raw_multi_label_accuracy: 0.1431
# Epoch 435/1000
#  - 2s - loss: 0.2736 - raw_multi_label_accuracy: 0.1878 - val_loss: 0.3272 - val_raw_multi_label_accuracy: 0.1152
# Epoch 436/1000
#  - 1s - loss: 0.2732 - raw_multi_label_accuracy: 0.1844 - val_loss: 0.3277 - val_raw_multi_label_accuracy: 0.1069
# Epoch 437/1000
#  - 1s - loss: 0.2718 - raw_multi_label_accuracy: 0.1874 - val_loss: 0.3280 - val_raw_multi_label_accuracy: 0.1387
# Epoch 438/1000
#  - 1s - loss: 0.2726 - raw_multi_label_accuracy: 0.1912 - val_loss: 0.3243 - val_raw_multi_label_accuracy: 0.1136
# Epoch 439/1000
#  - 1s - loss: 0.2724 - raw_multi_label_accuracy: 0.1853 - val_loss: 0.3262 - val_raw_multi_label_accuracy: 0.1061
# Epoch 440/1000
#  - 1s - loss: 0.2728 - raw_multi_label_accuracy: 0.1847 - val_loss: 0.3265 - val_raw_multi_label_accuracy: 0.1295
# Epoch 441/1000
#  - 1s - loss: 0.2732 - raw_multi_label_accuracy: 0.1884 - val_loss: 0.3410 - val_raw_multi_label_accuracy: 0.1383
# Epoch 442/1000
#  - 1s - loss: 0.2740 - raw_multi_label_accuracy: 0.1890 - val_loss: 0.3245 - val_raw_multi_label_accuracy: 0.1315
# Epoch 443/1000
#  - 1s - loss: 0.2724 - raw_multi_label_accuracy: 0.1835 - val_loss: 0.3274 - val_raw_multi_label_accuracy: 0.1358
# Epoch 444/1000
#  - 1s - loss: 0.2716 - raw_multi_label_accuracy: 0.1857 - val_loss: 0.3248 - val_raw_multi_label_accuracy: 0.1306
# Epoch 445/1000
#  - 1s - loss: 0.2707 - raw_multi_label_accuracy: 0.1922 - val_loss: 0.3273 - val_raw_multi_label_accuracy: 0.1251
# Epoch 446/1000
#  - 2s - loss: 0.2712 - raw_multi_label_accuracy: 0.1835 - val_loss: 0.3275 - val_raw_multi_label_accuracy: 0.1329
# Epoch 447/1000
#  - 1s - loss: 0.2734 - raw_multi_label_accuracy: 0.1875 - val_loss: 0.3290 - val_raw_multi_label_accuracy: 0.1350
# Epoch 448/1000
#  - 2s - loss: 0.2742 - raw_multi_label_accuracy: 0.1875 - val_loss: 0.3266 - val_raw_multi_label_accuracy: 0.1224
# Epoch 449/1000
#  - 1s - loss: 0.2725 - raw_multi_label_accuracy: 0.1838 - val_loss: 0.3298 - val_raw_multi_label_accuracy: 0.1207
# Epoch 450/1000
#  - 1s - loss: 0.2736 - raw_multi_label_accuracy: 0.1938 - val_loss: 0.3344 - val_raw_multi_label_accuracy: 0.0643
# Epoch 451/1000
#  - 1s - loss: 0.2724 - raw_multi_label_accuracy: 0.1832 - val_loss: 0.3266 - val_raw_multi_label_accuracy: 0.1330
# Epoch 452/1000
#  - 1s - loss: 0.2719 - raw_multi_label_accuracy: 0.1832 - val_loss: 0.3266 - val_raw_multi_label_accuracy: 0.1208
# Epoch 453/1000
#  - 1s - loss: 0.2707 - raw_multi_label_accuracy: 0.1900 - val_loss: 0.3249 - val_raw_multi_label_accuracy: 0.1296
# Epoch 454/1000
#  - 1s - loss: 0.2705 - raw_multi_label_accuracy: 0.1959 - val_loss: 0.3280 - val_raw_multi_label_accuracy: 0.1465
# Epoch 455/1000
#  - 1s - loss: 0.2706 - raw_multi_label_accuracy: 0.1933 - val_loss: 0.3295 - val_raw_multi_label_accuracy: 0.1302
# Epoch 456/1000
#  - 1s - loss: 0.2722 - raw_multi_label_accuracy: 0.1912 - val_loss: 0.3260 - val_raw_multi_label_accuracy: 0.1193
# Epoch 457/1000
#  - 1s - loss: 0.2705 - raw_multi_label_accuracy: 0.1865 - val_loss: 0.3316 - val_raw_multi_label_accuracy: 0.1527
# Epoch 458/1000
#  - 1s - loss: 0.2720 - raw_multi_label_accuracy: 0.1944 - val_loss: 0.3288 - val_raw_multi_label_accuracy: 0.1264
# Epoch 459/1000
#  - 1s - loss: 0.2691 - raw_multi_label_accuracy: 0.1858 - val_loss: 0.3276 - val_raw_multi_label_accuracy: 0.1422
# Epoch 460/1000
#  - 1s - loss: 0.2695 - raw_multi_label_accuracy: 0.1960 - val_loss: 0.3261 - val_raw_multi_label_accuracy: 0.1142
# Epoch 461/1000
#  - 1s - loss: 0.2689 - raw_multi_label_accuracy: 0.1972 - val_loss: 0.3285 - val_raw_multi_label_accuracy: 0.1126
# Epoch 462/1000
#  - 2s - loss: 0.2692 - raw_multi_label_accuracy: 0.1944 - val_loss: 0.3297 - val_raw_multi_label_accuracy: 0.1103
# Epoch 463/1000
#  - 2s - loss: 0.2687 - raw_multi_label_accuracy: 0.1991 - val_loss: 0.3284 - val_raw_multi_label_accuracy: 0.1120
# Epoch 464/1000
#  - 1s - loss: 0.2694 - raw_multi_label_accuracy: 0.1899 - val_loss: 0.3335 - val_raw_multi_label_accuracy: 0.1423
# Epoch 465/1000
#  - 1s - loss: 0.2699 - raw_multi_label_accuracy: 0.1982 - val_loss: 0.3334 - val_raw_multi_label_accuracy: 0.1123
# Epoch 466/1000
#  - 1s - loss: 0.2718 - raw_multi_label_accuracy: 0.1957 - val_loss: 0.3306 - val_raw_multi_label_accuracy: 0.1148
# Epoch 467/1000
#  - 2s - loss: 0.2681 - raw_multi_label_accuracy: 0.1987 - val_loss: 0.3282 - val_raw_multi_label_accuracy: 0.1300
# Epoch 468/1000
#  - 2s - loss: 0.2683 - raw_multi_label_accuracy: 0.1989 - val_loss: 0.3346 - val_raw_multi_label_accuracy: 0.1207
# Epoch 469/1000
#  - 2s - loss: 0.2690 - raw_multi_label_accuracy: 0.1966 - val_loss: 0.3294 - val_raw_multi_label_accuracy: 0.1310
# Epoch 470/1000
#  - 2s - loss: 0.2687 - raw_multi_label_accuracy: 0.1951 - val_loss: 0.3340 - val_raw_multi_label_accuracy: 0.1191
# Epoch 471/1000
#  - 1s - loss: 0.2683 - raw_multi_label_accuracy: 0.2026 - val_loss: 0.3303 - val_raw_multi_label_accuracy: 0.1107
# Epoch 472/1000
#  - 1s - loss: 0.2697 - raw_multi_label_accuracy: 0.2000 - val_loss: 0.3296 - val_raw_multi_label_accuracy: 0.1111
# Epoch 473/1000
#  - 1s - loss: 0.2694 - raw_multi_label_accuracy: 0.1948 - val_loss: 0.3323 - val_raw_multi_label_accuracy: 0.1007
# Epoch 474/1000
#  - 1s - loss: 0.2695 - raw_multi_label_accuracy: 0.1938 - val_loss: 0.3345 - val_raw_multi_label_accuracy: 0.0984
# Epoch 475/1000
#  - 1s - loss: 0.2680 - raw_multi_label_accuracy: 0.1958 - val_loss: 0.3307 - val_raw_multi_label_accuracy: 0.1634
# Epoch 476/1000
#  - 1s - loss: 0.2680 - raw_multi_label_accuracy: 0.2040 - val_loss: 0.3314 - val_raw_multi_label_accuracy: 0.1439
# Epoch 477/1000
#  - 1s - loss: 0.2661 - raw_multi_label_accuracy: 0.1976 - val_loss: 0.3311 - val_raw_multi_label_accuracy: 0.1331
# Epoch 478/1000
#  - 1s - loss: 0.2672 - raw_multi_label_accuracy: 0.2035 - val_loss: 0.3306 - val_raw_multi_label_accuracy: 0.1265
# Epoch 479/1000
#  - 1s - loss: 0.2672 - raw_multi_label_accuracy: 0.2023 - val_loss: 0.3338 - val_raw_multi_label_accuracy: 0.1064
# Epoch 480/1000
#  - 2s - loss: 0.2681 - raw_multi_label_accuracy: 0.1980 - val_loss: 0.3297 - val_raw_multi_label_accuracy: 0.1397
# Epoch 481/1000
#  - 1s - loss: 0.2690 - raw_multi_label_accuracy: 0.2033 - val_loss: 0.3312 - val_raw_multi_label_accuracy: 0.1331
# Epoch 482/1000
#  - 1s - loss: 0.2660 - raw_multi_label_accuracy: 0.1964 - val_loss: 0.3317 - val_raw_multi_label_accuracy: 0.1266
# Epoch 483/1000
#  - 1s - loss: 0.2645 - raw_multi_label_accuracy: 0.2079 - val_loss: 0.3343 - val_raw_multi_label_accuracy: 0.1131
# Epoch 484/1000
#  - 1s - loss: 0.2666 - raw_multi_label_accuracy: 0.2013 - val_loss: 0.3329 - val_raw_multi_label_accuracy: 0.1583
# Epoch 485/1000
#  - 1s - loss: 0.2659 - raw_multi_label_accuracy: 0.2096 - val_loss: 0.3406 - val_raw_multi_label_accuracy: 0.1198
# Epoch 486/1000
#  - 1s - loss: 0.2653 - raw_multi_label_accuracy: 0.2073 - val_loss: 0.3349 - val_raw_multi_label_accuracy: 0.1250
# Epoch 487/1000
#  - 1s - loss: 0.2657 - raw_multi_label_accuracy: 0.2068 - val_loss: 0.3334 - val_raw_multi_label_accuracy: 0.1424
# Epoch 488/1000
#  - 1s - loss: 0.2667 - raw_multi_label_accuracy: 0.2073 - val_loss: 0.3355 - val_raw_multi_label_accuracy: 0.1116
# Epoch 489/1000
#  - 1s - loss: 0.2643 - raw_multi_label_accuracy: 0.2132 - val_loss: 0.3334 - val_raw_multi_label_accuracy: 0.1297
# Epoch 490/1000
#  - 1s - loss: 0.2640 - raw_multi_label_accuracy: 0.2110 - val_loss: 0.3335 - val_raw_multi_label_accuracy: 0.1219
# Epoch 491/1000
#  - 1s - loss: 0.2637 - raw_multi_label_accuracy: 0.2067 - val_loss: 0.3342 - val_raw_multi_label_accuracy: 0.1219
# Epoch 492/1000
#  - 1s - loss: 0.2635 - raw_multi_label_accuracy: 0.2164 - val_loss: 0.3365 - val_raw_multi_label_accuracy: 0.1205
# Epoch 493/1000
#  - 1s - loss: 0.2640 - raw_multi_label_accuracy: 0.2096 - val_loss: 0.3380 - val_raw_multi_label_accuracy: 0.1358
# Epoch 494/1000
#  - 1s - loss: 0.2648 - raw_multi_label_accuracy: 0.2156 - val_loss: 0.3399 - val_raw_multi_label_accuracy: 0.1289
# Epoch 495/1000
#  - 1s - loss: 0.2649 - raw_multi_label_accuracy: 0.2063 - val_loss: 0.3371 - val_raw_multi_label_accuracy: 0.1152
# Epoch 496/1000
#  - 1s - loss: 0.2632 - raw_multi_label_accuracy: 0.2095 - val_loss: 0.3369 - val_raw_multi_label_accuracy: 0.1419
# Epoch 497/1000
#  - 1s - loss: 0.2646 - raw_multi_label_accuracy: 0.2114 - val_loss: 0.3382 - val_raw_multi_label_accuracy: 0.1464
# Epoch 498/1000
#  - 1s - loss: 0.2637 - raw_multi_label_accuracy: 0.2142 - val_loss: 0.3350 - val_raw_multi_label_accuracy: 0.1349
# Epoch 499/1000
#  - 1s - loss: 0.2639 - raw_multi_label_accuracy: 0.2079 - val_loss: 0.3357 - val_raw_multi_label_accuracy: 0.1099
# Epoch 500/1000
#  - 1s - loss: 0.2629 - raw_multi_label_accuracy: 0.2180 - val_loss: 0.3418 - val_raw_multi_label_accuracy: 0.1086
# Epoch 501/1000
#  - 1s - loss: 0.2634 - raw_multi_label_accuracy: 0.2165 - val_loss: 0.3377 - val_raw_multi_label_accuracy: 0.1155
# Epoch 502/1000
#  - 1s - loss: 0.2628 - raw_multi_label_accuracy: 0.2132 - val_loss: 0.3369 - val_raw_multi_label_accuracy: 0.1355
# Epoch 503/1000
#  - 1s - loss: 0.2630 - raw_multi_label_accuracy: 0.2106 - val_loss: 0.3348 - val_raw_multi_label_accuracy: 0.1160
# Epoch 504/1000
#  - 1s - loss: 0.2635 - raw_multi_label_accuracy: 0.2196 - val_loss: 0.3427 - val_raw_multi_label_accuracy: 0.1001

# %%
res = model_cnn.predict(x_test_seq)

# %%
label_predictions = []
for i in range(res.shape[0]):
    pred = [0]*20
    for j in range(res.shape[1]):
        if res[i][j] >= .5:
            pred[j] = 1
    label_predictions.append(pred)

# %%
y_test[:,2].sum()
# Out:
# 319

# %%
label_predictions = np.array(label_predictions)
label_predictions[:,2].sum()
# Out:
# 167

# %%
multi_label_accuracy(y_test, label_predictions)
# Out:
# 0.12264497088617693
