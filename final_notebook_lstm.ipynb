# %%
import numpy as np
import pandas as pd
#for reading in data properly
import ast
import json

import gensim
from gensim.models import Doc2Vec
from gensim.models import Word2Vec
from gensim.models.doc2vec import TaggedDocument

from sklearn.model_selection import train_test_split
from sklearn import utils

import re

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))

# %%
all_data = pd.read_csv('train.csv')
all_data = all_data.dropna(subset=['overview', 'genres']) #drop cols without overview or genre (data we use or labels)
genre_set = {'Comedy'}

# %%
def text_to_list(x):
    if pd.isna(x):
        return ''
    else:
        return ast.literal_eval(x)

def parse_json(x):
    try:
        return json.loads(x.replace("'", '"'))[0]['name']
    except:
        return ''
    
def parse_all_genres_json(x):
    try:
        json_genres = json.loads(x.replace("'", '"'))
        numElems = len(json_genres)
        for i in range(numElems):
            genre_set.add(json_genres[i]['name'])
    except:
        return ''
    
def parse_genres_json(x):
    try:
        json_genres = json.loads(x.replace("'", '"'))
        numElems = len(json_genres)
        ret = [0]*len(genre_dict) #20 0s
        for i in range(numElems):
            ret[genre_dict[(json_genres[i]['name'])]] = 1
        return ret
    except:
        return ''
    

def get_labels_as_strs(x):
    try:
        json_genres = json.loads(x.replace("'", '"'))
        numElems = len(json_genres)
        ret = []#20 0s
        for i in range(numElems):
            ret.append(json_genres[i]['name'])
        return ret
    except:
        return ''

# %%
 def getAllGenres():
    full_data = pd.read_csv('train.csv')

    y = full_data['genres']
    y.apply(parse_all_genres_json)

# %%
getAllGenres()#populate the genre set

# %%
#get set to dictionary for indexing of target vectors
genre_dict = {}
index = 0
for genre in genre_set:
    genre_dict[genre] = index
    index += 1

# %%
def getGenresVects():
    y = all_data['genres']
    ret = y.apply(parse_genres_json)
    all_data['genres_vect'] = ret
    label_strs = y.apply(get_labels_as_strs)
    all_data['genres_labels'] = label_strs
    return ret

# %%
labels_vects = getGenresVects() #get label vectors for genres indexed by indexes in genre_dict

# %%
#put to lower case, remove punctation
def cleanText(text):
    text = re.sub(r'[^a-z A-Z0-9]', "", text) #maybe shouldn't remove punction between words here?
    text = text.lower()
    return text
all_data['cleanOverview'] = all_data['overview'].apply(cleanText)

# %%
#logistic regression data
lr_data = all_data[['cleanOverview', 'genres_labels', 'genres_vect', 'overview']]

# %%
train, test = train_test_split(lr_data, test_size=0.2, random_state=42)

# %% [markdown]
# CNN STUFF here

# %%
#get word embeddings
x = train['cleanOverview'].values.tolist()
y = train['genres_vect']

# %%
x_test = test['cleanOverview'].values.tolist()
y_test = test['genres_vect']

# %%
y_train = y.tolist()
y_train = np.array(y_train)

# %%
y_test = y_test.tolist()
y_test = np.array(y_test)

# %%
tok = [word_tokenize(sent) for sent in x]

# %%
word_vec_len = 32
model = Word2Vec(tok, min_count = 1, size=word_vec_len)

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

num_words_kept = 100000 #using 100000 most popular words, use throughout

tokenizer = Tokenizer(num_words_kept)
tokenizer.fit_on_texts(x)
sequences = tokenizer.texts_to_sequences(x)

x_train_seq = pad_sequences(sequences, maxlen=200)

# %%
test_sequences = tokenizer.texts_to_sequences(x_test)
x_test_seq = pad_sequences(test_sequences, maxlen=200)

# %%
embeddings_index = {}
for w in model.wv.vocab.keys():
    embeddings_index[w] = model.wv[w]


embedding_matrix = np.zeros((num_words_kept, word_vec_len))
for word, i in tokenizer.word_index.items():
    if i >= num_words_kept:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

def get_per_label_metrics(real_labels_matrix, predictions_labels_matrix):
    for genre in genre_dict.keys():
        index = genre_dict[genre]
        real_labels_vect = real_labels_matrix[:, index]
        prediction_vect = predictions_labels_matrix[:,index]
        print("Accuracy for " + genre + ": " + str(accuracy_score(real_labels_vect, prediction_vect)))
        print("Precision for " + genre + ": " + str(precision_score(real_labels_vect, prediction_vect)))
        print("Recall for " + genre + ": " + str(recall_score(real_labels_vect, prediction_vect)))
        print()

# %%
#size of intersection of predicted and actual labels divided by size of their union for each datapoint tested on
#sum those and then divide by number of datapoints
#vectorized for speed
def multi_label_accuracy(real_labels_matrix, predictions_labels_matrix):
    #binary so set intersection is and operator
    intersection = real_labels_matrix & predictions_labels_matrix
    #set union for binary is same as or operator
    union = real_labels_matrix | predictions_labels_matrix
    #sum(array.T) gets number of 1s in row
    row_wise_accuracy = sum(intersection.T) / sum(union.T)
    return sum(row_wise_accuracy) / real_labels_matrix.shape[0]

#size of intersection of predicted and actual labels divided by size of predicted set for each datapoint tested on
#sum those and divide by number of datapoints
#if no predicted labels, don't count that row towards the precision as that would be undefined
def multi_label_precision(real_labels_matrix, predictions_labels_matrix):
    #binary so set intersection is and operator
    intersection = real_labels_matrix & predictions_labels_matrix
    precision_sum = 0
    num_rows = 0
    for row in range(intersection.shape[0]):
        if sum(predictions_labels_matrix[row]) > 0: #if there is at least one prediction for this row
            num_rows += 1
            precision_sum += sum(intersection[row]) / sum(predictions_labels_matrix[row])
    if num_rows == 0:
        return 0#no labels predicted at all will give us 0 precision as precision makes no sense here
    return precision_sum / num_rows

#size of intersection of predicted and actual labels divided by size of real label set for each datapoint tested on
#sum those and divide by number of datapoints
#all datapoints should have at least 1 real label in this data set
#vectorized for speed
def multi_label_recall(real_labels_matrix, predictions_labels_matrix):
    #binary so set intersection is and operator
    intersection = real_labels_matrix & predictions_labels_matrix
    #set union for binary is same as or operator
    #sum(array.T) gets number of 1s in row
    row_wise_recall = sum(intersection.T) / sum(real_labels_matrix.T)
    return sum(row_wise_recall) / real_labels_matrix.shape[0]

#lower is better
def hamming_loss(real_labels_matrix, predictions_labels_matrix):
    return (np.logical_xor(real_labels_matrix, predictions_labels_matrix)).sum()/(real_labels_matrix.shape[0] * real_labels_matrix.shape[1])

import keras.backend as K

#metric for keras for early stopping
#takes in raw labels from kerass (not yet converted to 0 and 1s)
#NOT the same as accuracy, this is total labels correctly identified divided by union of total labels
#this weights rows with more labels higher, where accruacy does not, but this is still a good metric for early stopping
def raw_multi_label_accuracy(y_true, y_pred):
    positives = K.greater_equal(y_pred, 0.5)
    positives = K.cast(positives, K.floatx())
    new_y_pred = positives #+ ((1-positives)*y_pred)
    intersection = y_true * new_y_pred
    union = 1 -((1-y_true)*(1-new_y_pred))
    accuracy = K.sum(intersection) / K.sum(union)
    return accuracy

# %%
from keras.callbacks import EarlyStopping
#for early stopping only after certain number of epochs. wait until delay epochs until early stopping
class DelayedEarlyStopping(EarlyStopping):
    def __init__(self, monitor, min_delta=0, patience=0, verbose=0, mode='auto', delay = 100):
        super(DelayedEarlyStopping, self).__init__()
        self.delay = delay

    def on_epoch_end(self, epoch, logs=None):
        if epoch > self.delay:
            super().on_epoch_end(epoch, logs)

# %%
from keras.layers import Conv1D, GlobalMaxPooling1D
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Flatten, LSTM
from keras.layers.embeddings import Embedding

model_lstm = Sequential()
#e = Embedding(num_words_kept, word_vec_len, weights=[embedding_matrix], input_length=200, trainable=False)
#e = Embedding(num_words_kept, word_vec_len, input_length=200, trainable=True)
e = Embedding(num_words_kept, word_vec_len, weights=[embedding_matrix], input_length=200, trainable=True)
model_lstm.add(e)
model_lstm.add(Conv1D(filters=100, kernel_size=2, padding='valid', activation='relu', strides=1))
model_lstm.add(GlobalMaxPooling1D())
model_lstm.add(LSTM(100))
model_lstm.add(Dense(256, activation='relu'))
model_lstm.add(Dense(20, activation='sigmoid'))
model_lstm.compile(loss='binary_crossentropy', optimizer='adam', metrics=[raw_multi_label_accuracy])
print(model_lstm.summary())
#model_cnn_01.fit(x_train_seq, y_train, validation_data=(x_val_seq, y_validation), epochs=5, batch_size=32, verbose=2)
model_lstm.fit(x_train_seq, y_train, validation_split = .1, callbacks = [DelayedEarlyStopping(monitor = 'val_raw_multi_label_accuracy', patience = 10, delay=250)], epochs=1000, batch_size=100, verbose=2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_8 (Embedding)      (None, 200, 32)           3200000
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 199, 100)          6500
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 99, 100)           0
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dense_4 (Dense)              (None, 20)                2020
# =================================================================
# Total params: 3,288,920
# Trainable params: 3,288,920
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 2149 samples, validate on 239 samples
# Epoch 1/1000
#  - 9s - loss: 0.4270 - raw_multi_label_accuracy: 0.0786 - val_loss: 0.3210 - val_raw_multi_label_accuracy: 0.1569
# Epoch 2/1000
#  - 6s - loss: 0.3150 - raw_multi_label_accuracy: 0.0871 - val_loss: 0.3153 - val_raw_multi_label_accuracy: 0.1682
# Epoch 3/1000
#  - 6s - loss: 0.3126 - raw_multi_label_accuracy: 0.1140 - val_loss: 0.3155 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 4/1000
#  - 6s - loss: 0.3119 - raw_multi_label_accuracy: 0.1155 - val_loss: 0.3141 - val_raw_multi_label_accuracy: 0.1542
# Epoch 5/1000
#  - 6s - loss: 0.3118 - raw_multi_label_accuracy: 0.1026 - val_loss: 0.3149 - val_raw_multi_label_accuracy: 0.1695
# Epoch 6/1000
#  - 6s - loss: 0.3114 - raw_multi_label_accuracy: 0.0877 - val_loss: 0.3146 - val_raw_multi_label_accuracy: 0.1668
# Epoch 7/1000
#  - 6s - loss: 0.3111 - raw_multi_label_accuracy: 0.0961 - val_loss: 0.3146 - val_raw_multi_label_accuracy: 0.1695
# Epoch 8/1000
#  - 7s - loss: 0.3111 - raw_multi_label_accuracy: 0.1197 - val_loss: 0.3149 - val_raw_multi_label_accuracy: 0.0861
# Epoch 9/1000
#  - 6s - loss: 0.3109 - raw_multi_label_accuracy: 0.0858 - val_loss: 0.3141 - val_raw_multi_label_accuracy: 0.1604
# Epoch 10/1000
#  - 8s - loss: 0.3105 - raw_multi_label_accuracy: 0.1251 - val_loss: 0.3144 - val_raw_multi_label_accuracy: 0.0000e+00
# Epoch 11/1000
#  - 12s - loss: 0.3105 - raw_multi_label_accuracy: 0.0574 - val_loss: 0.3143 - val_raw_multi_label_accuracy: 0.1364
# Epoch 12/1000
#  - 10s - loss: 0.3097 - raw_multi_label_accuracy: 0.1020 - val_loss: 0.3138 - val_raw_multi_label_accuracy: 0.1061
# Epoch 13/1000
#  - 10s - loss: 0.3076 - raw_multi_label_accuracy: 0.1294 - val_loss: 0.3144 - val_raw_multi_label_accuracy: 0.1697
# Epoch 14/1000
#  - 9s - loss: 0.3038 - raw_multi_label_accuracy: 0.1467 - val_loss: 0.3138 - val_raw_multi_label_accuracy: 0.1203
# Epoch 15/1000
#  - 7s - loss: 0.2976 - raw_multi_label_accuracy: 0.1319 - val_loss: 0.3141 - val_raw_multi_label_accuracy: 0.1393
# Epoch 16/1000
#  - 9s - loss: 0.2877 - raw_multi_label_accuracy: 0.1470 - val_loss: 0.3183 - val_raw_multi_label_accuracy: 0.1284
# Epoch 17/1000
#  - 8s - loss: 0.2740 - raw_multi_label_accuracy: 0.1934 - val_loss: 0.3162 - val_raw_multi_label_accuracy: 0.0981
# Epoch 18/1000
#  - 8s - loss: 0.2599 - raw_multi_label_accuracy: 0.2538 - val_loss: 0.3181 - val_raw_multi_label_accuracy: 0.1199
# Epoch 19/1000
#  - 7s - loss: 0.2439 - raw_multi_label_accuracy: 0.3397 - val_loss: 0.3218 - val_raw_multi_label_accuracy: 0.1355
# Epoch 20/1000
#  - 9s - loss: 0.2317 - raw_multi_label_accuracy: 0.3789 - val_loss: 0.3292 - val_raw_multi_label_accuracy: 0.1464
# Epoch 21/1000
#  - 8s - loss: 0.2176 - raw_multi_label_accuracy: 0.4206 - val_loss: 0.3252 - val_raw_multi_label_accuracy: 0.1814
# Epoch 22/1000
#  - 8s - loss: 0.2081 - raw_multi_label_accuracy: 0.4468 - val_loss: 0.3341 - val_raw_multi_label_accuracy: 0.1841
# Epoch 23/1000
#  - 8s - loss: 0.1991 - raw_multi_label_accuracy: 0.4735 - val_loss: 0.3355 - val_raw_multi_label_accuracy: 0.1869
# Epoch 24/1000
#  - 12s - loss: 0.1910 - raw_multi_label_accuracy: 0.4994 - val_loss: 0.3394 - val_raw_multi_label_accuracy: 0.1756
# Epoch 25/1000
#  - 10s - loss: 0.1830 - raw_multi_label_accuracy: 0.5173 - val_loss: 0.3422 - val_raw_multi_label_accuracy: 0.1892
# Epoch 26/1000
#  - 12s - loss: 0.1769 - raw_multi_label_accuracy: 0.5483 - val_loss: 0.3541 - val_raw_multi_label_accuracy: 0.1889
# Epoch 27/1000
#  - 7s - loss: 0.1709 - raw_multi_label_accuracy: 0.5576 - val_loss: 0.3583 - val_raw_multi_label_accuracy: 0.1992
# Epoch 28/1000
#  - 8s - loss: 0.1646 - raw_multi_label_accuracy: 0.5789 - val_loss: 0.3694 - val_raw_multi_label_accuracy: 0.1833
# Epoch 29/1000
#  - 8s - loss: 0.1590 - raw_multi_label_accuracy: 0.5995 - val_loss: 0.3702 - val_raw_multi_label_accuracy: 0.1861
# Epoch 30/1000
#  - 13s - loss: 0.1544 - raw_multi_label_accuracy: 0.6090 - val_loss: 0.3803 - val_raw_multi_label_accuracy: 0.2017
# Epoch 31/1000
#  - 11s - loss: 0.1498 - raw_multi_label_accuracy: 0.6224 - val_loss: 0.3869 - val_raw_multi_label_accuracy: 0.1926
# Epoch 32/1000
#  - 10s - loss: 0.1448 - raw_multi_label_accuracy: 0.6367 - val_loss: 0.3968 - val_raw_multi_label_accuracy: 0.1842
# Epoch 33/1000
#  - 8s - loss: 0.1400 - raw_multi_label_accuracy: 0.6495 - val_loss: 0.3974 - val_raw_multi_label_accuracy: 0.1881
# Epoch 34/1000
#  - 8s - loss: 0.1364 - raw_multi_label_accuracy: 0.6603 - val_loss: 0.4109 - val_raw_multi_label_accuracy: 0.1907
# Epoch 35/1000
#  - 7s - loss: 0.1348 - raw_multi_label_accuracy: 0.6572 - val_loss: 0.4145 - val_raw_multi_label_accuracy: 0.1930
# Epoch 36/1000
#  - 7s - loss: 0.1302 - raw_multi_label_accuracy: 0.6701 - val_loss: 0.4212 - val_raw_multi_label_accuracy: 0.1781
# Epoch 37/1000
#  - 8s - loss: 0.1245 - raw_multi_label_accuracy: 0.6862 - val_loss: 0.4272 - val_raw_multi_label_accuracy: 0.1807
# Epoch 38/1000
#  - 7s - loss: 0.1201 - raw_multi_label_accuracy: 0.7030 - val_loss: 0.4365 - val_raw_multi_label_accuracy: 0.1707
# Epoch 39/1000
#  - 7s - loss: 0.1188 - raw_multi_label_accuracy: 0.7035 - val_loss: 0.4489 - val_raw_multi_label_accuracy: 0.1746
# Epoch 40/1000
#  - 7s - loss: 0.1140 - raw_multi_label_accuracy: 0.7189 - val_loss: 0.4518 - val_raw_multi_label_accuracy: 0.1777
# Epoch 41/1000
#  - 7s - loss: 0.1098 - raw_multi_label_accuracy: 0.7304 - val_loss: 0.4568 - val_raw_multi_label_accuracy: 0.1766
# Epoch 42/1000
#  - 7s - loss: 0.1057 - raw_multi_label_accuracy: 0.7428 - val_loss: 0.4644 - val_raw_multi_label_accuracy: 0.1690
# Epoch 43/1000
#  - 7s - loss: 0.1018 - raw_multi_label_accuracy: 0.7554 - val_loss: 0.4742 - val_raw_multi_label_accuracy: 0.1754
# Epoch 44/1000
#  - 7s - loss: 0.0987 - raw_multi_label_accuracy: 0.7639 - val_loss: 0.4750 - val_raw_multi_label_accuracy: 0.1744
# Epoch 45/1000
#  - 7s - loss: 0.0957 - raw_multi_label_accuracy: 0.7773 - val_loss: 0.4856 - val_raw_multi_label_accuracy: 0.1717
# Epoch 46/1000
#  - 7s - loss: 0.0928 - raw_multi_label_accuracy: 0.7813 - val_loss: 0.4898 - val_raw_multi_label_accuracy: 0.1716
# Epoch 47/1000
#  - 7s - loss: 0.0914 - raw_multi_label_accuracy: 0.7844 - val_loss: 0.4932 - val_raw_multi_label_accuracy: 0.1865
# Epoch 48/1000
#  - 7s - loss: 0.0882 - raw_multi_label_accuracy: 0.7956 - val_loss: 0.5037 - val_raw_multi_label_accuracy: 0.1825
# Epoch 49/1000
#  - 7s - loss: 0.0839 - raw_multi_label_accuracy: 0.8102 - val_loss: 0.5039 - val_raw_multi_label_accuracy: 0.1913
# Epoch 50/1000
#  - 7s - loss: 0.0817 - raw_multi_label_accuracy: 0.8189 - val_loss: 0.5122 - val_raw_multi_label_accuracy: 0.1902
# Epoch 51/1000
#  - 7s - loss: 0.0783 - raw_multi_label_accuracy: 0.8264 - val_loss: 0.5166 - val_raw_multi_label_accuracy: 0.1762
# Epoch 52/1000
#  - 7s - loss: 0.0753 - raw_multi_label_accuracy: 0.8349 - val_loss: 0.5207 - val_raw_multi_label_accuracy: 0.1849
# Epoch 53/1000
#  - 7s - loss: 0.0723 - raw_multi_label_accuracy: 0.8490 - val_loss: 0.5298 - val_raw_multi_label_accuracy: 0.1850
# Epoch 54/1000
#  - 7s - loss: 0.0701 - raw_multi_label_accuracy: 0.8539 - val_loss: 0.5315 - val_raw_multi_label_accuracy: 0.1805
# Epoch 55/1000
#  - 7s - loss: 0.0678 - raw_multi_label_accuracy: 0.8677 - val_loss: 0.5407 - val_raw_multi_label_accuracy: 0.1835
# Epoch 56/1000
#  - 7s - loss: 0.0658 - raw_multi_label_accuracy: 0.8640 - val_loss: 0.5418 - val_raw_multi_label_accuracy: 0.1793
# Epoch 57/1000
#  - 7s - loss: 0.0660 - raw_multi_label_accuracy: 0.8625 - val_loss: 0.5494 - val_raw_multi_label_accuracy: 0.1829
# Epoch 58/1000
#  - 7s - loss: 0.0641 - raw_multi_label_accuracy: 0.8644 - val_loss: 0.5589 - val_raw_multi_label_accuracy: 0.1826
# Epoch 59/1000
#  - 7s - loss: 0.0618 - raw_multi_label_accuracy: 0.8751 - val_loss: 0.5599 - val_raw_multi_label_accuracy: 0.1859
# Epoch 60/1000
#  - 7s - loss: 0.0602 - raw_multi_label_accuracy: 0.8817 - val_loss: 0.5686 - val_raw_multi_label_accuracy: 0.1851
# Epoch 61/1000
#  - 7s - loss: 0.0575 - raw_multi_label_accuracy: 0.8841 - val_loss: 0.5665 - val_raw_multi_label_accuracy: 0.1831
# Epoch 62/1000
#  - 7s - loss: 0.0557 - raw_multi_label_accuracy: 0.8937 - val_loss: 0.5759 - val_raw_multi_label_accuracy: 0.1680
# Epoch 63/1000
#  - 7s - loss: 0.0536 - raw_multi_label_accuracy: 0.9028 - val_loss: 0.5798 - val_raw_multi_label_accuracy: 0.1838
# Epoch 64/1000
#  - 7s - loss: 0.0516 - raw_multi_label_accuracy: 0.9086 - val_loss: 0.5832 - val_raw_multi_label_accuracy: 0.1921
# Epoch 65/1000
#  - 8s - loss: 0.0502 - raw_multi_label_accuracy: 0.9127 - val_loss: 0.5890 - val_raw_multi_label_accuracy: 0.1851
# Epoch 66/1000
#  - 9s - loss: 0.0488 - raw_multi_label_accuracy: 0.9144 - val_loss: 0.5886 - val_raw_multi_label_accuracy: 0.1809
# Epoch 67/1000
#  - 7s - loss: 0.0475 - raw_multi_label_accuracy: 0.9167 - val_loss: 0.5962 - val_raw_multi_label_accuracy: 0.1791
# Epoch 68/1000
#  - 8s - loss: 0.0458 - raw_multi_label_accuracy: 0.9207 - val_loss: 0.5986 - val_raw_multi_label_accuracy: 0.1900
# Epoch 69/1000
#  - 9s - loss: 0.0440 - raw_multi_label_accuracy: 0.9262 - val_loss: 0.6076 - val_raw_multi_label_accuracy: 0.1839
# Epoch 70/1000
#  - 7s - loss: 0.0427 - raw_multi_label_accuracy: 0.9300 - val_loss: 0.6152 - val_raw_multi_label_accuracy: 0.1912
# Epoch 71/1000
#  - 8s - loss: 0.0408 - raw_multi_label_accuracy: 0.9379 - val_loss: 0.6123 - val_raw_multi_label_accuracy: 0.1789
# Epoch 72/1000
#  - 7s - loss: 0.0398 - raw_multi_label_accuracy: 0.9362 - val_loss: 0.6302 - val_raw_multi_label_accuracy: 0.1813
# Epoch 73/1000
#  - 7s - loss: 0.0391 - raw_multi_label_accuracy: 0.9381 - val_loss: 0.6359 - val_raw_multi_label_accuracy: 0.1791
# Epoch 74/1000
#  - 8s - loss: 0.0377 - raw_multi_label_accuracy: 0.9424 - val_loss: 0.6318 - val_raw_multi_label_accuracy: 0.1784
# Epoch 75/1000
#  - 9s - loss: 0.0361 - raw_multi_label_accuracy: 0.9445 - val_loss: 0.6400 - val_raw_multi_label_accuracy: 0.1892
# Epoch 76/1000
#  - 8s - loss: 0.0346 - raw_multi_label_accuracy: 0.9488 - val_loss: 0.6450 - val_raw_multi_label_accuracy: 0.1817
# Epoch 77/1000
#  - 8s - loss: 0.0338 - raw_multi_label_accuracy: 0.9520 - val_loss: 0.6522 - val_raw_multi_label_accuracy: 0.1876
# Epoch 78/1000
#  - 9s - loss: 0.0332 - raw_multi_label_accuracy: 0.9528 - val_loss: 0.6480 - val_raw_multi_label_accuracy: 0.1845
# Epoch 79/1000
#  - 7s - loss: 0.0324 - raw_multi_label_accuracy: 0.9511 - val_loss: 0.6588 - val_raw_multi_label_accuracy: 0.1847
# Epoch 80/1000
#  - 8s - loss: 0.0323 - raw_multi_label_accuracy: 0.9486 - val_loss: 0.6579 - val_raw_multi_label_accuracy: 0.1850
# Epoch 81/1000
#  - 7s - loss: 0.0331 - raw_multi_label_accuracy: 0.9454 - val_loss: 0.6687 - val_raw_multi_label_accuracy: 0.1915
# Epoch 82/1000
#  - 7s - loss: 0.0326 - raw_multi_label_accuracy: 0.9481 - val_loss: 0.6802 - val_raw_multi_label_accuracy: 0.1851
# Epoch 83/1000
#  - 7s - loss: 0.0304 - raw_multi_label_accuracy: 0.9550 - val_loss: 0.6744 - val_raw_multi_label_accuracy: 0.1870
# Epoch 84/1000
#  - 7s - loss: 0.0289 - raw_multi_label_accuracy: 0.9600 - val_loss: 0.6829 - val_raw_multi_label_accuracy: 0.1807
# Epoch 85/1000
#  - 7s - loss: 0.0280 - raw_multi_label_accuracy: 0.9605 - val_loss: 0.6854 - val_raw_multi_label_accuracy: 0.1762
# Epoch 86/1000
#  - 7s - loss: 0.0268 - raw_multi_label_accuracy: 0.9621 - val_loss: 0.6903 - val_raw_multi_label_accuracy: 0.1831
# Epoch 87/1000
#  - 7s - loss: 0.0255 - raw_multi_label_accuracy: 0.9709 - val_loss: 0.6902 - val_raw_multi_label_accuracy: 0.1809
# Epoch 88/1000
#  - 7s - loss: 0.0248 - raw_multi_label_accuracy: 0.9682 - val_loss: 0.6931 - val_raw_multi_label_accuracy: 0.1853
# Epoch 89/1000
#  - 7s - loss: 0.0237 - raw_multi_label_accuracy: 0.9729 - val_loss: 0.7060 - val_raw_multi_label_accuracy: 0.1784
# Epoch 90/1000
#  - 7s - loss: 0.0225 - raw_multi_label_accuracy: 0.9750 - val_loss: 0.7174 - val_raw_multi_label_accuracy: 0.1830
# Epoch 91/1000
#  - 7s - loss: 0.0216 - raw_multi_label_accuracy: 0.9770 - val_loss: 0.7129 - val_raw_multi_label_accuracy: 0.1845
# Epoch 92/1000
#  - 7s - loss: 0.0208 - raw_multi_label_accuracy: 0.9789 - val_loss: 0.7169 - val_raw_multi_label_accuracy: 0.1831
# Epoch 93/1000
#  - 7s - loss: 0.0203 - raw_multi_label_accuracy: 0.9801 - val_loss: 0.7228 - val_raw_multi_label_accuracy: 0.1879
# Epoch 94/1000
#  - 7s - loss: 0.0197 - raw_multi_label_accuracy: 0.9807 - val_loss: 0.7243 - val_raw_multi_label_accuracy: 0.1878
# Epoch 95/1000
#  - 7s - loss: 0.0192 - raw_multi_label_accuracy: 0.9818 - val_loss: 0.7333 - val_raw_multi_label_accuracy: 0.1882
# Epoch 96/1000
#  - 7s - loss: 0.0185 - raw_multi_label_accuracy: 0.9843 - val_loss: 0.7416 - val_raw_multi_label_accuracy: 0.1834
# Epoch 97/1000
#  - 7s - loss: 0.0180 - raw_multi_label_accuracy: 0.9848 - val_loss: 0.7465 - val_raw_multi_label_accuracy: 0.1854
# Epoch 98/1000
#  - 7s - loss: 0.0182 - raw_multi_label_accuracy: 0.9847 - val_loss: 0.7467 - val_raw_multi_label_accuracy: 0.1786
# Epoch 99/1000
#  - 7s - loss: 0.0180 - raw_multi_label_accuracy: 0.9822 - val_loss: 0.7421 - val_raw_multi_label_accuracy: 0.1805
# Epoch 100/1000
#  - 7s - loss: 0.0182 - raw_multi_label_accuracy: 0.9823 - val_loss: 0.7503 - val_raw_multi_label_accuracy: 0.1845
# Epoch 101/1000
#  - 7s - loss: 0.0183 - raw_multi_label_accuracy: 0.9831 - val_loss: 0.7587 - val_raw_multi_label_accuracy: 0.1893
# Epoch 102/1000
#  - 7s - loss: 0.0198 - raw_multi_label_accuracy: 0.9768 - val_loss: 0.7661 - val_raw_multi_label_accuracy: 0.1976
# Epoch 103/1000
#  - 7s - loss: 0.0187 - raw_multi_label_accuracy: 0.9788 - val_loss: 0.7674 - val_raw_multi_label_accuracy: 0.1880
# Epoch 104/1000
#  - 7s - loss: 0.0177 - raw_multi_label_accuracy: 0.9819 - val_loss: 0.7748 - val_raw_multi_label_accuracy: 0.1834
# Epoch 105/1000
#  - 7s - loss: 0.0165 - raw_multi_label_accuracy: 0.9842 - val_loss: 0.7773 - val_raw_multi_label_accuracy: 0.1773
# Epoch 106/1000
#  - 8s - loss: 0.0154 - raw_multi_label_accuracy: 0.9864 - val_loss: 0.7729 - val_raw_multi_label_accuracy: 0.1874
# Epoch 107/1000
#  - 7s - loss: 0.0147 - raw_multi_label_accuracy: 0.9876 - val_loss: 0.7834 - val_raw_multi_label_accuracy: 0.1869
# Epoch 108/1000
#  - 7s - loss: 0.0139 - raw_multi_label_accuracy: 0.9901 - val_loss: 0.7881 - val_raw_multi_label_accuracy: 0.1789
# Epoch 109/1000
#  - 7s - loss: 0.0133 - raw_multi_label_accuracy: 0.9918 - val_loss: 0.7971 - val_raw_multi_label_accuracy: 0.1822
# Epoch 110/1000
#  - 7s - loss: 0.0127 - raw_multi_label_accuracy: 0.9918 - val_loss: 0.7974 - val_raw_multi_label_accuracy: 0.1840
# Epoch 111/1000
#  - 7s - loss: 0.0124 - raw_multi_label_accuracy: 0.9921 - val_loss: 0.7964 - val_raw_multi_label_accuracy: 0.1823
# Epoch 112/1000
#  - 7s - loss: 0.0120 - raw_multi_label_accuracy: 0.9928 - val_loss: 0.8030 - val_raw_multi_label_accuracy: 0.1870
# Epoch 113/1000
#  - 7s - loss: 0.0116 - raw_multi_label_accuracy: 0.9933 - val_loss: 0.8130 - val_raw_multi_label_accuracy: 0.1809
# Epoch 114/1000
#  - 7s - loss: 0.0114 - raw_multi_label_accuracy: 0.9929 - val_loss: 0.8147 - val_raw_multi_label_accuracy: 0.1844
# Epoch 115/1000
#  - 7s - loss: 0.0111 - raw_multi_label_accuracy: 0.9937 - val_loss: 0.8184 - val_raw_multi_label_accuracy: 0.1800
# Epoch 116/1000
#  - 7s - loss: 0.0108 - raw_multi_label_accuracy: 0.9935 - val_loss: 0.8201 - val_raw_multi_label_accuracy: 0.1850
# Epoch 117/1000
#  - 7s - loss: 0.0105 - raw_multi_label_accuracy: 0.9939 - val_loss: 0.8180 - val_raw_multi_label_accuracy: 0.1801
# Epoch 118/1000
#  - 7s - loss: 0.0102 - raw_multi_label_accuracy: 0.9946 - val_loss: 0.8297 - val_raw_multi_label_accuracy: 0.1881
# Epoch 119/1000
#  - 7s - loss: 0.0100 - raw_multi_label_accuracy: 0.9942 - val_loss: 0.8357 - val_raw_multi_label_accuracy: 0.1843
# Epoch 120/1000
#  - 7s - loss: 0.0098 - raw_multi_label_accuracy: 0.9956 - val_loss: 0.8342 - val_raw_multi_label_accuracy: 0.1802
# Epoch 121/1000
#  - 7s - loss: 0.0096 - raw_multi_label_accuracy: 0.9942 - val_loss: 0.8430 - val_raw_multi_label_accuracy: 0.1856
# Epoch 122/1000
#  - 7s - loss: 0.0092 - raw_multi_label_accuracy: 0.9959 - val_loss: 0.8462 - val_raw_multi_label_accuracy: 0.1797
# Epoch 123/1000
#  - 7s - loss: 0.0090 - raw_multi_label_accuracy: 0.9957 - val_loss: 0.8473 - val_raw_multi_label_accuracy: 0.1845
# Epoch 124/1000
#  - 7s - loss: 0.0087 - raw_multi_label_accuracy: 0.9968 - val_loss: 0.8513 - val_raw_multi_label_accuracy: 0.1910
# Epoch 125/1000
#  - 7s - loss: 0.0086 - raw_multi_label_accuracy: 0.9967 - val_loss: 0.8495 - val_raw_multi_label_accuracy: 0.1916
# Epoch 126/1000
#  - 7s - loss: 0.0085 - raw_multi_label_accuracy: 0.9967 - val_loss: 0.8603 - val_raw_multi_label_accuracy: 0.1833
# Epoch 127/1000
#  - 7s - loss: 0.0083 - raw_multi_label_accuracy: 0.9957 - val_loss: 0.8543 - val_raw_multi_label_accuracy: 0.1822
# Epoch 128/1000
#  - 7s - loss: 0.0081 - raw_multi_label_accuracy: 0.9970 - val_loss: 0.8693 - val_raw_multi_label_accuracy: 0.1811
# Epoch 129/1000
#  - 8s - loss: 0.0079 - raw_multi_label_accuracy: 0.9970 - val_loss: 0.8634 - val_raw_multi_label_accuracy: 0.1824
# Epoch 130/1000
#  - 8s - loss: 0.0077 - raw_multi_label_accuracy: 0.9976 - val_loss: 0.8710 - val_raw_multi_label_accuracy: 0.1855
# Epoch 131/1000
#  - 7s - loss: 0.0075 - raw_multi_label_accuracy: 0.9974 - val_loss: 0.8761 - val_raw_multi_label_accuracy: 0.1806
# Epoch 132/1000
#  - 7s - loss: 0.0075 - raw_multi_label_accuracy: 0.9972 - val_loss: 0.8761 - val_raw_multi_label_accuracy: 0.1873
# Epoch 133/1000
#  - 7s - loss: 0.0073 - raw_multi_label_accuracy: 0.9983 - val_loss: 0.8836 - val_raw_multi_label_accuracy: 0.1800
# Epoch 134/1000
#  - 7s - loss: 0.0072 - raw_multi_label_accuracy: 0.9981 - val_loss: 0.8796 - val_raw_multi_label_accuracy: 0.1812
# Epoch 135/1000
#  - 7s - loss: 0.0071 - raw_multi_label_accuracy: 0.9979 - val_loss: 0.8776 - val_raw_multi_label_accuracy: 0.1807
# Epoch 136/1000
#  - 8s - loss: 0.0069 - raw_multi_label_accuracy: 0.9979 - val_loss: 0.8898 - val_raw_multi_label_accuracy: 0.1905
# Epoch 137/1000
#  - 8s - loss: 0.0072 - raw_multi_label_accuracy: 0.9970 - val_loss: 0.8846 - val_raw_multi_label_accuracy: 0.1883
# Epoch 138/1000
#  - 7s - loss: 0.0075 - raw_multi_label_accuracy: 0.9956 - val_loss: 0.8979 - val_raw_multi_label_accuracy: 0.1749
# Epoch 139/1000
#  - 7s - loss: 0.0102 - raw_multi_label_accuracy: 0.9889 - val_loss: 0.8882 - val_raw_multi_label_accuracy: 0.1677
# Epoch 140/1000
#  - 7s - loss: 0.0126 - raw_multi_label_accuracy: 0.9833 - val_loss: 0.9178 - val_raw_multi_label_accuracy: 0.1880
# Epoch 141/1000
#  - 8s - loss: 0.0183 - raw_multi_label_accuracy: 0.9619 - val_loss: 0.8864 - val_raw_multi_label_accuracy: 0.1773
# Epoch 142/1000
#  - 7s - loss: 0.0212 - raw_multi_label_accuracy: 0.9568 - val_loss: 0.8972 - val_raw_multi_label_accuracy: 0.1729
# Epoch 143/1000
#  - 7s - loss: 0.0163 - raw_multi_label_accuracy: 0.9700 - val_loss: 0.8734 - val_raw_multi_label_accuracy: 0.1875
# Epoch 144/1000
#  - 7s - loss: 0.0115 - raw_multi_label_accuracy: 0.9872 - val_loss: 0.8983 - val_raw_multi_label_accuracy: 0.1739
# Epoch 145/1000
#  - 7s - loss: 0.0099 - raw_multi_label_accuracy: 0.9914 - val_loss: 0.9006 - val_raw_multi_label_accuracy: 0.1735
# Epoch 146/1000
#  - 8s - loss: 0.0082 - raw_multi_label_accuracy: 0.9961 - val_loss: 0.9083 - val_raw_multi_label_accuracy: 0.1762
# Epoch 147/1000
#  - 7s - loss: 0.0070 - raw_multi_label_accuracy: 0.9975 - val_loss: 0.9145 - val_raw_multi_label_accuracy: 0.1755
# Epoch 148/1000
#  - 7s - loss: 0.0063 - raw_multi_label_accuracy: 0.9980 - val_loss: 0.9238 - val_raw_multi_label_accuracy: 0.1738
# Epoch 149/1000
#  - 7s - loss: 0.0059 - raw_multi_label_accuracy: 0.9987 - val_loss: 0.9220 - val_raw_multi_label_accuracy: 0.1749
# Epoch 150/1000
#  - 7s - loss: 0.0056 - raw_multi_label_accuracy: 0.9987 - val_loss: 0.9301 - val_raw_multi_label_accuracy: 0.1772
# Epoch 151/1000
#  - 7s - loss: 0.0054 - raw_multi_label_accuracy: 0.9986 - val_loss: 0.9310 - val_raw_multi_label_accuracy: 0.1764
# Epoch 152/1000
#  - 7s - loss: 0.0052 - raw_multi_label_accuracy: 0.9989 - val_loss: 0.9368 - val_raw_multi_label_accuracy: 0.1797
# Epoch 153/1000
#  - 7s - loss: 0.0050 - raw_multi_label_accuracy: 0.9991 - val_loss: 0.9359 - val_raw_multi_label_accuracy: 0.1753
# Epoch 154/1000
#  - 8s - loss: 0.0049 - raw_multi_label_accuracy: 0.9987 - val_loss: 0.9422 - val_raw_multi_label_accuracy: 0.1784
# Epoch 155/1000
#  - 7s - loss: 0.0048 - raw_multi_label_accuracy: 0.9991 - val_loss: 0.9420 - val_raw_multi_label_accuracy: 0.1808
# Epoch 156/1000
#  - 7s - loss: 0.0047 - raw_multi_label_accuracy: 0.9991 - val_loss: 0.9466 - val_raw_multi_label_accuracy: 0.1740
# Epoch 157/1000
#  - 7s - loss: 0.0046 - raw_multi_label_accuracy: 0.9990 - val_loss: 0.9504 - val_raw_multi_label_accuracy: 0.1778
# Epoch 158/1000
#  - 7s - loss: 0.0045 - raw_multi_label_accuracy: 0.9985 - val_loss: 0.9515 - val_raw_multi_label_accuracy: 0.1828
# Epoch 159/1000
#  - 7s - loss: 0.0044 - raw_multi_label_accuracy: 0.9989 - val_loss: 0.9551 - val_raw_multi_label_accuracy: 0.1818
# Epoch 160/1000
#  - 8s - loss: 0.0043 - raw_multi_label_accuracy: 0.9985 - val_loss: 0.9562 - val_raw_multi_label_accuracy: 0.1831
# Epoch 161/1000
#  - 9s - loss: 0.0042 - raw_multi_label_accuracy: 0.9985 - val_loss: 0.9589 - val_raw_multi_label_accuracy: 0.1851
# Epoch 162/1000
#  - 9s - loss: 0.0041 - raw_multi_label_accuracy: 0.9991 - val_loss: 0.9614 - val_raw_multi_label_accuracy: 0.1841
# Epoch 163/1000
#  - 8s - loss: 0.0040 - raw_multi_label_accuracy: 0.9985 - val_loss: 0.9644 - val_raw_multi_label_accuracy: 0.1826
# Epoch 164/1000
#  - 9s - loss: 0.0039 - raw_multi_label_accuracy: 0.9987 - val_loss: 0.9668 - val_raw_multi_label_accuracy: 0.1868
# Epoch 165/1000
#  - 7s - loss: 0.0039 - raw_multi_label_accuracy: 0.9991 - val_loss: 0.9686 - val_raw_multi_label_accuracy: 0.1822
# Epoch 166/1000
#  - 8s - loss: 0.0038 - raw_multi_label_accuracy: 0.9985 - val_loss: 0.9705 - val_raw_multi_label_accuracy: 0.1810
# Epoch 167/1000
#  - 9s - loss: 0.0037 - raw_multi_label_accuracy: 0.9989 - val_loss: 0.9761 - val_raw_multi_label_accuracy: 0.1824
# Epoch 168/1000
#  - 12s - loss: 0.0037 - raw_multi_label_accuracy: 0.9992 - val_loss: 0.9746 - val_raw_multi_label_accuracy: 0.1817
# Epoch 169/1000
#  - 11s - loss: 0.0036 - raw_multi_label_accuracy: 0.9987 - val_loss: 0.9784 - val_raw_multi_label_accuracy: 0.1841
# Epoch 170/1000
#  - 12s - loss: 0.0035 - raw_multi_label_accuracy: 0.9988 - val_loss: 0.9807 - val_raw_multi_label_accuracy: 0.1822
# Epoch 171/1000
#  - 10s - loss: 0.0035 - raw_multi_label_accuracy: 0.9993 - val_loss: 0.9824 - val_raw_multi_label_accuracy: 0.1827
# Epoch 172/1000
#  - 7s - loss: 0.0034 - raw_multi_label_accuracy: 0.9987 - val_loss: 0.9865 - val_raw_multi_label_accuracy: 0.1823
# Epoch 173/1000
#  - 7s - loss: 0.0034 - raw_multi_label_accuracy: 0.9993 - val_loss: 0.9864 - val_raw_multi_label_accuracy: 0.1814
# Epoch 174/1000
#  - 7s - loss: 0.0033 - raw_multi_label_accuracy: 0.9992 - val_loss: 0.9872 - val_raw_multi_label_accuracy: 0.1809
# Epoch 175/1000
#  - 13s - loss: 0.0033 - raw_multi_label_accuracy: 0.9989 - val_loss: 0.9884 - val_raw_multi_label_accuracy: 0.1789
# Epoch 176/1000
#  - 7s - loss: 0.0032 - raw_multi_label_accuracy: 0.9989 - val_loss: 0.9938 - val_raw_multi_label_accuracy: 0.1820
# Epoch 177/1000
#  - 7s - loss: 0.0032 - raw_multi_label_accuracy: 0.9989 - val_loss: 0.9956 - val_raw_multi_label_accuracy: 0.1846
# Epoch 178/1000
#  - 9s - loss: 0.0031 - raw_multi_label_accuracy: 0.9992 - val_loss: 0.9879 - val_raw_multi_label_accuracy: 0.1833
# Epoch 179/1000
#  - 11s - loss: 0.0033 - raw_multi_label_accuracy: 0.9990 - val_loss: 0.9984 - val_raw_multi_label_accuracy: 0.1813
# Epoch 180/1000
#  - 9s - loss: 0.0032 - raw_multi_label_accuracy: 0.9991 - val_loss: 1.0016 - val_raw_multi_label_accuracy: 0.1782
# Epoch 181/1000
#  - 7s - loss: 0.0031 - raw_multi_label_accuracy: 0.9991 - val_loss: 1.0030 - val_raw_multi_label_accuracy: 0.1809
# Epoch 182/1000
#  - 7s - loss: 0.0029 - raw_multi_label_accuracy: 0.9993 - val_loss: 1.0039 - val_raw_multi_label_accuracy: 0.1795
# Epoch 183/1000
#  - 8s - loss: 0.0029 - raw_multi_label_accuracy: 0.9993 - val_loss: 1.0042 - val_raw_multi_label_accuracy: 0.1866
# Epoch 184/1000
#  - 9s - loss: 0.0028 - raw_multi_label_accuracy: 0.9995 - val_loss: 1.0056 - val_raw_multi_label_accuracy: 0.1870
# Epoch 185/1000
#  - 8s - loss: 0.0027 - raw_multi_label_accuracy: 0.9992 - val_loss: 1.0088 - val_raw_multi_label_accuracy: 0.1798
# Epoch 186/1000
#  - 8s - loss: 0.0028 - raw_multi_label_accuracy: 0.9983 - val_loss: 1.0117 - val_raw_multi_label_accuracy: 0.1800
# Epoch 187/1000
#  - 8s - loss: 0.0027 - raw_multi_label_accuracy: 0.9994 - val_loss: 1.0127 - val_raw_multi_label_accuracy: 0.1837
# Epoch 188/1000
#  - 8s - loss: 0.0026 - raw_multi_label_accuracy: 0.9992 - val_loss: 1.0183 - val_raw_multi_label_accuracy: 0.1828
# Epoch 189/1000
#  - 7s - loss: 0.0026 - raw_multi_label_accuracy: 0.9989 - val_loss: 1.0186 - val_raw_multi_label_accuracy: 0.1838
# Epoch 190/1000
#  - 14s - loss: 0.0025 - raw_multi_label_accuracy: 0.9992 - val_loss: 1.0165 - val_raw_multi_label_accuracy: 0.1824
# Epoch 191/1000
#  - 11s - loss: 0.0025 - raw_multi_label_accuracy: 0.9991 - val_loss: 1.0190 - val_raw_multi_label_accuracy: 0.1833
# Epoch 192/1000
#  - 12s - loss: 0.0024 - raw_multi_label_accuracy: 0.9994 - val_loss: 1.0239 - val_raw_multi_label_accuracy: 0.1819
# Epoch 193/1000
#  - 12s - loss: 0.0024 - raw_multi_label_accuracy: 0.9989 - val_loss: 1.0250 - val_raw_multi_label_accuracy: 0.1804
# Epoch 194/1000
#  - 11s - loss: 0.0024 - raw_multi_label_accuracy: 0.9994 - val_loss: 1.0261 - val_raw_multi_label_accuracy: 0.1840
# Epoch 195/1000
#  - 13s - loss: 0.0023 - raw_multi_label_accuracy: 0.9995 - val_loss: 1.0282 - val_raw_multi_label_accuracy: 0.1830
# Epoch 196/1000
#  - 8s - loss: 0.0023 - raw_multi_label_accuracy: 0.9992 - val_loss: 1.0273 - val_raw_multi_label_accuracy: 0.1799
# Epoch 197/1000
#  - 9s - loss: 0.0022 - raw_multi_label_accuracy: 0.9994 - val_loss: 1.0281 - val_raw_multi_label_accuracy: 0.1799
# Epoch 198/1000
#  - 9s - loss: 0.0022 - raw_multi_label_accuracy: 0.9993 - val_loss: 1.0336 - val_raw_multi_label_accuracy: 0.1838
# Epoch 199/1000
#  - 8s - loss: 0.0022 - raw_multi_label_accuracy: 0.9994 - val_loss: 1.0355 - val_raw_multi_label_accuracy: 0.1821
# Epoch 200/1000
#  - 7s - loss: 0.0022 - raw_multi_label_accuracy: 0.9989 - val_loss: 1.0392 - val_raw_multi_label_accuracy: 0.1798
# Epoch 201/1000
#  - 7s - loss: 0.0021 - raw_multi_label_accuracy: 0.9995 - val_loss: 1.0382 - val_raw_multi_label_accuracy: 0.1818
# Epoch 202/1000
#  - 8s - loss: 0.0021 - raw_multi_label_accuracy: 0.9995 - val_loss: 1.0394 - val_raw_multi_label_accuracy: 0.1822
# Epoch 203/1000
#  - 12s - loss: 0.0021 - raw_multi_label_accuracy: 0.9991 - val_loss: 1.0437 - val_raw_multi_label_accuracy: 0.1799
# Epoch 204/1000
#  - 13s - loss: 0.0020 - raw_multi_label_accuracy: 0.9995 - val_loss: 1.0448 - val_raw_multi_label_accuracy: 0.1809
# Epoch 205/1000
#  - 9s - loss: 0.0020 - raw_multi_label_accuracy: 0.9993 - val_loss: 1.0481 - val_raw_multi_label_accuracy: 0.1821
# Epoch 206/1000
#  - 9s - loss: 0.0020 - raw_multi_label_accuracy: 0.9992 - val_loss: 1.0444 - val_raw_multi_label_accuracy: 0.1836
# Epoch 207/1000
#  - 8s - loss: 0.0020 - raw_multi_label_accuracy: 0.9994 - val_loss: 1.0504 - val_raw_multi_label_accuracy: 0.1795
# Epoch 208/1000
#  - 10s - loss: 0.0019 - raw_multi_label_accuracy: 0.9994 - val_loss: 1.0487 - val_raw_multi_label_accuracy: 0.1791
# Epoch 209/1000
#  - 11s - loss: 0.0019 - raw_multi_label_accuracy: 0.9994 - val_loss: 1.0551 - val_raw_multi_label_accuracy: 0.1811
# Epoch 210/1000
#  - 8s - loss: 0.0018 - raw_multi_label_accuracy: 0.9994 - val_loss: 1.0534 - val_raw_multi_label_accuracy: 0.1803
# Epoch 211/1000
#  - 7s - loss: 0.0018 - raw_multi_label_accuracy: 0.9994 - val_loss: 1.0576 - val_raw_multi_label_accuracy: 0.1809
# Epoch 212/1000
#  - 7s - loss: 0.0018 - raw_multi_label_accuracy: 0.9991 - val_loss: 1.0559 - val_raw_multi_label_accuracy: 0.1824
# Epoch 213/1000
#  - 9s - loss: 0.0018 - raw_multi_label_accuracy: 0.9993 - val_loss: 1.0584 - val_raw_multi_label_accuracy: 0.1809
# Epoch 214/1000
#  - 10s - loss: 0.0017 - raw_multi_label_accuracy: 0.9992 - val_loss: 1.0629 - val_raw_multi_label_accuracy: 0.1773
# Epoch 215/1000
#  - 7s - loss: 0.0017 - raw_multi_label_accuracy: 0.9991 - val_loss: 1.0641 - val_raw_multi_label_accuracy: 0.1802
# Epoch 216/1000
#  - 7s - loss: 0.0017 - raw_multi_label_accuracy: 0.9989 - val_loss: 1.0599 - val_raw_multi_label_accuracy: 0.1771
# Epoch 217/1000
#  - 11s - loss: 0.0017 - raw_multi_label_accuracy: 0.9990 - val_loss: 1.0673 - val_raw_multi_label_accuracy: 0.1758
# Epoch 218/1000
#  - 12s - loss: 0.0016 - raw_multi_label_accuracy: 0.9994 - val_loss: 1.0672 - val_raw_multi_label_accuracy: 0.1794
# Epoch 219/1000
#  - 13s - loss: 0.0016 - raw_multi_label_accuracy: 0.9993 - val_loss: 1.0692 - val_raw_multi_label_accuracy: 0.1782
# Epoch 220/1000
#  - 12s - loss: 0.0016 - raw_multi_label_accuracy: 0.9991 - val_loss: 1.0700 - val_raw_multi_label_accuracy: 0.1809
# Epoch 221/1000
#  - 10s - loss: 0.0016 - raw_multi_label_accuracy: 0.9991 - val_loss: 1.0785 - val_raw_multi_label_accuracy: 0.1796
# Epoch 222/1000
#  - 10s - loss: 0.0016 - raw_multi_label_accuracy: 0.9994 - val_loss: 1.0737 - val_raw_multi_label_accuracy: 0.1786
# Epoch 223/1000
#  - 8s - loss: 0.0015 - raw_multi_label_accuracy: 0.9991 - val_loss: 1.0778 - val_raw_multi_label_accuracy: 0.1780
# Epoch 224/1000
#  - 8s - loss: 0.0015 - raw_multi_label_accuracy: 0.9991 - val_loss: 1.0789 - val_raw_multi_label_accuracy: 0.1788
# Epoch 225/1000
#  - 8s - loss: 0.0015 - raw_multi_label_accuracy: 0.9995 - val_loss: 1.0819 - val_raw_multi_label_accuracy: 0.1772
# Epoch 226/1000
#  - 8s - loss: 0.0015 - raw_multi_label_accuracy: 0.9994 - val_loss: 1.0823 - val_raw_multi_label_accuracy: 0.1781
# Epoch 227/1000
#  - 9s - loss: 0.0015 - raw_multi_label_accuracy: 0.9989 - val_loss: 1.0845 - val_raw_multi_label_accuracy: 0.1784
# Epoch 228/1000
#  - 8s - loss: 0.0015 - raw_multi_label_accuracy: 0.9993 - val_loss: 1.0863 - val_raw_multi_label_accuracy: 0.1728
# Epoch 229/1000
#  - 10s - loss: 0.0015 - raw_multi_label_accuracy: 0.9990 - val_loss: 1.0849 - val_raw_multi_label_accuracy: 0.1814
# Epoch 230/1000
#  - 8s - loss: 0.0015 - raw_multi_label_accuracy: 0.9994 - val_loss: 1.0802 - val_raw_multi_label_accuracy: 0.1824
# Epoch 231/1000
#  - 7s - loss: 0.0014 - raw_multi_label_accuracy: 0.9994 - val_loss: 1.0865 - val_raw_multi_label_accuracy: 0.1774
# Epoch 232/1000
#  - 7s - loss: 0.0014 - raw_multi_label_accuracy: 0.9991 - val_loss: 1.0917 - val_raw_multi_label_accuracy: 0.1806
# Epoch 233/1000
#  - 10s - loss: 0.0014 - raw_multi_label_accuracy: 0.9993 - val_loss: 1.0951 - val_raw_multi_label_accuracy: 0.1833
# Epoch 234/1000
#  - 7s - loss: 0.0014 - raw_multi_label_accuracy: 0.9993 - val_loss: 1.1000 - val_raw_multi_label_accuracy: 0.1830
# Epoch 235/1000
#  - 7s - loss: 0.0014 - raw_multi_label_accuracy: 0.9995 - val_loss: 1.0924 - val_raw_multi_label_accuracy: 0.1760
# Epoch 236/1000
#  - 8s - loss: 0.0018 - raw_multi_label_accuracy: 0.9989 - val_loss: 1.0889 - val_raw_multi_label_accuracy: 0.1882
# Epoch 237/1000
#  - 7s - loss: 0.0130 - raw_multi_label_accuracy: 0.9675 - val_loss: 1.0571 - val_raw_multi_label_accuracy: 0.1816
# Epoch 238/1000
#  - 7s - loss: 0.0246 - raw_multi_label_accuracy: 0.9364 - val_loss: 1.0438 - val_raw_multi_label_accuracy: 0.1852
# Epoch 239/1000
#  - 7s - loss: 0.0316 - raw_multi_label_accuracy: 0.9171 - val_loss: 1.0603 - val_raw_multi_label_accuracy: 0.1658
# Epoch 240/1000
#  - 7s - loss: 0.0216 - raw_multi_label_accuracy: 0.9429 - val_loss: 1.0345 - val_raw_multi_label_accuracy: 0.1774
# Epoch 241/1000
#  - 8s - loss: 0.0183 - raw_multi_label_accuracy: 0.9542 - val_loss: 1.0498 - val_raw_multi_label_accuracy: 0.2003
# Epoch 242/1000
#  - 7s - loss: 0.0086 - raw_multi_label_accuracy: 0.9848 - val_loss: 1.0670 - val_raw_multi_label_accuracy: 0.1805
# Epoch 243/1000
#  - 7s - loss: 0.0042 - raw_multi_label_accuracy: 0.9977 - val_loss: 1.0732 - val_raw_multi_label_accuracy: 0.1885
# Epoch 244/1000
#  - 7s - loss: 0.0031 - raw_multi_label_accuracy: 0.9992 - val_loss: 1.0700 - val_raw_multi_label_accuracy: 0.1831
# Epoch 245/1000
#  - 8s - loss: 0.0025 - raw_multi_label_accuracy: 0.9991 - val_loss: 1.0768 - val_raw_multi_label_accuracy: 0.1834
# Epoch 246/1000
#  - 7s - loss: 0.0022 - raw_multi_label_accuracy: 0.9994 - val_loss: 1.0783 - val_raw_multi_label_accuracy: 0.1841
# Epoch 247/1000
#  - 8s - loss: 0.0020 - raw_multi_label_accuracy: 0.9994 - val_loss: 1.0910 - val_raw_multi_label_accuracy: 0.1787
# Epoch 248/1000
#  - 10s - loss: 0.0019 - raw_multi_label_accuracy: 0.9993 - val_loss: 1.0905 - val_raw_multi_label_accuracy: 0.1824
# Epoch 249/1000
#  - 9s - loss: 0.0018 - raw_multi_label_accuracy: 0.9990 - val_loss: 1.0940 - val_raw_multi_label_accuracy: 0.1825
# Epoch 250/1000
#  - 7s - loss: 0.0018 - raw_multi_label_accuracy: 0.9994 - val_loss: 1.0973 - val_raw_multi_label_accuracy: 0.1818
# Epoch 251/1000
#  - 7s - loss: 0.0017 - raw_multi_label_accuracy: 0.9992 - val_loss: 1.0978 - val_raw_multi_label_accuracy: 0.1838
# Epoch 252/1000
#  - 7s - loss: 0.0016 - raw_multi_label_accuracy: 0.9990 - val_loss: 1.1020 - val_raw_multi_label_accuracy: 0.1824
# Epoch 253/1000
#  - 6s - loss: 0.0016 - raw_multi_label_accuracy: 0.9991 - val_loss: 1.1038 - val_raw_multi_label_accuracy: 0.1838

# %%
def nn_output_to_predictions(res):
    label_predictions = []
    for i in range(res.shape[0]):
        pred = [0]*20
        for j in range(res.shape[1]):
            if res[i][j] >= .5:
                pred[j] = 1
        label_predictions.append(pred)
    return np.array(label_predictions)

# %%
predictions = nn_output_to_predictions(model_lstm.predict(x_test_seq))

# %%
y_test[:,2].sum()
# Out:
# 27

# %%
predictions[:,2].sum()
# Out:
# 11

# %%
multi_label_accuracy(y_test, predictions)
# Out:
# 0.2355627343064528

# %%
multi_label_precision(y_test, predictions)
# Out:
# 0.39967551622418895

# %%
multi_label_recall(y_test, predictions)
# Out:
# 0.32300789662598717

# %%
print("Percent of correctly decided label decisions: " + str(100* (1-hamming_loss(y_test, predictions))))
# Out:
# Percent of correctly decided label decisions: 84.71524288107203

# %%
get_per_label_metrics(y_test, predictions)
# Out:
# Accuracy for Comedy: 0.6147403685092128
# Precision for Comedy: 0.46153846153846156
# Recall for Comedy: 0.3888888888888889
#
# Accuracy for Western: 0.9782244556113903
# Precision for Western: 0.0
# Recall for Western: 0.0
#
# Accuracy for Animation: 0.9430485762144054
# Precision for Animation: 0.18181818181818182
# Recall for Animation: 0.07407407407407407
#
# Accuracy for TV Movie: 1.0
# Precision for TV Movie: 0.0
# Recall for TV Movie: 0.0
#
# Accuracy for Foreign: 0.9849246231155779
# Precision for Foreign: 0.0
# Recall for Foreign: 0.0
#
# Accuracy for Music: 0.9698492462311558
# Precision for Music: 0.0
# Recall for Music: 0.0
#
# Accuracy for Adventure: 0.8157453936348409
# Precision for Adventure: 0.3170731707317073
# Recall for Adventure: 0.1368421052631579
#
# Accuracy for Action: 0.6733668341708543
# Precision for Action: 0.32727272727272727
# Recall for Action: 0.22929936305732485
#
# Accuracy for Fantasy: 0.8609715242881072
# Precision for Fantasy: 0.04878048780487805
# Recall for Fantasy: 0.043478260869565216
#
# Accuracy for Thriller: 0.6365159128978225
# Precision for Thriller: 0.35542168674698793
# Recall for Thriller: 0.34911242603550297
#
# Accuracy for History: 0.9530988274706867
# Precision for History: 0.14285714285714285
# Recall for History: 0.043478260869565216
#
# Accuracy for Crime: 0.8123953098827471
# Precision for Crime: 0.3191489361702128
# Recall for Crime: 0.15789473684210525
#
# Accuracy for Family: 0.897822445561139
# Precision for Family: 0.2222222222222222
# Recall for Family: 0.13043478260869565
#
# Accuracy for War: 0.9581239530988275
# Precision for War: 0.16666666666666666
# Recall for War: 0.047619047619047616
#
# Accuracy for Drama: 0.5376884422110553
# Precision for Drama: 0.570957095709571
# Recall for Drama: 0.542319749216301
#
# Accuracy for Science Fiction: 0.8425460636515912
# Precision for Science Fiction: 0.23333333333333334
# Recall for Science Fiction: 0.22580645161290322
#
# Accuracy for Mystery: 0.8994974874371859
# Precision for Mystery: 0.2222222222222222
# Recall for Mystery: 0.2
#
# Accuracy for Romance: 0.7738693467336684
# Precision for Romance: 0.36046511627906974
# Recall for Romance: 0.27927927927927926
#
# Accuracy for Horror: 0.8207705192629816
# Precision for Horror: 0.11940298507462686
# Recall for Horror: 0.14285714285714285
#
# Accuracy for Documentary: 0.9698492462311558
# Precision for Documentary: 0.25
# Recall for Documentary: 0.0625

# %%
y_train.shape
# Out:
# (2388, 20)
